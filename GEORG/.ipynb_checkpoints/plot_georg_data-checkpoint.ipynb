# %% [markdown]
# # Convert GEORG CSV to Mseed

# %%
import matplotlib.pyplot as plt

from pandas import read_csv
from andbro__read_sds import __read_sds
from obspy import UTCDateTime, Stream
from functions.welch_psd import __welch_psd

# %% [markdown]
# ### Configurations

# %%
t1 = UTCDateTime("2024-12-27 13:10:00")
t2 = UTCDateTime("2024-12-27 14:20:00")

path_to_data = workdir+"/kilauea-data/GEORG/data/"

# %%
st = __read_sds(path_to_data, seed, t1, t2)

# st = st.detrend("demean")

# %%
# st_rlas = obs.read("/home/andbro/freenas/romy_archive/2024/BW/RLAS/BJZ.D/"+"BW.RLAS..BJZ.D.2024.362")

# %%
st_romy = obs.read("/home/andbro/freenas/romy_archive/2024/BW/ROMY/BJU.D/"+"BW.ROMY..BJU.D.2024.362")
st_romy += obs.read("/home/andbro/freenas/romy_archive/2024/BW/ROMY/BJV.D/"+"BW.ROMY..BJV.D.2024.362")

# %%
st_georg = obs.read("/home/andbro/kilauea-data/GEORG/data/2024/XX/GEORG/BJZ.D/"+"XX.GEORG.10.BJZ.D.2024.362")

# %%
st = Stream()
st += st_romy.copy()
st += st_georg.copy()

st = st.detrend("demean")
st = st.taper(0.02)
st = st.filter("bandpass", freqmin=0.03, freqmax=0.1, corners=4, zerophase=True)

st = st.trim(t1, t2)

st.plot(equal_scale=False, method="full");

# %%
# %matplotlib tk

st_georg = st_georg.detrend("demean")
st_georg = st_georg.taper(0.02)
st_georg = st_georg.filter("bandpass", freqmin=0.05, freqmax=0.1, corners=4, zerophase=True)


st_georg.plot(method="full");
