# %% [markdown]
# ## Georg Seismic Experiment

# %% [markdown]
# Explore seismic signals at Bonn

# %% [markdown]
# ## Imports

# %%
import os
import gc
import matplotlib.pyplot as plt
import numpy as np
import obspy as obs

import pandas as pd

# %%
import os
import gc
import matplotlib.pyplot as plt
import numpy as np

from datetime import datetime, date
from pandas import DataFrame, read_pickle, date_range, concat, read_csv
from obspy import UTCDateTime, read, Trace, Stream, read_inventory
from scipy.signal import hilbert
from scipy.ndimage import gaussian_filter1d

# from functions.get_fft import __get_fft
# from functions.multitaper_psd import __multitaper_psd
# from functions.welch_psd import __welch_psd
# from functions.rotate_romy_ZUV_ZNE import __rotate_romy_ZUV_ZNE
# from functions.reduce import __reduce
from functions.load_backscatter_data import __load_backscatter_data

from andbro__read_sds import __read_sds
from andbro__readYaml import __readYaml
from andbro__load_FURT_stream import __load_furt_stream

# %% [markdown]
# ## Configurations

# %%
config = {}

config['path_to_inv'] = "/home/andbro/kilauea-data/GEORG/stationxml/"

config['path_to_data'] = "/home/andbro/kilauea-data/GEORG/data/"

config['tbeg'] = obs.UTCDateTime("2024-12-17 02:00")
config['tend'] = obs.UTCDateTime("2024-12-17 04:00")

# %% [markdown]
# ### Load Data

# %%
st_seis = obs.read(config['path_to_data']+'BONN_centaur-3_10343_20241216_180000.seed')

# %%
head = ["time", "north", "east", "X1", "X2", "pressure", "X3", "X4", "X5", "X6"]

tilt = pd.read_csv(config['path_to_data']+"LGMBoxmessung12_16.csv", delimiter=";", names=head)

starttime = obs.UTCDateTime(tilt.time[0])
print(starttime)

mean_dt = tilt.time.diff().mean()
print(mean_dt)
# Out:
# 2024-12-16T16:36:15.716615Z
# 1.0550388852159318

# %%
# plt.plot(tilt.time.diff())

# %%
tilt_n = obs.Trace()
tilt_n.stats.network = "XX"
tilt_n.stats.network = "BONN"
tilt_n.stats.network = ""
tilt_n.stats.network = "LAN"

tilt_n.stats.starttime = starttime
tilt_n.stats.sampling_rate = 1/mean_dt
# tilt_n.stats.delta = mean_dt

tilt_n.data = np.array(tilt.north)

tilt_e = obs.Trace()
tilt_e.stats.network = "XX"
tilt_e.stats.network = "BONN"
tilt_e.stats.network = ""
tilt_e.stats.network = "LAE"

tilt_e.stats.starttime = starttime
tilt_e.stats.sampling_rate = 1/mean_dt
# tilt_n.stats.delta = mean_dt

tilt_e.data = np.array(tilt.east)

st_tilt = obs.Stream(traces=[tilt_n, tilt_e])

# %%
st_tilt
# Out:
# 2 Trace(s) in Stream:
# LAN... | 2024-12-16T16:36:15.716615Z - 2024-12-17T08:27:11.164489Z | 0.9 Hz, 54080 samples
# LAE... | 2024-12-16T16:36:15.716615Z - 2024-12-17T08:27:11.164489Z | 0.9 Hz, 54080 samples

# %%
st_tilt.plot();

# %%
st_rasp = obs.Stream()
st_rasp += obs.read(config['path_to_data']+"AM.RACB0.00.EHZ.D.2024.352")
st_rasp += obs.read(config['path_to_data']+"AM.RACB0.00.EHN.D.2024.352")
st_rasp += obs.read(config['path_to_data']+"AM.RACB0.00.EHE.D.2024.352")

inv_rasp = obs.read_inventory(config['path_to_inv']+"station_AM_RACB0.dataless")

for tr in st_rasp:
    tr = tr.stats.station = "R106A"
    tr = tr.stats.location = ""
    tr = tr.remove_response(inv_rasp, output="VEL")
    tr = tr.stats.station = "RACB0"

# %%
st_rasp
# Out:
# 3 Trace(s) in Stream:
# AM.RACB0..EHZ | 2024-12-17T00:00:01.216999Z - 2024-12-17T09:23:00.056999Z | 100.0 Hz, 3377885 samples
# AM.RACB0..EHN | 2024-12-17T00:00:00.886999Z - 2024-12-17T09:24:18.136999Z | 100.0 Hz, 3385726 samples
# AM.RACB0..EHE | 2024-12-17T00:00:02.086999Z - 2024-12-17T09:22:30.666999Z | 100.0 Hz, 3374859 samples

# %%
st_rasp.plot();

# %%
st = obs.Stream()
st += st_seis
st += st_tilt
st += st_rasp

# %%
st = st.detrend("demean")
st = st.taper(0.05)
st = st.filter("bandpass", freqmin=0.01, freqmax=0.1, corners=4, zerophase=True)

st = st.trim(config['tbeg'], config['tend'])

# %%
st.plot(equal_scale=False);

# %%
ppsd = obs.signal.PPSD(st[0].stats, metadata=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 ppsd = obs.signal.PPSD(st[0].stats, )
#
# TypeError: PPSD.__init__() missing 1 required positional argument: 'metadata'

# %%
config = {}

config['ring'] = "Z"

config['delta'] = 10

# for FSR ex5 (after fixation 2024-10-01 14:00)
config['name'] = "ex0"
config['tbeg'] = UTCDateTime("2024-10-01 00:00")
config['tend'] = UTCDateTime("2024-10-01 04:00")
flim1, flim2 = 315.0, 316.0

# no jumps
# config['name'] = "no_jumps"
# config['tbeg'] = UTCDateTime("2024-09-12 16:00")
# config['tend'] = UTCDateTime("2024-09-14 02:00")
# flim1, flim2 = 553.572, 553.585

# path to Sagnac data
config['path_to_autodata'] = "/import/kilauea-data/sagnac_frequency/bonn/"

config['path_to_data'] = "/import/kilauea-data/sagnac_frequency/bonn/backscatter/"

config['path_to_out_data'] = "/import/kilauea-data/sagnac_frequency/bonn/data/"

config['path_to_figs'] = "/import/kilauea-data/sagnac_frequency/bonn/"

# %% [markdown]
# ### Load backscatter data

# %%
read_pickle("/import/kilauea-data/sagnac_frequency/bonn/FJZ_20241001_00:00:00_backscatter.pkl")
# Out:
#                            time1                        time2       fj_fs  \
# 0    2024-10-01T00:00:00.000000Z  2024-10-01T00:00:10.000000Z         NaN
# 1    2024-10-01T00:00:10.000000Z  2024-10-01T00:00:20.000000Z  312.502815
# 2    2024-10-01T00:00:20.000000Z  2024-10-01T00:00:30.000000Z  312.485450
# 3    2024-10-01T00:00:30.000000Z  2024-10-01T00:00:40.000000Z  312.649907
# 4    2024-10-01T00:00:40.000000Z  2024-10-01T00:00:50.000000Z  312.583389
# 1438  312.337152  2.647530e-09  1.917498e-09  99.679052  2.494753 -0.851913
#
#            f1_fs  ...       f2_fs         f2_ac         f2_dc      f2_ph  \
# 1     312.502815  ...  312.502815  2.870953e-09  2.050871e-09  -1.347332
# 2     312.485450  ...  312.485450  1.856995e-09  2.044430e-09  -0.611524
# 3     312.649907  ...  312.649907  2.411085e-09  1.991101e-09  -0.643076
# 4     312.583389  ...  312.583389  2.416891e-09  1.979033e-09  -3.065027
# 5     312.411850  ...  312.411850  3.011914e-09  1.969076e-09  -5.906835
# ...          ...  ...         ...           ...           ...        ...
# 1434  312.198933  ...  312.198933  2.729678e-09  1.889469e-09  97.985798
# 1435  312.307049  ...  312.307049  2.489348e-09  1.859137e-09  97.607014
# 1436  312.226800  ...  312.226800  1.771393e-09  1.861603e-09  96.341033
# 1437  312.155041  ...  312.155041  2.370253e-09  1.884711e-09  97.167810
# 1438  312.337152  ...  312.337152  2.647530e-09  1.917498e-09  99.679052
#
#          f2_st    f2_phw           w_s  bscorrection       term  time_sec
# 1     1.650832 -1.347332  -5377.264068   5735.233357 -17.207090      20.0
# 2     2.180265 -0.611524    593.305211   -283.079499   1.898665      30.0
# 3     8.754104 -0.643076   1823.080043  -1521.783573   5.831059      40.0
# 4     2.287949 -3.065027   1968.568724  -1668.787913   6.297739      50.0
# 5     1.831257  0.376351  -1519.074885   1846.659532  -4.862411      60.0
# ...        ...       ...           ...           ...        ...       ...
# 1434  0.749815 -2.545167  -2827.907518   3168.279673  -9.058031   14350.0
# 1435  1.143279 -2.923951  21287.741797 -21156.301071  68.162861   14360.0
# 1436  0.954008  2.093253    650.940470   -341.722126   2.084832   14370.0
# 1437  1.520815  2.920031   2737.955772  -2447.909304   8.771141   14380.0
# 1438  2.494753 -0.851913  -8818.620474   9208.804119 -28.234299   14390.0
#
# [1438 rows x 25 columns]

# %%
plt.plot(bs.time_sec/3600, bs.fj_fs)
plt.ylabel("Sagnac Frequency / Hz")
plt.xlabel("Time / hours")
# Out:
# Text(0, 0.5, 'Sagnac Frequency / Hz')
# Text(0.5, 0, 'Time / hours')

# %%
from allantools import oadev, adev

# %%
# define tau range e.g. 5 (= 10⁵) and number of samples N
upper = 6
lower = -4
N = 150

# list of tau values in seconds
taux = np.logspace(lower, upper, N)

# smallest sampling in seconds
dtaux = taux[1]-taux[0]

omegaE = 2*np.pi/86400
scalef = 4/632.8e-9

data = bs.fj_fs.values / scalef / omegaE

taus, ad, ade, ns = oadev(data, rate=1/config['delta'], data_type="freq", taus=taux)

# %%
plt.loglog(taus, ad)
plt.grid(True, which="both")
plt.xlabel("Tau / s")
plt.ylabel("Overlapping Allan Deviation $\Omega$/$\Omega_E$")
# Out:
# Text(0.5, 0, 'Tau / s')
# Text(0, 0.5, 'Overlapping Allan Deviation $\\Omega$/$\\Omega_E$')
