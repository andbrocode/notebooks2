# %% [markdown]
# ## Georg Seismic Experiment

# %% [markdown]
# Explore seismic signals at Bonn

# %% [markdown]
# ## Imports

# %%
import os
import gc
import matplotlib.pyplot as plt
import numpy as np
import obspy as obs
import pandas as pd

from obspy.signal import PPSD

from andbro__read_sds import __read_sds
from andbro__trim_stream import __trim_stream

# %% [markdown]
# ## Configurations

# %%
config = {}

config['workdir'] = "/home/andbro/"
# config['workdir'] = "/import/"

config['path_to_inv'] = config['workdir']+"kilauea-data/GEORG/stationxml/"

config['path_to_data'] = config['workdir']+"kilauea-data/GEORG/data/"

config['path_to_figs'] = config['workdir']+"kilauea-data/GEORG/figs/"

config['tbeg'] = obs.UTCDateTime("2024-12-17 02:00")
config['tend'] = obs.UTCDateTime("2024-12-17 04:00")

# config['tbeg'] = obs.UTCDateTime("2024-12-17 05:00")
# config['tend'] = obs.UTCDateTime("2024-12-17 06:00")

# Kuril Islands
config['tbeg'] = obs.UTCDateTime("2024-12-27 12:47:00")
config['tend'] = obs.UTCDateTime("2024-12-27 14:47:00")

# South Sandwich Islands
# config['tbeg'] = obs.UTCDateTime("2025-01-01 13:48:00")
# config['tend'] = obs.UTCDateTime("2025-01-01 15:48:00")

# Small Event
# config['tbeg'] = obs.UTCDateTime("2024-12-21 13:20:00")
# config['tend'] = obs.UTCDateTime("2024-12-21 13:30:00")

# Calibration
config['tbeg'] = obs.UTCDateTime("2024-12-19 13:08:00")
config['tend'] = obs.UTCDateTime("2024-12-19 13:14:00")

# %% [markdown]
# ### Load Data

# %% [markdown]
# ### Load Seismometer Data

# %%
# st_seis = obs.read(config['path_to_data']+'BONN_centaur-3_10343_20241216_180000.seed')
st_seis = __read_sds(config['path_to_data'], "XN.BONN..BH*", config['tbeg'], config['tend'])

inv_seis = obs.read_inventory(config['path_to_inv']+'station_XN_BONN_centaur.xml')

st_seis.remove_response(inv_seis, output="ACC")

print(st_seis)
# Out:
# 3 Trace(s) in Stream:
# XN.BONN..BHE | 2024-12-19T13:08:00.000000Z - 2024-12-19T13:14:00.000000Z | 40.0 Hz, 14401 samples
# XN.BONN..BHN | 2024-12-19T13:08:00.000000Z - 2024-12-19T13:14:00.000000Z | 40.0 Hz, 14401 samples
# XN.BONN..BHZ | 2024-12-19T13:08:00.000000Z - 2024-12-19T13:14:00.000000Z | 40.0 Hz, 14401 samples

# %% [markdown]
# ### Load Tiltmeter Data

# %%
st_tilt = __read_sds(config['path_to_data'], "XX.TILT..LA*", config['tbeg'], config['tend'])

print(st_tilt)
# Out:
# 2 Trace(s) in Stream:
# XX.TILT..LAE | 2024-12-19T13:07:59.710515Z - 2024-12-19T13:13:59.479254Z | 0.9 Hz, 342 samples
# XX.TILT..LAN | 2024-12-19T13:07:59.710515Z - 2024-12-19T13:13:59.479254Z | 0.9 Hz, 342 samples

# %%
for tr in st_tilt:
    tr.data *= 9.81

# %%
st_tilt.plot();

# %% [markdown]
# ### Load RaspShake Data

# %%
st_rasp = __read_sds(config['path_to_data'], "AM.RACB0.00.EH*", config['tbeg'], config['tend'])

inv_rasp = obs.read_inventory(config['path_to_inv']+"station_AM_RACB0.xml")

st_rasp = st_rasp.remove_response(inv_rasp, output="ACC")

# %%
st_rasp
# Out:
# 3 Trace(s) in Stream:
# AM.RACB0.00.EHE | 2024-12-19T13:07:59.996999Z - 2024-12-19T13:13:59.996999Z | 100.0 Hz, 36001 samples
# AM.RACB0.00.EHN | 2024-12-19T13:07:59.996999Z - 2024-12-19T13:13:59.996999Z | 100.0 Hz, 36001 samples
# AM.RACB0.00.EHZ | 2024-12-19T13:07:59.996999Z - 2024-12-19T13:13:59.996999Z | 100.0 Hz, 36001 samples

# %%
st_rasp.plot();

# %% [markdown]
# ### Combine Data

# %%
st0 = obs.Stream()
st0 += st_seis.copy()
st0 += st_tilt.copy()
st0 += st_rasp.copy()

# %%
st = st0.copy()

st = st.detrend("demean")
st = st.taper(0.05)
st = st.filter("bandpass", freqmin=0.01, freqmax=0.1, corners=4, zerophase=True)

st = st.trim(config['tbeg'], config['tend'])

# %%
st.plot(equal_scale=False);

# %%
stx = st.copy()

# stx = stx.trim(config['tbeg']+3100, config['tend']-2200)

stx = stx.resample(1.0, no_filter=True)

stx = __trim_stream(stx, set_common=True, set_interpolate=True)

print(stx)

stx.plot();
# Out:
# 8 Trace(s) in Stream:
# XN.BONN..BHE    | 2024-12-19T13:08:00.000000Z - 2024-12-19T13:13:59.000000Z | 1.0 Hz, 360 samples
# XN.BONN..BHN    | 2024-12-19T13:08:00.000000Z - 2024-12-19T13:13:59.000000Z | 1.0 Hz, 360 samples
# XN.BONN..BHZ    | 2024-12-19T13:08:00.000000Z - 2024-12-19T13:13:59.000000Z | 1.0 Hz, 360 samples
# XX.TILT..LAE    | 2024-12-19T13:07:59.710515Z - 2024-12-19T13:13:58.710515Z | 1.0 Hz, 360 samples
# XX.TILT..LAN    | 2024-12-19T13:07:59.710515Z - 2024-12-19T13:13:58.710515Z | 1.0 Hz, 360 samples
# AM.RACB0.00.EHE | 2024-12-19T13:07:59.996999Z - 2024-12-19T13:13:58.996999Z | 1.0 Hz, 360 samples
# AM.RACB0.00.EHN | 2024-12-19T13:07:59.996999Z - 2024-12-19T13:13:58.996999Z | 1.0 Hz, 360 samples
# AM.RACB0.00.EHZ | 2024-12-19T13:07:59.996999Z - 2024-12-19T13:13:58.996999Z | 1.0 Hz, 360 samples

# %%
from andbro__crosscorrelationTraces import __crosscorrelationTraces

# %%
tr1 = stx.select(channel="LAN")[0]
tr2 = stx.select(channel="BHN")[0]

out = __crosscorrelationTraces(tr1, tr2)

# out['figure'].savefig(config['path_to_figs']+"CC_n.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# Maximum Correlation:
#  x: 26s
#  y: -0.38

# %%
tr1 = stx.select(channel="LAE")[0]
tr2 = stx.select(channel="BHE")[0]

out = __crosscorrelationTraces(tr1, tr2)

# out['figure'].savefig(config['path_to_figs']+"CC_e.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# Maximum Correlation:
#  x: 63s
#  y: -0.45

# %%
tr1 = stx.select(channel="EHE")[0]
tr2 = stx.select(channel="BHE")[0]

out = __crosscorrelationTraces(tr1, tr2)

# out['figure'].savefig(config['path_to_figs']+"CC_e_rasp.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# Maximum Correlation:
#  x: 105s
#  y: 0.34

# %%
tr1 = stx.select(channel="EHN")[0]
tr2 = stx.select(channel="BHN")[0]

out = __crosscorrelationTraces(tr1, tr2)

# out['figure'].savefig(config['path_to_figs']+"CC_N_rasp.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# Maximum Correlation:
#  x: 124s
#  y: 0.3

# %%
def __compare_psd_stream(st0, twin_sec=3600, psd="welch", time_bandwidth=None, n_win=5, plot=True):

    def __welch_psd(arr, dt, twin_sec=60):

        from scipy.signal import welch
        from scipy.signal.windows import hann

        nblock = int(1/dt * twin_sec)
        overlap = int(0.5*nblock)
        win = hann(nblock, True)

        ff, Pxx = welch(arr,
                        fs=1/dt,
                        window=win,
                        noverlap=overlap,
                        nfft=nblock,
                        scaling="density",
                        return_onesided=True)

        return ff, Pxx

    def __multitaper_psd(arr, dt, n_win=5, time_bandwidth=4.0):

        import multitaper as mt

        out_psd = mt.MTSpec(arr, nw=time_bandwidth, kspec=n_win, dt=dt, iadapt=2)

        _f, _psd = out_psd.rspec()

        f = _f.reshape(_f.size)
        psd = _psd.reshape(_psd.size)

        ## 95% confidence interval
        # _psd95 = out_psd.jackspec()
        # psd95_lower, psd95_upper = psd95[::2, 0], psd95[::2, 1]

        return f, psd

    fxxs, pxxs = {}, {}

    for tr in st0:

        seed = tr.get_id()

        if psd == "welch":
            fxxs[seed], pxxs[seed] = __welch_psd(tr.data, tr.stats.delta, twin_sec)
        elif psd == "multitaper":
            fxxs[seed], pxxs[seed] = __multitaper_psd(tr.data, tr.stats.delta, n_win=n_win, time_bandwidth=time_bandwidth)

    if plot:

        Nrow, Ncol = 1, 1

        font = 12

        fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

        for tr in st0:

            ax.plot(fxxs[tr.get_id()], pxxs[tr.get_id()], label=tr.get_id())

        ax.set_xscale("log")
        ax.set_yscale("log")

        ax.grid(ls=":", zorder=0)
        ax.legend(loc=1)

        ax.set_xlim(1/twin_sec, 0.5/tr.stats.delta)

        ax.set_xlabel("Frequency (Hz")
        ax.set_ylabel("PSD")

        plt.show();

    return fxxs, pxxs

# %%
st2 = st0.copy()

st2 = st2.detrend("demean")

st2 = st2.taper(0.01)

# st2 = st2.resample(1.0, no_filter=False)

fxx, pxx = __compare_psd_stream(st2, twin_sec=3600, psd="welch", plot=False)

# fxx, pxx = __compare_psd_stream(st2, n_win=10, time_bandwidth=3.5, psd="multitaper", plot=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 9
#       5 st2 = st2.taper(0.01)
#       7 # st2 = st2.resample(1.0, no_filter=False)
# ----> 9 fxx, pxx = __compare_psd_stream(st2, twin_sec=3600, psd="welch", plot=False)
#
# Cell In[158], line 46, in __compare_psd_stream(st0, twin_sec, psd, time_bandwidth, n_win, plot)
#      43 seed = tr.get_id()
#      45 if psd == "welch":
# ---> 46     fxxs[seed], pxxs[seed] = __welch_psd(tr.data, tr.stats.delta, twin_sec)
#      47 elif psd == "multitaper":
#      48     fxxs[seed], pxxs[seed] = __multitaper_psd(tr.data, tr.stats.delta, n_win=n_win, time_bandwidth=time_bandwidth)
#
# Cell In[158], line 12, in __compare_psd_stream.<locals>.__welch_psd(arr, dt, twin_sec)
#       9 overlap = int(0.5*nblock)
#      10 win = hann(nblock, True)
# ---> 12 ff, Pxx = welch(arr,
#      13                 fs=1/dt,
#      14                 window=win,
#      15                 noverlap=overlap,
#      16                 nfft=nblock,
#      17                 scaling="density",
#      18                 return_onesided=True)
#      20 return ff, Pxx
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:455, in welch(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, average)
#     297 def welch(x, fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None,
#     298           detrend='constant', return_onesided=True, scaling='density',
#     299           axis=-1, average='mean'):
#     300     r"""
#     301     Estimate power spectral density using Welch's method.
#     302
#    (...)
#     453
#     454     """
# --> 455     freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,
#     456                      noverlap=noverlap, nfft=nfft, detrend=detrend,
#     457                      return_onesided=return_onesided, scaling=scaling,
#     458                      axis=axis, average=average)
#     460     return freqs, Pxx.real
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:590, in csd(x, y, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, average)
#     463 def csd(x, y, fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None,
#     464         detrend='constant', return_onesided=True, scaling='density',
#     465         axis=-1, average='mean'):
#     466     r"""
#     467     Estimate the cross power spectral density, Pxy, using Welch's method.
#     468
#    (...)
#     588
#     589     """
# --> 590     freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap, nfft,
#     591                                      detrend, return_onesided, scaling, axis,
#     592                                      mode='psd')
#     594     # Average over windows.
#     595     if len(Pxy.shape) >= 2 and Pxy.size > 0:
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1798, in _spectral_helper(x, y, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode, boundary, padded)
#    1795         raise ValueError('nperseg must be a positive integer')
#    1797 # parse window; if array like, then set nperseg = win.shape
# -> 1798 win, nperseg = _triage_segments(window, nperseg, input_length=x.shape[-1])
#    1800 if nfft is None:
#    1801     nfft = nperseg
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:2027, in _triage_segments(window, nperseg, input_length)
#    2025     raise ValueError('window must be 1-D')
#    2026 if input_length < win.shape[-1]:
# -> 2027     raise ValueError('window is longer than input signal')
#    2028 if nperseg is None:
#    2029     nperseg = win.shape[0]
#
# ValueError: window is longer than input signal

# %%
models = np.load(config['workdir']+"kilauea-data/GEORG/data/"+"noise_models.npz")

# %%
models
# Out:
# NpzFile '/home/andbro/kilauea-data/GEORG/data/noise_models.npz' with keys: low_noise, model_periods, high_noise

# %%
Nrow, Ncol = 1, 1

font = 12

fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

for tr in st2:

    ax.plot(fxx[tr.get_id()], 10*np.log10(pxx[tr.get_id()]), label=tr.get_id())

ax.plot(1/models['model_periods'], models['low_noise'], color="k", ls="--")
ax.plot(1/models['model_periods'], models['high_noise'], color="k", ls="--")

ax.set_xscale("log")
# ax.set_yscale("log")

ax.set_ylim(-200, -80)

ax.grid(ls=":", zorder=0)
ax.legend(loc=4)

fmax = 0.5/tr.stats.delta

if fmax < 10:
    ax.set_xlim(1/3600, fmax)
else:
    ax.set_xlim(1/3600, 10)

ax.set_xlabel(r"Frequency (Hz)", fontsize=font)
ax.set_ylabel(r"PSD (dB rel. to 1 m$^2$ / s$^4$ / Hz)", fontsize=font)

plt.show();

# %%
Nrow, Ncol = 1, 1

font = 12

fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

for tr in st2.select(channel="*N"):

    ax.plot(fxx[tr.get_id()], 10*np.log10(pxx[tr.get_id()]), label=tr.get_id())

ax.plot(1/models['model_periods'], models['low_noise'], color="k", ls="--")
ax.plot(1/models['model_periods'], models['high_noise'], color="k", ls="--")

ax.set_xscale("log")
# ax.set_yscale("log")

ax.set_ylim(-200, -80)

ax.grid(ls=":", zorder=0)
ax.legend(loc=4)

fmax = 0.5/tr.stats.delta

if fmax < 10:
    ax.set_xlim(1/3600, fmax)
else:
    ax.set_xlim(1/3600, 10)

ax.set_xlabel(r"Frequency (Hz)", fontsize=font)
ax.set_ylabel(r"PSD (dB rel. to 1 m$^2$ / s$^4$ / Hz)", fontsize=font)

plt.show();

# %%
Nrow, Ncol = 1, 1

font = 12

fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

for tr in st2.select(channel="*E"):

    ax.plot(fxx[tr.get_id()], 10*np.log10(pxx[tr.get_id()]), label=tr.get_id())

ax.plot(1/models['model_periods'], models['low_noise'], color="k", ls="--")
ax.plot(1/models['model_periods'], models['high_noise'], color="k", ls="--")

ax.set_xscale("log")
# ax.set_yscale("log")

ax.set_ylim(-200, -80)

ax.grid(ls=":", zorder=0)
ax.legend(loc=4)

fmax = 0.5/tr.stats.delta

if fmax < 10:
    ax.set_xlim(1/3600, fmax)
else:
    ax.set_xlim(1/3600, 10)

ax.set_xlabel(r"Frequency (Hz)", fontsize=font)
ax.set_ylabel(r"PSD (dB rel. to 1 m$^2$ / s$^4$ / Hz)", fontsize=font)

plt.show();

# %%
# %matplotlib tk

# shift = stx.select(channel="EHN")[0].data
# shift = np.roll(shift, -5)

# plt.plot(stx.select(channel="HHN")[0].times(), stx.select(channel="HHN")[0].data/10)
# # plt.plot(stx.select(channel="LAN")[0].times(), stx.select(channel="LAN")[0].data)
# plt.plot(stx.select(channel="EHN")[0].times(), shift)
# plt.show()

# %%
from obspy.taup import TauPyModel
from obspy.geodetics import locations2degrees

lat_event = 47.29
lon_event = 151.15
time_event = "2024-12-27 12:47:36.7"
dep_event = 10
event_id = "C202412271247A"

lat_georg = 50.728310247878376
lon_georg = 7.0890113662166385

distance_in_degree = locations2degrees(lat_georg, lon_georg, lat_event, lon_event)

model = TauPyModel(model="iasp91") # ak135 | iasp91

arrivals = model.get_travel_times(source_depth_in_km=dep_event,
                                  distance_in_degree=distance_in_degree,
                                  phase_list=["P", "S"] # "ttbasic"
                                 )

print(arrivals)

paths = model.get_ray_paths(source_depth_in_km=dep_event,
                            distance_in_degree=distance_in_degree,
                            phase_list=["P", "S"] # "ttbasic"
                            )

paths.plot_rays()
# Out:
# 2 arrivals
# 	P phase arrival at 714.238 seconds
# 	S phase arrival at 1304.493 seconds
# <PolarAxes: >

# %%
from obspy.clients.syngine import Client

client = Client()

# %%
syn_model = "iasp91_2s" # "ak135f_2s" | "prem_a_2s" | "iasp91_2s"

lat_event = 47.29
lon_event = 151.15
time_event = "2024-12-27 12:47:36.7"
dep_event = 10
event_id = "C202412271247A"

lat_georg = 50.728310
lon_georg = 7.089011

synx = client.get_waveforms(model=syn_model,
                            receiverlatitude=lat_georg,
                            receiverlongitude=lat_georg,
                            networkcode="XX",
                            stationcode="GEORG",
                            locationcode=None,
                            eventid=f"GCMT:{event_id}",
                            sourcelatitude=lat_event,
                            sourcelongitude=lon_event,
                            sourcedepthinmeters=dep_event*1000,
                            origintime=time_event,
                            starttime=None,
                            endtime=None,
                            dt=1/20,
                           )

# %%
synx.plot();

# %%
st.plot();

# %%
import obspy as obs

# %%
st_ring = obs.read("/import/kilauea-data/GEORG/data/2024/XX/GEORG/BJZ.D/"+"XX.GEORG.10.BJZ.D.2024.362")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 st_ring = obs.read("/import/kilauea-data/GEORG/data/2024/XX/GEORG/BJZ.D/"+"XX.GEORG.10.BJZ.D.2024.362")
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/core/util/decorator.py:297, in map_example_filename.<locals>._map_example_filename(func, *args, **kwargs)
#     295                 except IOError:
#     296                     pass
# --> 297 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/core/stream.py:208, in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#     206     st = _create_example_stream(headonly=headonly)
#     207 else:
# --> 208     st = _generic_reader(pathname_or_url, _read, **kwargs)
#     210 if len(st) == 0:
#     211     # try to give more specific information why the stream is empty
#     212     if has_magic(pathname_or_url) and not glob(pathname_or_url):
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/core/util/base.py:656, in _generic_reader(pathname_or_url, callback_func, **kwargs)
#     654         raise Exception("No file matching file pattern: %s" % pathname)
#     655     elif not glob.has_magic(pathname) and not Path(pathname).is_file():
# --> 656         raise IOError(2, "No such file or directory", pathname)
#     658 generic = callback_func(pathnames[0], **kwargs)
#     659 if len(pathnames) > 1:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/import/kilauea-data/GEORG/data/2024/XX/GEORG/BJZ.D/XX.GEORG.10.BJZ.D.2024.362'

# %%
st_ring = st_ring.detrend("demean")
st_ring = st_ring.taper(0.05)
st_ring = st_ring.filter("bandpass", freqmin=0.1, freqmax=0.5, corners=4, zerophase=True)

# %%
# %matplotlib tk

st_ring.plot()

# %%
st_ring = obs.read("/import/kilauea-data/GEORG/data/2024/XX/GEORG/FJZ.D/XX.GEORG..FJZ.D.2024.361")

# %%
st_ring.plot()

# %%
import obspy as obs

st_ring = obs.read("/home/andbro/kilauea-data/GEORG/data/2024/XX/GEORG/BJZ.D/XX.GEORG.10.BJZ.D.2024.361")

# %%
st_ring.plot();
