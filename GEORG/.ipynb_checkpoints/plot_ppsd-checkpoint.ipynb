# %% [markdown]
# ## Georg Seismic Experiment

# %% [markdown]
# Explore seismic signals at Bonn

# %% [markdown]
# ## Imports

# %%
import os
import gc
import matplotlib.pyplot as plt
import numpy as np
import obspy as obs
import pandas as pd

from obspy.signal import PPSD

from andbro__read_sds import __read_sds
from andbro__compare_psd_stream import __compare_psd_stream

# %% [markdown]
# ## Configurations

# %%
config = {}

config['workdir'] = "/home/andbro/"
# config['workdir'] = "/import/"

config['path_to_inv'] = config['workdir']+"kilauea-data/GEORG/stationxml/"

config['path_to_data'] = config['workdir']+"kilauea-data/GEORG/data/"

config['path_to_figs'] = config['workdir']+"kilauea-data/GEORG/figures/"

# test day
config['tbeg'] = obs.UTCDateTime("2024-12-16 22:00")
config['tend'] = obs.UTCDateTime("2024-12-17 02:00")

# quiet day
config['tbeg'] = obs.UTCDateTime("2024-12-25 00:00")
config['tend'] = obs.UTCDateTime("2024-12-26 00:00")

# %% [markdown]
# ### Seismometer Data

# %%
st_seis = __read_sds(config['path_to_data'], "XN.BONN..BH*", config['tbeg'], config['tend'])

inv_seis = obs.read_inventory(config['path_to_inv']+'station_XN_BONN_centaur.xml')

print(st_seis)
# Out:
# 3 Trace(s) in Stream:
# XN.BONN..BHE | 2024-12-25T00:00:00.000000Z - 2024-12-26T00:00:00.000000Z | 40.0 Hz, 3456001 samples
# XN.BONN..BHN | 2024-12-25T00:00:00.000000Z - 2024-12-26T00:00:00.000000Z | 40.0 Hz, 3456001 samples
# XN.BONN..BHZ | 2024-12-25T00:00:00.000000Z - 2024-12-26T00:00:00.000000Z | 40.0 Hz, 3456001 samples

# %%
for tr in st_seis:
    ppsd = obs.signal.PPSD(tr.stats, metadata=inv_seis, skip_on_gaps=True)
    ppsd.add(tr)
    ppsd.plot()
    ppsd.plot(filename=config['path_to_figs']+f"ppsd_{tr.get_id()}.png")

# %% [markdown]
# ### Tiltmeter Data

# %%
# head = ["time", "north", "east", "X1", "X2", "pressure", "X3", "X4", "X5", "X6"]

# tilt = pd.read_csv(config['path_to_data']+"LGMBoxmessung12_16.csv", delimiter=";", names=head)

# starttime = obs.UTCDateTime(tilt.time[0])
# print(starttime)

# mean_dt = tilt.time.diff().mean()
# print(mean_dt)
# Out:
# 2024-12-16T16:36:15.716615Z
# 1.0550388852159318

# %%
# plt.plot(tilt.time.diff())

# %%
st_tilt = __read_sds(config['path_to_data'], "XX.TILT..LA*", config['tbeg'], config['tend'])

inv_tilt = obs.read_inventory(config['path_to_inv']+'station_XX_TILT.xml')

print(st_tilt)
# Out:
# 2 Trace(s) in Stream:
# XX.TILT..LAE | 2024-12-25T00:00:00.567492Z - 2024-12-30T23:59:59.890132Z | 0.9 Hz, 491356 samples
# XX.TILT..LAN | 2024-12-25T00:00:00.567492Z - 2024-12-30T23:59:59.890132Z | 0.9 Hz, 491356 samples

# %%
for tr in st_tilt:
    tr.data *= 9.81
    tr.detrend("linear")

# %%
for tr in st_tilt:
    ppsd = obs.signal.PPSD(tr.stats, metadata=inv_tilt, skip_on_gaps=True)
    ppsd.add(tr)
    ppsd.plot()
    # ppsd.plot(filename=config['path_to_figs']+f"ppsd_{tr.get_id()}.png")
# Out:
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T03:30:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T04:30:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T05:30:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T08:30:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T09:30:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T10:30:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T14:00:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T15:00:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T16:00:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T19:00:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T20:00:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/spectral_estimation.py:892: UserWarning: Already covered time spans detected (e.g. 2024-12-25T21:00:00.567492Z), skipping these slices.
#   warnings.warn(msg)
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/core/inventory/response.py:1205: UserWarning: The unit 'RAD/S' is not known to ObsPy. It will be passed in to evalresp as 'undefined'. This should result in evalresp using the response as is, without adding any integration or differentiation and the 'output' parameter (here: 'VEL') not having any effect. Please double check output data.
#   warnings.warn(msg)

# %%
st_tilt0 = __read_sds(config['path_to_data'], "XX.TILT..LA*", config['tbeg']-5*86400, config['tend']+10*86400)

# %%
st_tilt = st_tilt0.copy()

st_tilt = st_tilt.detrend("simple")

st_tilt = st_tilt.taper(0.05)

st_tilt = st_tilt.filter("lowpass", freq=1/(10*3600), corners=4, zerophase=True)
st_tilt = st_tilt.filter("highpass", freq=1/(26*3600), corners=4, zerophase=True)

st_tilt.plot();

# %% [markdown]
# ### RaspShake Data

# %%
st_rasp = __read_sds(config['path_to_data'], "AM.RACB0.00.EH*", config['tbeg'], config['tend'])

inv_rasp = obs.read_inventory(config['path_to_inv']+"station_AM_RACB0.xml")

# %%
st_rasp
# Out:
# 3 Trace(s) in Stream:
# AM.RACB0.00.EHE | 2024-12-24T23:59:59.997000Z - 2024-12-25T23:59:59.997000Z | 100.0 Hz, 8640001 samples
# AM.RACB0.00.EHN | 2024-12-24T23:59:59.997000Z - 2024-12-25T23:59:59.997000Z | 100.0 Hz, 8640001 samples
# AM.RACB0.00.EHZ | 2024-12-24T23:59:59.997000Z - 2024-12-25T23:59:59.997000Z | 100.0 Hz, 8640001 samples

# %%
for tr in st_rasp:
    ppsd = obs.signal.PPSD(tr.stats, metadata=inv_rasp)
    ppsd.add(tr)
    ppsd.plot()
    ppsd.plot(filename=config['path_to_figs']+f"ppsd_{tr.get_id()}.png")

# %% [markdown]
# ## Plot Spectra

# %%
st_fur = __read_sds("/bay200/mseed_online/archive/", "GR.FUR..BHZ", config['tbeg'], config['tend'])

inv_fur = obs.read_inventory(config['workdir']+"/kilauea-data/stationxml_ringlaser/station_GR_FUR.xml")
# Out:
#  -> /bay200/mseed_online/archive/ does not exist!

# %%
st0 = obs.Stream()

st0 += st_seis.copy().remove_response(inv_seis, output="ACC")
# st0 += st_tilt.copy()
st0 += st_rasp.copy().remove_response(inv_rasp, output="ACC")

try:
    st0 += st_fur.copy().remove_response(inv_fur, output="ACC")
except:
    pass

# %%
st2 = st0.copy()

st2 = st2.detrend("demean")

st2 = st2.taper(0.01)

# st2 = st2.resample(1.0, no_filter=False)

fxx, pxx = __compare_psd_stream(st2, twin_sec=7200, psd="welch", plot=False)

# fxx, pxx = __compare_psd_stream(st2, n_win=10, time_bandwidth=3.5, psd="multitaper", plot=False)

fxx2, pxx2 = __compare_psd_stream(st2, twin_sec=300, psd="welch", plot=False)

# %% [markdown]
# ## Plotting

# %%
def makeplot():

    Nrow, Ncol = 1, 1

    font = 12

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

    for tr in st2:

        ax.plot(fxx[tr.get_id()], 10*np.log10(pxx[tr.get_id()]), label=tr.get_id())

    try:
        ax.plot(1/models['model_periods'], models['low_noise'], color="k", ls="--")
        ax.plot(1/models['model_periods'], models['high_noise'], color="k", ls="--")
    except:
        pass

    ax.set_xscale("log")
    # ax.set_yscale("log")

    ax.set_ylim(-200, -80)

    ax.grid(which="both", ls=":", zorder=0)
    ax.legend(loc=4)

    fmax = 0.5/tr.stats.delta

    if fmax < 10:
        ax.set_xlim(1/3600, fmax)
    else:
        ax.set_xlim(1/3600, 10)

    ax.set_xlabel(r"Frequency (Hz)", fontsize=font)
    ax.set_ylabel(r"PSD (dB rel. to 1 m$^2$ / s$^4$ / Hz)", fontsize=font)

    ax.set_title(f"{config['tbeg'].date} {config['tbeg'].time} - {config['tend'].date} {config['tend'].time} UTC")

    plt.show();
    return fig

models = np.load(config['workdir']+"kilauea-data/GEORG/data/"+"noise_models.npz")

fig = makeplot()

fig.savefig(config['path_to_figs']+"PSDs.png", format="png", dpi=150, bbox_inches='tight')

# %%
def makeplot2():

    Nrow, Ncol = 1, 1

    font = 12

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

    for tr in st2:

        if "AM" in tr.get_id():
            alpha = 0.25
        else:
            alpha = 1

        N = 1200
        p = ax.plot(fxx[tr.get_id()][:N],
                    10*np.log10(pxx[tr.get_id()])[:N],
                    alpha=alpha,
                   )


        N = 50
        ax.plot(fxx2[tr.get_id()][N:],
                10*np.log10(pxx2[tr.get_id()])[N:],
                label=tr.get_id(),
                color=p[0].get_color(),
               )
    try:
        ax.plot(1/models['model_periods'], models['low_noise'], color="k", ls="--")
        ax.plot(1/models['model_periods'], models['high_noise'], color="k", ls="--")
    except:
        pass

    ax.set_xscale("log")
    # ax.set_yscale("log")

    ax.set_ylim(-200, -80)

    ax.grid(which="both", ls=":", zorder=0)
    ax.legend(loc=4)

    fmax = 0.5/tr.stats.delta

    if fmax < 10:
        ax.set_xlim(1/3600, fmax)
    else:
        ax.set_xlim(1/3600, 10)

    ax.set_xlabel(r"Frequency (Hz)", fontsize=font)
    ax.set_ylabel(r"PSD (dB rel. to 1 m$^2$ / s$^4$ / Hz)", fontsize=font)

    ax.set_title(f"{config['tbeg'].date} {config['tbeg'].time} - {config['tend'].date} {config['tend'].time} UTC")

    plt.show();
    return fig

fig = makeplot2()

fig.savefig(config['path_to_figs']+"PSDs_split.png", format="png", dpi=150, bbox_inches='tight')

# %% [markdown]
# ## Ringlaser Data

# %%
st_georg = obs.read(config['workdir']+"kilauea-data/GEORG/data/2024/XX/GEORG/BJZ.D/XX.GEORG.10.BJZ.D.2024.361")

inv_georg = obs.read_inventory(config['workdir']+"kilauea-data/GEORG/stationxml/station_XX_GEORG.xml")

# st_georg.remove_sensitivity(inv_georg)

st_georg.trim(obs.UTCDateTime("2024-12-26 19:10"), obs.UTCDateTime("2024-12-26 20:20"))
# Out:
# 1 Trace(s) in Stream:
# XX.GEORG.10.BJZ | 2024-12-26T19:10:00.000000Z - 2024-12-26T20:20:00.000000Z | 20.0 Hz, 84001 samples

# %%
for tr in st_georg:
    ppsd = obs.signal.PPSD(tr.stats, metadata=inv_georg)
    ppsd.add(tr)
    ppsd.plot()
    # ppsd.plot(filename=config['path_to_figs']+f"ppsd_{tr.get_id()}.png")
# Out:
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/core/inventory/response.py:1205: UserWarning: The unit 'RAD/S' is not known to ObsPy. It will be passed in to evalresp as 'undefined'. This should result in evalresp using the response as is, without adding any integration or differentiation and the 'output' parameter (here: 'VEL') not having any effect. Please double check output data.
#   warnings.warn(msg)

# %%
# %matplotlib tk

# %%
plt.plot(st_georg[0].data)

# %%
st_rlas = obs.read(config['workdir']+"kilauea-data/GEORG/data/2024/BW/RLAS/BJZ.D/BW.RLAS..BJZ.D.2024.361")

inv_rlas = obs.read_inventory(config['workdir']+"kilauea-data/GEORG/stationxml/station_BW_RLAS.xml")

st_rlas.remove_sensitivity(inv_rlas)
# Out:
# 1 Trace(s) in Stream:
# BW.RLAS..BJZ | 2024-12-26T00:00:02.331749Z - 2024-12-27T00:00:04.581749Z | 20.0 Hz, 1728046 samples

# %%
st_ring = st_georg.copy()
st_ring += st_rlas.copy()

# %%
st_ring = st_ring.detrend("demean")

st_ring = st_ring.taper(0.01)

fxx_ring, pxx_ring = __compare_psd_stream(st_ring, twin_sec=3600, psd="welch", plot=False)

# %%
models2 = pd.read_csv(config['workdir']+"kilauea-data/GEORG/data/"+"RLNM_model_data.csv")

# %%
def makeplot_ring():

    Nrow, Ncol = 1, 1

    font = 12

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))

#     ax.plot(fxx_ring['XX.GEORG.10.BJZ'], 10*np.log10(pxx_ring['XX.GEORG.10.BJZ']), label='XX.GEORG.10.BJZ')
#     ax.plot(fxx_ring['BW.RLAS..BJZ'], 10*np.log10(pxx_ring['BW.RLAS..BJZ']), label='BW.RLAS..BJZ')

    ax.plot(models2['frequency'], 10*np.log10(models2['rlnm_rot_rate']), color="k", ls="--")
    ax.plot(models2['frequency'], 10*np.log10(models2['rhnm_rot_rate']), color="k", ls="--")

    for tr in st_ring:

        ax.plot(fxx_ring[tr.get_id()], 10*np.log10(pxx_ring[tr.get_id()]), label=tr.get_id())

    ax.set_xscale("log")
    # ax.set_yscale("log")

    ax.set_ylim(-270, -140)

    ax.grid(which="both", ls=":", zorder=0)
    ax.legend(loc=4)

    fmax = 0.5/tr.stats.delta

    if fmax < 10:
        ax.set_xlim(1/3600, fmax)
    else:
        ax.set_xlim(1/3600, 10)

    ax.set_xlabel(r"Frequency (Hz)", fontsize=font)
    ax.set_ylabel(r"PSD (dB rel. to 1 rad$^2$ / s$^2$ / Hz)", fontsize=font)

    ax.set_title(f"{config['tbeg'].date} {config['tbeg'].time} - {config['tend'].date} {config['tend'].time} UTC")

    plt.show();
    return fig

fig = makeplot_ring()

fig.savefig(config['path_to_figs']+"PSDs_rings.png", format="png", dpi=150, bbox_inches='tight')

# %%
# from obspy.clients.filesystem.tsindex import Client
# from obspy.clients.filesystem.tests.test_tsindex import get_test_data_filepath
# from obspy.clients.filesystem.tsindex import Indexer
# import os

# # for this example get the file path to test data

# filepath = config['workdir']+"kilauea-data/GEORG/data/2024/XX/GEORG/FJZ.D/"

# db_path = os.path.join(filepath, 'timeseries.sqlite')

# # create a new Client instance
# client = Client(db_path, datapath_replace=("^", filepath))

# # create a new Indexer instance
# indexer = Indexer(filepath, filename_pattern='*')

# # indexer.run()

# # event_data = client.get_waveforms("*", "*", "*", "FJZ", t1, t1 + 120)

# %%
# from obspy.clients.filesystem.tsindex import Client
# from obspy import UTCDateTime

# client = Client('bigdata.sqlite')
# start = UTCDateTime ('2010-6-1T00:00:00')
# event_data = client.get_waveforms("*", "*", "*", "BHZ", start, start + 120)
# event_data.plot()

# %%
# import obspy
# import io


# chunksize = 100000 * 512 # Around 50 MB

# file = config['workdir']+"kilauea-data/GEORG/data/2024/XX/GEORG/FJZ.D/XX.GEORG..FJZ.D.2024.361"

# t1 = obspy.UTCDateTime("2024-12-26 00:00")
# t2 = obspy.UTCDateTime("2024-12-26 01:00")

# st0 = obspy.Stream()

# with io.open(file, "rb") as fh:
#     while True:
#         with io.BytesIO() as buf:
#             c = fh.read(chunksize)
#             if not c:
#                 break
#             buf.write(c)
#             buf.seek(0, 0)
#             st = obs.read(buf,
#                           headeronly=True,
#                          )
#             st = st.trim(t1, t2, nearest_sample=True)

#         if len(st) != 0:
#             st0 += st.copy()
#             st0.sort()
#         N = len(st0)
#         print(st0)
#         if N != 0 and st0[N-1].stats.endtime >= t2:
#             break

# st0.merge(fill_value=0)

# %%
file = config['workdir']+"kilauea-data/GEORG/data/2024/XX/GEORG/FJZ.D/XX.GEORG..FJZ.D.2024.361"
stx = obs.read(file,
               starttime="2024-12-26 00:00",
               endtime="2024-12-26 01:00",
               headonly=True
              )

# %%
stx = __read_sds(config['workdir']+"kilauea-data/GEORG/data/", "XX.GEORG..FJZ", "2024-12-26 00:00", "2024-12-26 00:30")

# %%
stx.plot();

# %%
plt.plot(stx[0].data[:300])

# %%
6_319_100_000_000
# Out:
# 6319100000000

# %%
4*16/16/632.8e-9
