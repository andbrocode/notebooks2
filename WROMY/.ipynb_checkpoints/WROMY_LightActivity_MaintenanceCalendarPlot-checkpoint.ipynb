# %% [markdown]
# # Generate Log for Maintenance Activitiy based on WROMY LightSensors

# %% [markdown]
# Use the light sensors of WROMY to identify maintenance activity and plot them as calendar plots

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import calplot

from pathlib import Path

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
    bay_path = '/home/andbro/bay200/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/bay200/'
elif os.uname().nodename == 'lin-ffb-01':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/bay200/'

# %% [markdown]
# ### Configurations

# %%
config = {}

config['threshold'] = 5 ## light threshold to classify as <light on> / <light off>

config['path_to_LX_data'] = archive_path+"romy_archive/"

config['start_date'] = '01/01/2021' ## MM/DD/YYYY
config['end_date']   = '12/31/2021' ## MM/DD/YYYY

config['year'] = config['start_date'][-4:]

config['path_to_outdata'] = archive_path+f"wromy_files/{config['year']}_maintenance_lx_sensors.csv"

config['path_to_figs'] = archive_path+f"romy_plots/{config['year']}/logs/"

# %%
def __update_maintenance_protocoll(config):

    ## make new output file with header
    with open(config['path_to_outdata'], mode="w") as f:
        f.write("Sensor,Timestamp,Date,Time,State\n")

    ## iterate for dates
    for date in pd.date_range(start=config['start_date'], end=config['end_date']):

        fdate = str(date)[:10].replace("-", "")

        ## interate for all sensors of WROMY
        for sensor in [1,4,5,6,7,8,9]:

            filename = f'WS{sensor}_{fdate}.txt'
            datapath = f'/import/freenas-ffb-01-data/romy_archive/{date.year}/BW/WROMY/LX{sensor}.D/'

            ## read file
            if Path(datapath+filename).exists():
                df = pd.read_csv(datapath+filename, names=['Date', 'Time', 'State'])
            else:
                print(f" -> {datapath+filename} does not exists!")
                continue

            ## smooth the light sensor data
            df['smoothed'] = df['State'].rolling(10, center=True).mean()

            ## apply threshold
            df['smoothed'] = df['smoothed'].where(df.smoothed > config['threshold']).fillna(0)
            df['smoothed'] = df['smoothed'].clip(lower=None, upper=config['threshold'])

            ## calculate differences for picking
            df['State'] = df.smoothed.diff()/config['threshold']

            ## get start and end points of light period
            select = df.where(abs(df.State) > 0).dropna()

            ## modify data
            select.drop(columns=["smoothed"], inplace=True)
            select = select.astype(int)
            select['State'] = select['State'].replace(-1, 0)

            ## format and write to output file
            with open(config['path_to_outdata'], mode="a") as f:
                for idx, row in select.iterrows():
                    dd = str(row.Date)
                    tt = str(row.Time).zfill(6)
                    ts = f"{dd[:4]}-{dd[4:6]}-{dd[6:8]}T{tt[:2]}:{tt[2:4]}:{tt[4:6]}"
                    f.write(f"WS{sensor},{ts},{row.Date},{row.Time},{row.State}\n");

# %%
__update_maintenance_protocoll(config)
# Out:
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210101.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210102.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210103.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210104.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210105.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210106.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX8.D/WS8_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX9.D/WS9_20210107.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX1.D/WS1_20210108.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX4.D/WS4_20210108.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX5.D/WS5_20210108.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX6.D/WS6_20210108.txt does not exists!
#  -> /import/freenas-ffb-01-data/romy_archive/2021/BW/WROMY/LX7.D/WS7_20
bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pl1 = calplot.calplot(data = df_compressed['sensor_count'],
#       2                       how = 'sum',
#       3                       cmap = plt.get_cmap('viridis', 7),
#       4                       colorbar = True,
#       5                       suptitle = "Count of triggered light sensors per day",
#       6                       yearlabel_kws={'fontname':'sans-serif'},
#       7                       vmin=0, vmax=7,
#       8                      )
#      10 pl1[0].savefig(config['path_to_figs']+f"{config['year']}_LX_maintenance_overview.png", format="png", dpi=150, bbox_inches='tight')
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/calplot/calplot.py:313, in calplot(data, how, yearlabels, yearascending, yearlabel_kws, subplot_kws, gridspec_kws, figsize, fig_kws, colorbar, suptitle, suptitle_kws, tight_layout, **kwargs)
#     310 if figsize is None:
#     311     figsize = (10+(colorbar*2.5), 1.7*len(years))
# --> 313 fig, axes = plt.subplots(nrows=len(years), ncols=1, squeeze=False,
#     314                          figsize=figsize,
#     315                          subplot_kw=subplot_kws,
#     316                          gridspec_kw=gridspec_kws, **fig_kws)
#     317 axes = axes.T[0]
#     319 # We explicitely resample by day only once. This is an optimization.
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/matplotlib/pyplot.py:1502, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1358 """
#    1359 Create a figure and a set of subplots.
#    1360
#    (...)
#    1499
#    1500 """
#    1501 fig = figure(**fig_kw)
# -> 1502 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1503                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1504                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1505                    width_ratios=width_ratios)
#    1506 return fig, axs
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/matplotlib/figure.py:916, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     912         raise ValueError("'width_ratios' must not be defined both as "
#     913                          "parameter and as key in 'gridspec_kw'")
#     914     gridspec_kw['width_ratios'] = width_ratios
# --> 916 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     917 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     918                   subplot_kw=subplot_kw)
#     919 return axs
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/matplotlib/figure.py:1544, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1505 """
#    1506 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1507 complex layout of Axes in the figure.
#    (...)
#    1540
#    1541 """
#    1543 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1544 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1545 return gs
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/matplotlib/gridspec.py:379, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     376 self.hspace = hspace
#     377 self.figure = figure
# --> 379 super().__init__(nrows, ncols,
#     380                  width_ratios=width_ratios,
#     381                  height_ratios=height_ratios)
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/matplotlib/gridspec.py:49, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      34 """
#      35 Parameters
#      36 ----------
#    (...)
#      46     If not given, all rows will have the same height.
#      47 """
#      48 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 49     raise ValueError(
#      50         f"Number of rows must be a positive integer, not {nrows!r}")
#      51 if not isinstance(ncols, Integral) or ncols <= 0:
#      52     raise ValueError(
#      53         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 0
