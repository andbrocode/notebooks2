# %% [markdown]
# ## Make Allan Deviation Plot

# %%
import obspy as obs
import matplotlib.pyplot as plt
import numpy as np
import allantools

from andbro__querrySeismoData import __querrySeismoData

# %% [markdown]
# ## Configurations

# %%
## Configurations

config = {}

config['tbeg'] = obs.UTCDateTime("2023-01-20 00:00")
config['tend'] = config['tbeg']+ 86400

# config['seed'] = "BW.DROMY..FJZ"
config['seed'] = "BW.ROMY.10.BJZ"

config['repository'] = "george"

# config['outpath'] = f''
# config['outfile'] = f''
# config['outfigs'] = f''

config['net'], config['sta'], config['loc'], config['cha'] = config['seed'].split(".")

## ALLAN
config['errorbars'] = False
config['relative'] = False

# %% [markdown]
# ## Load Data

# %%
st, inv = __querrySeismoData(    
                            seed_id=config['seed'],
                            starttime=config['tbeg']-10,
                            endtime=config['tend']+10,
                            repository=config['repository'],
                            path=None,
                            restitute=False,
                            detail=None,
                            fill_value=None,
)
# Out:
# /home/andbro/anaconda3/envs/obs/lib/python3.7/site-packages/obspy/io/stationxml/core.py:98: UserWarning: The StationXML file has version 1.2, ObsPy can read versions (1.0, 1.1). Proceed with caution.
#   version, ", ".join(READABLE_VERSIONS)))

# %%
st.detrend("demean")

st.remove_sensitivity(inv)

st.trim(config['tbeg'], config['tend'])
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY.10.BJZ | 2023-01-19T23:59:59.990199Z - 2023-01-20T23:59:59.990199Z | 20.0 Hz, 1728001 samples

# %%
st.plot();

# %% [markdown]
# ## Compute Allan Dev

# %%
def __compute_allan_deviations(config, st):
    
    
    ## sampling rate
    df = st[0].stats.sampling_rate
    
    ## looping hourly
    t1, t2 = config['tbeg'], config['tbeg']+3600
    
    allans,traces = [], []
    for nn in range(24):
        
        print(str(nn).rjust(2,"0"),": ", t1, t2)
        tmp = st.copy().trim(t1, t2)
        traces.append(tmp[0].data)
        
        ## normal allan deviation
        ## allan = (taus1, adevs1, errors, ns) 
        allan = allantools.adev(tmp[0].data, 
                                data_type='freq', 
                                rate=df, 
                                taus='all', ## all, octave, decade
                                )
        allans.append(allan)
        t1 += 3600
        t2 += 3600
        
    return allans, traces

allan, traces = __compute_allan_deviations(config, st)
# Out:
# 00 :  2023-01-20T00:00:00.000000Z 2023-01-20T01:00:00.000000Z
# 01 :  2023-01-20T01:00:00.000000Z 2023-01-20T02:00:00.000000Z
# 02 :  2023-01-20T02:00:00.000000Z 2023-01-20T03:00:00.000000Z
# 03 :  2023-01-20T03:00:00.000000Z 2023-01-20T04:00:00.000000Z
# 04 :  2023-01-20T04:00:00.000000Z 2023-01-20T05:00:00.000000Z
# 05 :  2023-01-20T05:00:00.000000Z 2023-01-20T06:00:00.000000Z
# 06 :  2023-01-20T06:00:00.000000Z 2023-01-20T07:00:00.000000Z
# 07 :  2023-01-20T07:00:00.000000Z 2023-01-20T08:00:00.000000Z
# 08 :  2023-01-20T08:00:00.000000Z 2023-01-20T09:00:00.000000Z
# 09 :  2023-01-20T09:00:00.000000Z 2023-01-20T10:00:00.000000Z
# 10 :  2023-01-20T10:00:00.000000Z 2023-01-20T11:00:00.000000Z
# 11 :  2023-01-20T11:00:00.000000Z 2023-01-20T12:00:00.000000Z
# 12 :  2023-01-20T12:00:00.000000Z 2023-01-20T13:00:00.000000Z
# 13 :  2023-01-20T13:00:00.000000Z 2023-01-20T14:00:00.000000Z
# 14 :  2023-01-20T14:00:00.000000Z 2023-01-20T15:00:00.000000Z
# 15 :  2023-01-20T15:00:00.000000Z 2023-01-20T16:00:00.000000Z
# 16 :  2023-01-20T16:00:00.000000Z 2023-01-20T17:00:00.000000Z
# 17 :  2023-01-20T17:00:00.000000Z 2023-01-20T18:00:00.000000Z
# 18 :  2023-01-20T18:00:00.000000Z 2023-01-20T19:00:00.000000Z
# 19 :  2023-01-20T19:00:00.000000Z 2023-01-20T20:00:00.000000Z
# 20 :  2023-01-20T20:00:00.000000Z 2023-01-20T21:00:00.000000Z
# 21 :  2023-01-20T21:00:00.000000Z 2023-01-20T22:00:00.000000Z
# 22 :  2023-01-20T22:00:00.000000Z 2023-01-20T23:00:00.000000Z
# 23 :  2023-01-20T23:00:00.000000Z 2023-01-21T00:00:00.000000Z

# %% [markdown]
# ## Plotting

# %%
def __makeplot_allan_deviation_overview(config, st, allan, traces):

    from numpy import shape, linspace
    
    taus, adev, errors, ns = allan[0], allan[1], allan[2], allan[3]

    day = st[0].stats.starttime.date
    tt1 = str(st[0].stats.starttime.time)[:8]
    tt2 = str(st[0].stats.endtime.time)[:8]  
    
    if config['relative']:
        adev = adev / 7.3e-5
        
    ## -------------------------------------------
    fig, ax = plt.subplots(1,2, figsize=(18,6))

    plt.subplots_adjust(wspace=0.15)
    
    font = 14

    cols = plt.cm.viridis(linspace(0,1,24+1))
    cols = plt.cm.rainbow(linspace(0,1,24+1))
    
    ## ___________________________________
    ## PLOT 1
    
    for n, al in enumerate(allan):
        taus, adev, errors, ns = al[0], al[1], al[2], al[3]

        ax[0].plot(taus, adev, color=cols[n], label=f"{config['sta']}.{config['cha']}")
        
        
    if config['relative']:
        ax[0].set_ylabel(r"Allan Deviation  $\Omega$/$\Omega_E$", fontsize=font)
    else:
        ax[0].set_ylabel(r"Allan Deviation $\sigma_{\tau}$ [rad/s]", fontsize=font)

    ax[0].set_xlabel(r"$\tau$ [s]", fontsize=font)
    
    ax[0].set_xscale('log')
    ax[0].set_yscale('log')

    ax[0].grid(True, which="both", ls="--")

    ax[0].tick_params(labelsize=font-1)
    
#     ax[0].set_title(f"Allan Deviation for {config['net']}.{config['cha']} on {day}  [{tt1}-{tt2}]", fontsize=font+3)

    
    ## ___________________________________
    ## PLOT 2
    
    norm_st_max = max(st[0].data)
    timeaxis = linspace(0, 60, len(traces[0]))
    
    for m, tr in enumerate(traces):
        
        norm_tr_max = max(tr)
        
        ax[1].plot(timeaxis, tr/norm_st_max + m, color=cols[m])
    
    ax[1].set_yticks(linspace(0,23,24))
    ax[1].set_yticklabels([str(int(tt)).rjust(2,"0")+":00" for tt in linspace(0,23,24)])
    
    ax[1].set_ylim(-1, 24)
    
    ax[1].set_xlabel("Time [min]", fontsize=font)
    
    ax[1].tick_params(labelsize=font-1)

    plt.show();
    
__makeplot_allan_deviation_overview(config, st, allan, traces)
