# %% [markdown]
# ## Sagnac Frequency - Backscatter Correction - Compare Settings

# %% [markdown]
# ## Imports

# %%
import os
import gc
import matplotlib.pyplot as plt
import numpy as np

# from datetime import datetime, date
# from pandas import DataFrame, read_pickle, date_range, concat, read_csv
from obspy import UTCDateTime, read, Trace, Stream, read_inventory
# from scipy.signal import hilbert
# from scipy.ndimage import gaussian_filter1d

import sys; sys.path.append("../")

from functions.get_fft import __get_fft
from functions.multitaper_psd import __multitaper_psd
from functions.welch_psd import __welch_psd
from functions.trim_stream import __trim_stream
from functions.read_sds import __read_sds

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
    bay_path = '/home/andbro/ontap-ffb-bay200/'
    lamont_path = '/home/andbro/lamont/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/import/ontap-ffb-bay200/'
    lamont_path = '/lamont/'
elif os.uname().nodename in ['lin-ffb-01', 'ambrym', 'hochfelln']:
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/import/ontap-ffb-bay200/'
    lamont_path = '/lamont/'

# %%
def __makeplot_spectra(st01, st02, db=True):

    from numpy import log10
    import numpy as np

    arr1 = st01[0].data
    arr2 = st02[0].data

    f1, s1, p1 = __get_fft(arr1, st1[0].stats.delta, window="hann")
    f2, s2, p2 = __get_fft(arr2, st2[0].stats.delta, window="hann")

    if db:
        s1 = 20*log10(s1)
        s2 = 20*log10(s2)

    font = 12

    fig, ax = plt.subplots(1, 1, figsize=(12, 5))

    cols = ["tab:blue", "tab:red", "tab:orange", "tab:green", "darkblue"]

    ax.plot(f1, s1, color="tab:orange", label=st01[0].get_id(), alpha=0.8)

    ax.plot(f2, s2, color="tab:green", label=st02[0].get_id(), alpha=0.8, ls="-")

    ax2 = ax.twinx()

    ax2.fill_between(f2, 0, abs(s2-s1),
                     color="gray", alpha=0.4
                    )

    ax2.set_ylim(0, 60)
    ax2.set_ylabel(r"|PSD$_{1}$ - PSD$_{2}$| (dB wrt. 1 rad/s/$\sqrt{Hz}$)", fontsize=font)

    ax.set_xlabel("Frequenc (Hz)", fontsize=font)
    ax.set_ylabel(r"PSD (dB wrt. 1 rad/s/$\sqrt{Hz}$)", fontsize=font)

    # ax.vyscale("log")
    ax.set_xscale("log")

    ax.set_title(f"{str(config['tbeg'])[:19].replace('T',' ')} - {str(config['tend'])[:19].replace('T',' ')}")

    ax.grid(ls="--", color="gray", alpha=0.4, which="both")

    ax.set_ylim(-300, -150)
    ax.set_xlim(1e-3, 5e0)

    ax.legend(ncol=2)

    axy = np.linspace(ax.get_yticks()[0], ax.get_yticks()[-1], len(ax.get_yticks()))
    ax2y = np.linspace(ax2.get_yticks()[0], ax2.get_yticks()[-1], len(ax.get_yticks()))
    ax2.set_yticks(ax2y)

    plt.show();
    return fig

# %%
def __makeplot_spectra_all(st0):

    spec = {}
    freq = {}

    for tr in st0:

        loc = tr.get_id()
        freq[loc], spec[loc], _ = __get_fft(tr.data, tr.stats.delta, window="hann")

    fig, ax = plt.subplots(1, 1, figsize=(15, 5))

    font = 12

    for k in spec.keys():

        plt.plot(freq[k], 20*np.log10(spec[k]), label=k)

    plt.xscale("log")
    # plt.yscale("log")

    plt.legend()

    plt.grid(which="both", ls="--")

    plt.xlabel(r"Frequency (Hz)", fontsize=font)
    plt.ylabel(r"Spectrum (dB wrt. 1 rad/s/$\sqrt{Hz}$)", fontsize=font)

    plt.show();
    return fig

# %%
def __makeplot_coherence(st01, st02):

    import numpy as np
    from numpy import log10
    from functions.multitaper_coherence import __multitaper_coherence

    arr1 = st01[0].data
    arr2 = st02[0].data

    id1 = st01[0].get_id()
    id2 = st02[0].get_id()

    dt = st1[0].stats.delta

    out = __multitaper_coherence(arr1, arr2, dt, n_taper=10)

    font = 12

    fig, ax = plt.subplots(1, 1, figsize=(12, 5))

    ax.plot(out['fcoh'], out['coh'], color="k", label=f"{id1} - {id2}")

    ax.set_xlabel("Frequenc (Hz)", fontsize=font)
    ax.set_ylabel(r" Coherency", fontsize=font)

    # ax.vyscale("log")
    ax.set_xscale("log")

    ax.set_title(f"{str(config['tbeg'])[:19].replace('T',' ')} - {str(config['tend'])[:19].replace('T',' ')}")

    ax.grid(ls="--", color="gray", alpha=0.4, which="both")

    ax.set_xlim(1e-3, 5e0)
    ax.set_ylim(0, 1.05)

    ax.legend(ncol=2)

    plt.show();
    return fig

# %%
# %matplotlib inline

# %% [markdown]
# ## Configurations

# %%
config = {}

config['ring'] = "Z"

# config['delta'] = 120

# small event
# config['tbeg'] = UTCDateTime("2024-10-23 15:00")
# config['tend'] = UTCDateTime("2024-10-23 16:00")

# morocco event
config['tbeg'] = UTCDateTime("2023-09-08 22:00")
config['tend'] = UTCDateTime("2023-09-09 00:00")-0.1

# path to Sagnac data
config['path_to_data1'] = archive_path+"romy_archive/"
config['path_to_data2'] = data_path+"sagnac_frequency/data/demod/"
config['path_to_data3'] = archive_path+"temp_archive/"

# path to out figures
config['path_to_figs'] = data_path+"sagnac_frequency/figures/"

# %% [markdown]
# ## Get Original Data (plugin)

# %%
st1 = __read_sds(config['path_to_data1'], "BW.ROMY.10.BJZ", config['tbeg'], config['tend'])

inv = read_inventory(data_path+"stationxml_ringlaser/"+"station_BW_ROMY.xml")

st1 = st1.remove_sensitivity(inv)

st1 = st1.detrend("demean")

print(st1)

st1.plot();
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY.10.BJZ | 2023-09-08T22:00:00.011600Z - 2023-09-08T23:59:59.911600Z | 20.0 Hz, 143999 samples

# %% [markdown]
# ## Load new Data

# %%
# [ f=10Hz, CA(off), AS(off), ]
st2 = __read_sds(config['path_to_data2'], "BW.ROMY..BJZ", config['tbeg'], config['tend'])

print(st2)

st2.plot();
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY..BJZ | 2023-09-08T22:00:00.000000Z - 2023-09-08T23:59:59.900000Z | 20.0 Hz, 143999 samples

# %% [markdown]
# Scaling has to be adjusted. Currently not understood why ...

# %%
# scaling correction
for tr in st2:
    tr.data *= 0.75
    # tr.data *= 1/np.sqrt(np.pi)
    tr = tr.detrend("demean")

# %%
# st1.trim(config['tbeg'], config['tend'], nearest_sample=False), st2

# %%
from andbro__crosscorrelationTraces import __crosscorrelationTraces

# %%
__crosscorrelationTraces(st1[0], st2[0])
# Out:
# Maximum Correlation:
#  x: 0s
#  y: 0.97
# {'ccorr': array([-0.00012659,  0.00100205,  0.00048923, ...,  0.00090753,
#          0.00065404, -0.00070691]),
#  'xlags': array([-72000, -71999, -71998, ...,  71996,  71997,  71998]),
#  'maximum': (0, 0.9720586782323652),
#  'figure': <Figure size 1500x800 with 3 Axes>}

# %%
fig = __makeplot_spectra(st1, st2)

# %%
fig = __makeplot_coherence(st1, st2)
# Out:
# DPSS using interpolation 143999 100000
# DPSS using interpolation 143999 100000

# %% [markdown]
# ## Compare different settings

# %%
st_all = Stream()

# reference 11 fband = 1Hz
# st_all += __read_sds(config['path_to_data2'], "BW.ROMY.11.BJZ", config['tbeg'], config['tend'])

# reference 12 fband = 10Hz
st_all += __read_sds(config['path_to_data2'], "BW.ROMY.12.BJZ", config['tbeg'], config['tend'])

# reference 20 [ f=10Hz, CA(off), AS(off), ]
# st_all += __read_sds(config['path_to_data2'], "BW.ROMY.20.BJZ", config['tbeg'], config['tend'])

# reference 21 [ f=10Hz, CA(on), SS(off), ]
st_all += __read_sds(config['path_to_data2'], "BW.ROMY.21.BJZ", config['tbeg'], config['tend'])

# reference 22 [ f=10Hz, CA(off), SS(on), ]
st_all += __read_sds(config['path_to_data2'], "BW.ROMY.22.BJZ", config['tbeg'], config['tend'])

# reference 23 [ f=10Hz, CA(on), SS(on), ]
st_all += __read_sds(config['path_to_data2'], "BW.ROMY.23.BJZ", config['tbeg'], config['tend'])

# scaling correction
for tr in st_all:
    tr.data *= 0.75

# add original
st_all += st1.copy()

st_all = st_all.detrend("demean")

st_all = __trim_stream(st_all)
# Out:
#  -> stream size inconsistent: [143999, 72000, 72000, 72000, 143999]
#   -> adjusted: [72000, 72000, 72000, 72000, 72000]

# %%
fig = __makeplot_spectra_all(st_all)

# %% [markdown]
# ## Compare frequency band set

# %%
st5 = Stream()

# fband = 10Hz
st5 += __read_sds(config['path_to_data2'], "BW.ROMY.12.BJZ", config['tbeg'], config['tend'])

# fband = 1Hz
st5 += __read_sds(config['path_to_data2'], "BW.ROMY.11.BJZ", config['tbeg'], config['tend'])

print(st5)
# Out:
# 2 Trace(s) in Stream:
# BW.ROMY.12.BJZ | 2023-09-08T22:00:00.000000Z - 2023-09-08T23:59:59.900000Z | 20.0 Hz, 143999 samples
# BW.ROMY.11.BJZ | 2023-09-08T22:00:00.000000Z - 2023-09-08T23:59:59.900000Z | 20.0 Hz, 143999 samples

# %%
fig = __makeplot_spectra_all(st5)

# %% [markdown]
# ## Filter

# %%
fmin, fmax = 0.001, 0.1

st10 = st1.copy()
st20 = st2.copy()

st10.detrend("demean")
st10.filter("bandpass", freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)

st20.detrend("demean")
st20.filter("bandpass", freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY.XX.LJZ | 2024-11-04T00:00:30.000000Z - 2024-11-04T23:59:30.000000Z | 60.0 s, 1440 samples

# %%
fig = __makeplot_spectra(st10, st20)
# Out:
# /tmp/ipykernel_92224/1648566016.py:13: RuntimeWarning: divide by zero encountered in log10
#   s1 = 20*log10(s1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 fig = __makeplot_spectra(st10, st20)
#
# Cell In[4], line 28, in __makeplot_spectra(st01, st02, db)
#      24 ax.plot(f2, s2, color="tab:green", label=st02[0].get_id(), alpha=0.8, ls="-")
#      26 ax2 = ax.twinx()
# ---> 28 ax2.fill_between(f2, 0, abs(s2-s1),
#      29                  color="gray", alpha=0.4
#      30                 )
#      32 ax2.set_ylim(0, 60)
#      33 ax2.set_ylabel(r"|PSD$_{1}$ - PSD$_{2}$| (dB wrt. 1 rad/s/$\sqrt{Hz}$)", fontsize=font)
#
# ValueError: operands could not be broadcast together with shapes (720,) (71999,)

# %%
def __makeplot_waveforms(st01, st02, db=True):

    yscale, yunit = 1e9, "nrad/s"
    tscale, tunit = 1/60, "min"

    arr1 = st01[0].data*yscale
    arr2 = st02[0].data*yscale

    t1 = st01[0].times(reftime=config['tbeg'])*tscale
    t2 = st02[0].times(reftime=config['tbeg'])*tscale

    font = 12

    fig, ax = plt.subplots(1, 1, figsize=(12, 5))

    cols = ["tab:blue", "tab:red", "tab:orange", "tab:green", "darkblue"]

    ax.plot(t1, arr1, color="tab:orange", label=st01[0].get_id(), alpha=0.8)

    ax.plot(t2, arr2, color="tab:green", label=st02[0].get_id(), alpha=0.8, ls="-")

    ax2 = ax.twinx()
    ax2.tick_params(axis='y', colors="gray")

    ax2.fill_between(t1, 0, abs(arr1-arr2),
                     color="gray", alpha=0.4
                    )

    ax2.set_ylim(bottom=0, top=1)
    ax2.set_ylabel(f"|$\Omega_1$ - $\Omega_2$| ({yunit})", fontsize=font, color="gray")

    ax.set_xlabel(f"Time ({tunit})", fontsize=font)
    ax.set_ylabel(f"$\Omega$ ({yunit})", fontsize=font)

    # ax.vyscale("log")
    # ax.set_xscale("log")

    ax.set_title(f"{str(config['tbeg'])[:19].replace('T',' ')} - {str(config['tend'])[:19].replace('T',' ')}")

    # ax.grid(ls="--", color="gray", alpha=0.4, which="both")

    # ax.set_ylim(-300, -200)
    # ax.set_xlim(1e-3, 5e0)

    ax.legend(ncol=2)

    plt.show();
    return fig

# %%
# %matplotlib tk

fig = __makeplot_waveforms(st10, st20)

# %% [markdown]
# ## Compare with ADR

# %%
# %matplotlib tk

# %%
fmin, fmax = 0.001, 0.5

st_adr = __read_sds(config['path_to_data3'], "BW.ROMY.22.BJZ", config['tbeg'], config['tend'])

print(st_adr)

st_adr.plot();
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY.22.BJZ | 2023-09-08T21:59:59.990000Z - 2023-09-08T23:59:59.890000Z | 20.0 Hz, 143999 samples

# %%
stt = Stream()
stt += st_adr.copy()
stt += st1.copy()
stt += st2.copy()

# stt = stt.detrend("demean")
# stt = stt.taper(0.01)
# stt = stt.filter("bandpass", freqmin=fmin, freqmax=fmax, corners=4, zerophase=True)

fig = __makeplot_spectra_all(stt);

# %%
__crosscorrelationTraces(st1[0], st_adr[0])
# Out:
# Maximum Correlation:
#  x: 5s
#  y: 0.65
# {'ccorr': array([ 8.80188883e-04,  8.57660302e-04,  8.51370498e-04, ...,
#         -1.00193456e-04, -3.37882151e-05,  7.49485524e-05]),
#  'xlags': array([-72000, -71999, -71998, ...,  71996,  71997,  71998]),
#  'maximum': (5, 0.646723057564802),
#  'figure': <Figure size 1500x800 with 3 Axes>}

# %% [markdown]
# ## OTHER

# %%
config['tbeg2'] = UTCDateTime("2024-11-04 00:00")
config['tend2'] = UTCDateTime("2024-11-05 00:00")

# %%
st1 = __read_sds(config['path_to_data1'], "BW.ROMY.10.BJZ", config['tbeg2'], config['tend2'])

inv = read_inventory(data_path+"stationxml_ringlaser/"+"station_BW_ROMY.xml")

st1 = st1.remove_sensitivity(inv)

# fmean = np.nanmean(st1[0].data)

# st1 = st1.detrend("demean")
# st1 = st1.filter("lowpass", freq=1/120, corners=4, zerophase=True)
# st1 = st1.resample(1/60, no_filter=True)

# st1[0].data += fmean

print(st1)

st1.plot();
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY.10.BJZ | 2024-11-04T00:00:00.006398Z - 2024-11-05T00:00:00.006398Z | 20.0 Hz, 1728001 samples

# %%
st2 = __read_sds(config['path_to_data2'], "BW.ROMY.XX.LJZ", config['tbeg2'], config['tend2'])

print(st2)

st2.plot();
# Out:
# 1 Trace(s) in Stream:
# BW.ROMY.XX.LJZ | 2024-11-04T00:00:30.000000Z - 2024-11-04T23:59:30.000000Z | 60.0 s, 1440 samples

# %%
stx = Stream()

stx += st1.copy()
stx += st2.copy()

__makeplot_spectra_all(stx)
