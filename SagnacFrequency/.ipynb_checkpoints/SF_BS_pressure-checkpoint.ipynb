# %% [markdown]
# ## Sagnac Frequency - Backscatter Correction - Pressure

# %% [markdown]
# ## Imports

# %%
import os
import gc
import matplotlib.pyplot as plt
import numpy as np

from datetime import datetime, date
from pandas import DataFrame, read_pickle, date_range, concat, read_csv
from obspy import UTCDateTime, read, Trace, Stream
from scipy.signal import hilbert

from functions.get_fft import __get_fft
from functions.multitaper_psd import __multitaper_psd
from functions.welch_psd import __welch_psd
from functions.compute_cwt import __compute_cwt

from andbro__read_sds import __read_sds
from andbro__readYaml import __readYaml

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
    bay_path = '/home/andbro/bay200/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/bay200/'
elif os.uname().nodename == 'lin-ffb-01':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/bay200/'

# %%
from functions.reduce import __reduce
from functions.multitaper_coherence import __multitaper_coherence
from functions.cross_correlation_function_windows import __cross_correlation_function_windows
from functions.cross_correlation_windows import __cross_correlation_windows
from functions.load_backscatter_data import __load_backscatter_data
from functions.cc_lag_matrix import __cc_lag_matrix

# %% [markdown]
# ## Configurations

# %%
config = {}

config['ring'] = "U"

config['seed'] = "BW.DROMY..FJU"

config['path_to_sds'] = archive_path+"romy_archive/"

case = 10
# config['tbeg'] = UTCDateTime("2023-12-05 00:00")
# config['tend'] = UTCDateTime("2023-12-16 00:00")

# config['tbeg'] = UTCDateTime("2023-12-08 00:00")
# config['tend'] = UTCDateTime("2023-12-15 00:00")
# flim1, flim2 = 302.425, 302.485

## note air ventilation on from 27-12-2023 !!!
# case = 11
# config['tbeg'] = UTCDateTime("2023-12-24 00:00")
# config['tend'] = UTCDateTime("2023-12-31 00:00")

case = 12
config['tbeg'] = UTCDateTime("2024-01-13 00:00")
config['tend'] = UTCDateTime("2024-01-17 00:00")
flim1, flim2 = 302.375, 302.475

# case = 13
# config['tbeg'] = UTCDateTime("2024-02-08 07:00")
# config['tend'] = UTCDateTime("2024-02-13 05:00")
# flim1, flim2 = 302.395, 302.45

case = 14
config['tbeg'] = UTCDateTime("2024-02-15 18:00")
config['tend'] = UTCDateTime("2024-02-18 16:00")
flim1, flim2 = 302.40, 302.455

case = 15
config['tbeg'] = UTCDateTime("2024-02-09 00:00")
config['tend'] = UTCDateTime("2024-02-12 12:00")
flim1, flim2 = 302.40, 302.455

## path to Sagnac data
config['path_to_autodata'] = archive_path+f"romy_autodata/"

config['path_to_data'] = data_path+"sagnac_frequency/data/backscatter/"

config['path_to_figs'] = data_path+"sagnac_frequency/figures/"

# %% [markdown]
# ## Configurations

# %%
bs = __load_backscatter_data(config['tbeg'], config['tend'], config['ring'], config['path_to_data'])

bs['time_sec'] = bs.time2 - bs.time1 + (bs.time1 - bs.time1.loc[0])

# %% [markdown]
# ### Cut corrupt data periods

# %%
times = [("2023-12-04T09:11", "2023-12-04T18:01")]

for t1, t2 in times:
    # bs['fj_fs'] = np.where((bs.time1 > t1) & (bs.time1 < t2), np.nan, bs.fj_fs)
    # bs['w_s'] = np.where((bs.time1 > t1) & (bs.time1 < t2), np.nan, bs.w_s)
    bs['fj_fs'] = np.where((bs.time1 > t1) & (bs.time1 < t2), np.nan, bs.fj_fs)
    bs['w_s'] = np.where((bs.time1 > t1) & (bs.time1 < t2), np.nan, bs.w_s)


bs['fj_fs'] = np.nan_to_num(bs['fj_fs'], nan=np.nanmedian(bs['fj_fs']))
bs['w_s'] = np.nan_to_num(bs['w_s'], nan=np.nanmedian(bs['w_s']))

# %%
plt.figure(figsize=(15,5))
plt.plot(bs.time_sec/86400, bs.fj_fs)
plt.ylim(flim1, flim2)
# Out:
# (302.4, 302.455)

# %%
from functions.load_mlti import __load_mlti

mltiU = __load_mlti(config['tbeg'], config['tend'], "U", archive_path)

# %%
from functions.get_mlti_intervals import __get_mlti_intervals

mltiU_t1, mltiU_t2 = __get_mlti_intervals(mltiU.time_utc)

# %%
from functions.mlti_intervals_to_NaN import __mlti_intervals_to_NaN

bs = __mlti_intervals_to_NaN(bs, "fj_fs", "time1", mltiU_t1, mltiU_t2, t_offset_sec=300)
bs = __mlti_intervals_to_NaN(bs, "w_s", "time1", mltiU_t1, mltiU_t2, t_offset_sec=300)

bs['fj_fs_nan'] = bs['fj_fs']
bs['w_s_nan'] = bs['w_s']

# %%
tt1, tt2 = "2023-11-20 14:00", "2024-01-11"
cond1 = bs.time1 > tt1
cond2 = bs.time1 < tt2
cond3 = bs.fj_fs_nan < 302.4
cond4 = bs.fj_fs_nan > 302.6

bs['fj_fs_nan'] = np.where(cond1 & cond2 & cond3, np.nan, bs.fj_fs_nan)
bs['fj_fs_nan'] = np.where(cond1 & cond2 & cond4, np.nan, bs.fj_fs_nan)

bs['w_s_nan'] = np.where(cond1 & cond2 & cond3, np.nan, bs.w_s_nan)
bs['w_s_nan'] = np.where(cond1 & cond2 & cond4, np.nan, bs.w_s_nan)

# %%
from functions.interpolate_nan import __interpolate_nan

bs['fj_fs_inter'] = __interpolate_nan(np.array(bs.fj_fs_nan))
bs['w_s_inter'] = __interpolate_nan(np.array(bs.w_s_nan))

# %%
from functions.smoothing import __smooth

n_minutes = 240

bs['fj_fs_smooth'] = __smooth(bs.fj_fs_inter, n_minutes)
bs['w_s_smooth']   = __smooth(bs.w_s_inter, n_minutes)

# %%
def __makeplot():

    Nrow, Ncol = 1, 1

    font = 12

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 5), sharex=True)

    plt.subplots_adjust(hspace=0.1)

    # time_scaling = 1/86400
    time_scaling = 1

    ax.plot(bs.time_sec*time_scaling, bs.fj_fs, color="tab:grey", alpha=0.3, label="raw")
    ax.plot(bs.time_sec*time_scaling, bs.fj_fs_inter, color="tab:blue", label="cleaned")
    ax.plot(bs.time_sec*time_scaling, bs.fj_fs_smooth, color="k", label=f"mov. avg. ({n_minutes} min)")
    ax.set_ylim(flim1, flim2)
    ax.ticklabel_format(useOffset=False)
    ax.set_ylabel("$\delta f$ north ring (Hz)", fontsize=font)

    ax.grid(ls=":", zorder=0)
    ax.legend(loc=1)


    ## add dates to x-axis
    ref_date = str(bs.time1.iloc[0])[:10]
    tcks = ax.get_xticks()
    tcklbls = [UTCDateTime(UTCDateTime(ref_date)+t).date for t in tcks]
    ax.set_xticklabels(tcklbls)

    plt.show();
    return fig

fig = __makeplot();

fig.savefig(config['path_to_figs']+f"SF_BS_RU_multiday_Case{case}_cleaned.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1871760/1523202915.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(tcklbls)

# %%
ttt = bs.time_sec
arr = bs.fj_fs_inter
dt  = 60 # seconds

out = __compute_cwt(ttt, arr, dt, tscale="hour", datalabel="$\Delta f (Hz)",
                    log=False, period=True, fmax=None, plot=True)

out['fig'].savefig(config['path_to_figs']+f"SF_BS_RU_multiday_Case{case}_CWT_1.png", format="png", dpi=200, bbox_inches='tight')
# Out:
# 0.008066777576619926

# %%
bs['fj_bs'] = bs.term * bs.fj_fs

# %%
plt.plot(bs.time_sec, bs.fj_fs)
plt.plot(bs.time_sec, bs.term * bs.fj_fs)

# %% [markdown]
# ### Compute PSD

# %%
def __makeplot(key1, key2):

    dat1 = np.array((bs[key1] - bs[key1].mean()).replace(np.nan, 0))
    dat2 = np.array((bs[key2] - bs[key2].mean()).replace(np.nan, 0))


    out = __multitaper_coherence(dat1, dat2, 60, n_taper=10, time_bandwidth=3.5, method=0)


    f1, psd1, pha1 = __get_fft(dat1, 60)
    f2, psd2, pha2 = __get_fft(dat2, 60)


    Nrow, Ncol = 2, 1

    font = 12

    time_scaling = 1

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 8))


    ax[0].plot(bs.time_sec*time_scaling, bs[key1], color="black", label=f"$\delta$f cleaned")
    ax[0].plot(bs.time_sec*time_scaling, bs[key2], color="tab:red", label=f"$\delta$f backscatter corrected")

    ax[0].ticklabel_format(useOffset=False)

    ax[1].semilogx(1/f1/3600, psd1, color="black", label=f"$\delta$f cleaned")
    ax[1].semilogx(1/f2/3600, psd2, color="tab:red", label=f"$\delta$f backscatter corrected")

    # ax[1].semilogx(out['ff1'], out['psd1'], color="black", label=f"$\delta$f w/ backscatter")
    # ax[1].semilogx(out['ff2'], out['psd2'], color="tab:red", label=f"$\delta$f w/o backscatter")

    ax11 = ax[1].twinx()
    ax11.semilogx(1/out['fcoh']/3600, out['coh'], color="tab:grey", label=f"coherence")
    ax11.set_ylim(0, 1.)
    ax11.set_ylabel(f"Coherence", fontsize=font, color="tab:grey")
    [t.set_color('tab:grey') for t in ax11.yaxis.get_ticklabels()]

    for _n in range(Nrow):
        ax[_n].grid(which="both", ls=":", zorder=0)
        ax[_n].legend(loc=1, fontsize=font-1)

    # ax[0].set_ylim(302.395, 302.465)
    ax[0].set_ylim(flim1, flim2)
    ax[0].set_xlim(0, max(bs.time_sec)*time_scaling)

    ax[1].set_ylim(0, max(psd1)+0.2*max(psd1))
    # ax[1].set_xlim(0, 1e-3)
    ax[1].set_xlim(1e-1, 1e2)

    ax[1].legend(loc=4, fontsize=font-1)

    ax[0].set_ylabel(f"$\delta$f (Hz)", fontsize=font)
    # ax[0].set_xlabel(f"Time from {config['tbeg'].date} {config['tbeg'].time} UTC (hours)", fontsize=font)

    ax[1].set_ylabel("Spectrum (Hz $\sqrt{Hz}$)", fontsize=font)
    # ax[1].set_xlabel("Frequency (Hz)", fontsize=font)
    ax[1].set_xlabel("Period (hour)", fontsize=font)

    ax[1].axvline(12, ls="--", color="grey", zorder=0)
    ax[1].axvline(24, ls="--", color="grey", zorder=0)

    ## add dates to x-axis
    ref_date = str(bs.time1.iloc[0])[:10]
    tcks = ax[0].get_xticks()
    tcklbls = [UTCDateTime(UTCDateTime(ref_date)+t).date for t in tcks]
    ax[0].set_xticklabels(tcklbls)

    gc.collect()

    plt.show();
    return fig

fig = __makeplot("fj_fs_inter", "fj_bs");

fig.savefig(config['path_to_figs']+f"SF_BS_RU_pressure_Case{case}_PSD.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1871760/3154820591.py:28: RuntimeWarning: divide by zero encountered in divide
#   ax[1].semilogx(1/f1/3600, psd1, color="black", label=f"$\delta$f cleaned")
# /tmp/ipykernel_1871760/3154820591.py:29: RuntimeWarning: divide by zero encountered in divide
#   ax[1].semilogx(1/f2/3600, psd2, color="tab:red", label=f"$\delta$f backscatter corrected")
# /tmp/ipykernel_1871760/3154820591.py:35: RuntimeWarning: divide by zero encountered in divide
#   ax11.semilogx(1/out['fcoh']/3600, out['coh'], color="tab:grey", label=f"coherence")
# /tmp/ipykernel_1871760/3154820591.py:68: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(tcklbls)

# %% [markdown]
# ## Load Pressure Data

# %%
# ps = __read_sds(archive_path+"temp_archive/", "BW.PROMY.03.LDI", config['tbeg'], config['tend'])
ps = __read_sds(archive_path+"temp_archive/", "BW.PROMY.05.LDI", config['tbeg'], config['tend'])
ps = __read_sds(archive_path+"temp_archive/", "BW.PROMY.09.LDI", config['tbeg'], config['tend'])

# ps = __read_sds(archive_path+"temp_archive/", "BW.WROMY.05.LDI", config['tbeg'], config['tend'])

# %%
for tr in ps:
    # tr.data = __smooth(tr.data, 10)
    tr.data = __interpolate_nan(tr.data)
    # tr.data = np.gradient(tr.data)
ps
# Out:
# 1 Trace(s) in Stream:
# BW.PROMY.09.LDI | 2024-02-09T00:00:00.000000Z - 2024-02-12T12:00:00.000000Z | 1.0 Hz, 302401 samples

# %%
tr00 = Trace()
tr00.data = np.array(bs.fj_fs)
tr00.stats.delta = 60
tr00.stats.starttime = bs.time1[0]
tr00.stats.network = "BW"
tr00.stats.station = "ROMY"
tr00.stats.location = "FS"

tr11 = Trace()
tr11.data = np.array(bs.fj_fs_inter)
tr11.stats.delta = 60
tr11.stats.starttime = bs.time1[0]
tr11.stats.network = "BW"
tr11.stats.station = "ROMY"
tr11.stats.location = "FSI"

tr22 = Trace()
tr22.data = np.array(bs.w_s)
tr22.stats.delta = 60
tr22.stats.starttime = bs.time1[0]
tr22.stats.network = "BW"
tr22.stats.station = "ROMY"
tr22.stats.location = "WS"

tr33 = Trace()
tr33.data = np.array(bs.w_s_inter)
tr33.stats.delta = 60
tr33.stats.starttime = bs.time1[0]
tr33.stats.network = "BW"
tr33.stats.station = "ROMY"
tr33.stats.location = "WSI"

st0 = Stream()
st0 += tr00.copy()
st0 += tr11.copy()
st0 += tr22.copy()
st0 += tr33.copy()

st0.plot()

# %%
tr00 = Trace()
tr00.data = np.array(bs.w_s_inter)
tr00.stats.delta = 60
tr00.stats.starttime = bs.time1[0]
tr00.stats.network = "BW"
tr00.stats.station = "ROMY"
tr00.stats.location = "WS"

tr11 = Trace()
tr11.data = np.array(bs.fj_fs_inter)
tr11.stats.delta = 60
tr11.stats.starttime = bs.time1[0]
tr11.stats.network = "BW"
tr11.stats.station = "ROMY"
tr11.stats.location = "FS"

st = Stream()
st += tr00.copy()
st += tr11.copy()
st += ps[0].copy()

st = st.detrend("linear")
st = st.filter("lowpass", freq = 0.005, corners=4, zerophase=True)
st = st.resample(0.01, no_filter=True)

st
# Out:
# 3 Trace(s) in Stream:
# BW.ROMY.WS.     | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:58:20.000000Z | 100.0 s, 3024 samples
# BW.ROMY.FS.     | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:58:20.000000Z | 100.0 s, 3024 samples
# BW.PROMY.09.LDI | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:58:20.000000Z | 100.0 s, 3024 samples

# %%
st.plot(equal_scale=False);

# %%
ttt = st[1].times()
arr = st[1].data
dt  = st[1].stats.delta # seconds

out = __compute_cwt(ttt, arr, dt, tscale="hour", datalabel="Air Pressure (hPa)",
                    log=False, period=True, fmax=None, plot=True)

out['fig'].savefig(config['path_to_figs']+f"SF_BS_RU_multiday_Case{case}_CWT_2.png", format="png", dpi=200, bbox_inches='tight')
# Out:
# 0.004840066545971956

# %%
lp = st.copy()

lp = lp.detrend("simple")
lp = lp.taper(0.1)
# lp = lp.filter("bandpass", freqmin=1/(12*3600), freqmax=1/(1*3600), corners=4, zerophase=True)
lp = lp.filter("highpass", freq=1/(48*3600), corners=4, zerophase=True)
# lp = lp.filter("lowpass", freq=0.01, corners=4, zerophase=True)

lp.plot(equal_scale=False);

# %%
st
# Out:
# 3 Trace(s) in Stream:
# BW.ROMY.WS.     | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:58:20.000000Z | 100.0 s, 3024 samples
# BW.ROMY.FS.     | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:58:20.000000Z | 100.0 s, 3024 samples
# BW.PROMY.09.LDI | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:58:20.000000Z | 100.0 s, 3024 samples

# %%
def __makeplot():

    from numpy import nanmax

    fl, fu = 1/(4*3600), 1/(0.2*3600)


    lp = st.copy()

    lp = lp.detrend("simple")
    lp = lp.taper(0.1)
    lp = lp.filter("bandpass", freqmin=fl, freqmax=fu, corners=4, zerophase=True)
    # lp = lp.filter("highpass", freq=fl, corners=4, zerophase=True)

    lp_ps = lp.select(station="PROMY")[0]
    lp_fs = lp.select(station="ROMY", location="WS")[0]

    env0 = abs(hilbert(lp_ps.data))
    env1 = abs(hilbert(lp_fs.data))

    env0_smooth = __smooth(env0, 1)
    env1_smooth = __smooth(env1, 1)

    dt = st[0].stats.delta
    over = 0.9
    twin = 1.5/fl ## seconds

    # tt, cc = __cross_correlation_windows(st[0].data, st[1].data, dt, twin, overlap=over, demean=True)
    tt_lp, cc_lp = __cross_correlation_windows(lp_ps.data, lp_fs.data, dt, twin, overlap=over, demean=False)


    Nrow, Ncol = 5, 1

    font = 12

    ref_date = str(bs.time1.iloc[0])[:10]
    ref_sec = abs(st0.select(location="WS")[0].times()[0]-st0.select(location="WS")[0].times(reftime=UTCDateTime(ref_date))[0])

    print(ref_sec)

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 10), sharex=True)

    plt.subplots_adjust(hspace=0.1)

    # time_scaling = 1/86400
    time_scaling = 1


    ax[0].plot(st0.select(location="WS")[0].times(reftime=UTCDateTime(ref_date)),
               st0.select(location="WS")[0].data,
               color="grey", label="raw", lw=1)
    ax[0].plot(st0.select(location="WSI")[0].times(reftime=UTCDateTime(ref_date)),
               st0.select(location="WSI")[0].data,
               color="black", label="cleaned & BS corrected", lw=1)

    ax[0].set_ylim(flim1, flim2)
    ax[0].ticklabel_format(useOffset=False)
    ax[0].set_ylabel("$\delta$f (Hz)", fontsize=font)


    ax00 = ax[0].twinx()
    ax00.plot(ps.select(channel="*I")[0].times(reftime=UTCDateTime(ref_date)),
              ps.select(channel="*I")[0].data, color="tab:purple", label="WS5")
    ax00.set_ylabel("Pressure (hPa)", fontsize=font, color="tab:purple")
    [t.set_color('tab:purple') for t in ax00.yaxis.get_ticklabels()]


    ax[1].plot(lp_fs.times(reftime=UTCDateTime(ref_date)),
               lp_fs.data, color="k", label=f"$\Delta$f ( bp = {round(1/fu/3600, 1)} - {round(1/fl/3600,1)} hr )", lw=1)


    ax11 = ax[1].twinx()
    ax11.plot(lp_ps.times(reftime=UTCDateTime(ref_date)),
              lp_ps.data, color="tab:purple", label=f"PS{lp_ps.stats.location[-1]}", lw=1)
    ax11.set_ylabel("Pressure (hPa)", fontsize=font, color="tab:purple")
    [t.set_color('tab:purple') for t in ax11.yaxis.get_ticklabels()]
    ax11.legend(loc=1)

    max_lim = max([abs(min(lp_fs.data)), abs(max(lp_fs.data))])
    ax[1].set_ylim(-max_lim, max_lim)

    max_lim = max([abs(min(lp_ps.data)), abs(max(lp_ps.data))])
    ax11.set_ylim(-max_lim, max_lim)

    ax[1].set_ylabel("$\Delta$f (Hz)", fontsize=font)



    ax[2].plot(lp_fs.times(reftime=UTCDateTime(ref_date)),
               env1_smooth / nanmax(env1_smooth), color="black", label="$\Delta$f")
    ax[2].set_ylabel("norm. envelope", fontsize=font)


    ax[2].plot(lp_ps.times(reftime=UTCDateTime(ref_date)),
              env0_smooth / nanmax(env0_smooth), color="tab:purple", label="Pressure")
    # ax[2].set_ylabel("Pressure envelope", fontsize=font, color="tab:purple")
    # [t.set_color('tab:purple') for t in ax[2].yaxis.get_ticklabels()]


    # ax[3].plot(tt, cc, label="CC")
    # ax[3].plot(tt_lp, cc_lp, label="CC (bandpass)")
    ax[3].scatter(tt_lp+ref_sec, cc_lp, alpha=abs(cc_lp), label="CC (bandpass)", color="w", edgecolor="tab:purple", lw=1.5, zorder=2)
    ax[3].set_ylim(-1.1, 1.1)
    ax[3].set_ylabel("CC-Coefficient", fontsize=font)


    ttt, ccf, tlags, shifts, maxima = __cross_correlation_function_windows(lp_ps.data, lp_fs.data, dt, twin, overlap=0.5, demean=True)
    cmap = plt.get_cmap("PuOr_r")
    ca4 = ax[4].pcolormesh(ttt+ref_sec, tlags/60, ccf.T, rasterized=True, vmin=-1, vmax=1, cmap=cmap)
    ax[4].set_ylabel("Lag time (min)", fontsize=font)

    for _n in range(Nrow):
        ax[_n].grid(ls=":", zorder=0)
        # ax[_n].set_xlim(left=0)

    ax[0].legend(loc=1, ncol=3)
    ax[1].legend(loc=4, ncol=3)
    ax[2].legend(loc=1, ncol=3)
    # ax[3].legend(loc=4, ncol=3)

    ## add dates to x-axis
    tcks = ax[Nrow-1].get_xticks()
    tcklbls = [f"{UTCDateTime(UTCDateTime(ref_date)+t).date} \n {UTCDateTime(UTCDateTime(ref_date)+t).time}" for t in tcks]
    ax[Nrow-1].set_xticklabels(tcklbls)

    ## add labels for subplots
    for _k, ll in enumerate(['(a)', '(b)', '(c)', '(d)', '(e)']):
        ax[_k].text(.005, .97, ll, ha='left', va='top', transform=ax[_k].transAxes, fontsize=font+2)


    ## add colorbar
    cbar_ax = fig.add_axes([0.91, 0.11, 0.02, 0.14]) #[left, bottom, width, height]
    cb = plt.colorbar(ca4, cax=cbar_ax)
    cb.set_label("CC", fontsize=font, labelpad=-1, color="black")

    gc.collect()

    plt.show();
    return fig

fig = __makeplot();

fig.savefig(config['path_to_figs']+f"SF_BS_RU_Case{case}_pressure.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# 0.0
# /tmp/ipykernel_1871760/92612194.py:124: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[Nrow-1].set_xticklabels(tcklbls)

# %%
tr00 = Trace()
tr00.data = np.array(bs.w_s_inter)
tr00.stats.delta = 60
tr00.stats.starttime = bs.time1[0]
tr00.stats.network = "BW"
tr00.stats.station = "ROMY"
tr00.stats.location = "U"

st_all = Stream()
st_all += tr00.copy()
st_all += ps.copy()

print(st_all)

st_all.resample(0.01, no_filter=True)

st_all.plot(equal_scale=False);
# Out:
# 2 Trace(s) in Stream:
# BW.ROMY.U.      | 2024-02-09T00:00:00.000000Z - 2024-02-12T11:59:00.000000Z | 60.0 s, 5040 samples
# BW.PROMY.09.LDI | 2024-02-09T00:00:00.000000Z - 2024-02-12T12:00:00.000000Z | 1.0 Hz, 302401 samples

# %%
def __makeplot(st0):


    dat0 = st0.select(station="ROMY")[0].data

    dat1 = st0.select(station="PROMY")[0].data


    dt, df = st0[0].stats.delta, st0[0].stats.sampling_rate

    out01 = __multitaper_coherence(dat0, dat1, dt, n_taper=20, time_bandwidth=3.5, method=0)


    # f1, psd1, pha1 = __get_fft(dat1, df)
    # f2, psd2, pha2 = __get_fft(dat2, df)


    Nrow, Ncol = 4, 1

    font = 12

    ref_date = config['tbeg'].date

    fig, ax = plt.subplots(Nrow, Ncol, figsize=(15, 10), sharex=False)

    plt.subplots_adjust(hspace=0.25)

    # time_scaling = 1/86400
    time_scaling = 1

    # ax[0].plot(bs.time_sec, bs.fj_fs, color="tab:grey", alpha=0.3, label="raw")
    ax[0].plot(st0.select(station="ROMY")[0].times(reftime=UTCDateTime(ref_date)),
               st0.select(station="ROMY")[0].data, color="black", label="backscatter corrected", lw=1)

    ax[0].set_ylim(flim1, flim2)
    ax[0].ticklabel_format(useOffset=False)
    ax[0].set_ylabel("$\delta$f (Hz)", fontsize=font)


    ax[1].plot(st0.select(station="PROMY")[0].times(reftime=UTCDateTime(ref_date)),
               st0.select(station="PROMY")[0].data, color="tab:blue", label="PS1")
    ax[1].set_ylabel("Pressure (hPa)", fontsize=font)
    # [t.set_color('tab:purple') for t in ax00.yaxis.get_ticklabels()]



    ax[2].plot(1/out01['ff1'][1:]/3600, out01['psd1'][1:], color="k")
    ax[2].set_xscale("log")
    ax[2].set_yscale("log")
    ax[2].set_ylabel(f"PSD (Hz$^2$/Hz)", fontsize=font)


    ax22 = ax[2].twinx()
    ax22.plot(1/out01['ff2'][1:]/3600, out01['psd2'][1:], color="tab:blue", label=f"PS{st0.select(station='PROMY')[0].stats.location[-1]}")

    ax22.set_xscale("log")
    ax22.set_yscale("log")
    ax22.set_ylabel(f"PSD (hPa$^2$/Hz)", fontsize=font)

    ax[3].plot(1/out01['fcoh'][1:]/3600, out01['coh'][1:], color="tab:blue", label=f"PS{st0.select(station='PROMY')[0].stats.location[-1]}")

    ax[3].set_xscale("log")
    ax[3].set_ylabel("Coherence", fontsize=font)
    ax[3].set_xlabel("Period (cycles per hour)", fontsize=font)

    for _n in range(Nrow):
        ax[_n].grid(ls=":", zorder=0)
        # ax[_n].set_xlim(left=0)

    ax[0].legend(loc=1, ncol=3)
    ax[1].legend(loc=4, ncol=1)
    ax22.legend(loc=4, ncol=1)
    ax[3].legend(loc=1, ncol=1)

    ax[3].set_ylim(0, 1)

    ## add dates to x-axis
    tcks = ax[0].get_xticks()
    tcklbls = [f"{UTCDateTime(UTCDateTime(ref_date)+t).date} \n {UTCDateTime(UTCDateTime(ref_date)+t).time}" for t in tcks]
    ax[0].set_xticklabels(tcklbls)
    tcks = ax[1].get_xticks()
    tcklbls = [f"{UTCDateTime(UTCDateTime(ref_date)+t).date} \n {UTCDateTime(UTCDateTime(ref_date)+t).time}" for t in tcks]
    ax[1].set_xticklabels(tcklbls)

    ## add labels for subplots
    for _k, ll in enumerate(['(a)', '(b)', '(c)', '(d)']):
        ax[_k].text(.005, .97, ll, ha='left', va='top', transform=ax[_k].transAxes, fontsize=font+2)


    gc.collect()

    plt.show();
    return fig

fig = __makeplot(st_all)

fig.savefig(config['path_to_figs']+f"SF_BS_RU_Case{case}_spectra_pressure.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1871760/3115486665.py:80: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(tcklbls)
# /tmp/ipykernel_1871760/3115486665.py:83: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(tcklbls)

# %%
# dt = st[0].stats.delta
# dat1 = st[0].data
# dat2 = st[1].data

dt = lp[0].stats.delta
dat1 = lp[0].data
dat2 = lp[1].data
# dat2 = np.roll(lp[0].data,50)


twin = 3*3600

ttt, ccf, tlags, shifts, maxima = __cross_correlation_function_windows(dat1, dat2, dt, twin, overlap=0.5, demean=True)

# %%
plt.figure(figsize=(15, 5))

cmap = plt.get_cmap("seismic")

plt.pcolormesh(ttt/86400, tlags/60, ccf.T, rasterized=True, vmin=-1, vmax=1, cmap=cmap)

# %%
# dt = st[0].stats.delta
# dat1 = st[0].data
# dat2 = st[1].data

dt = lp[0].stats.delta
dat1 = lp[0].data
dat2 = lp[1].data

twin = 3*3600


tt, Tlags, ccc = __cc_lag_matrix(dat1, dat2, dt, twin, 3*3600, 600, plot=True)

# %%
bands = [(0.5, 1.0),(1.0, 2.0), (1.0, 3.0), (2.0, 3.0), (2.0, 4.0), (3.0, 5.0), (4.0, 8.0), (6.0, 8.0)]

fig, ax = plt.subplots(len(bands), 1, figsize=(15, 10), sharex=True)


for _n, band in enumerate(bands):

    flower = 1/(band[1]*3600)
    fupper = 1/(band[0]*3600)

    lp = st.copy()

    lp = lp.detrend("simple")
    lp = lp.taper(0.1)
    lp = lp.filter("bandpass", freqmin=flower, freqmax=fupper, corners=4, zerophase=True)

    tt, cc = __cross_correlation_windows(lp[0].data, lp[1].data, lp[0].stats.delta, 3*band[1]*3600, overlap=0.9, lag=0, demean=False)

    # ax[_n].plot(tt/86400, cc, label=f"{band[0]} - {band[1]} hr", zorder=2)
    ax[_n].scatter(tt/86400, cc, alpha=abs(cc), label=f"{band[0]} - {band[1]} hr", color="w", edgecolor="tab:blue", lw=1.5, zorder=2)

    ax[_n].grid(axis="y", color="grey", zorder=0, alpha=0.5)

    ax[_n].legend(loc=1)

    ax[_n].set_ylim(-1, 1)

plt.show();

# %%
from functions.compute_wavelet_coherencey_transform import __compute_wavelet_coherency_transform

# %%
n1 = 1500

plt.scatter(st_all.select(station="PROMY")[0].data[n1:], st_all.select(station="ROMY")[0].data[n1:], s=5)
