# %% [markdown]
# ## Compute Sagnac Frequency - Plotting

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt

from datetime import datetime, date
from pandas import DataFrame, read_pickle, date_range, concat, read_csv
from obspy import UTCDateTime

# %% [markdown]
# ## Configurations

# %%
config = {}

config['seed'] = "BW.DROMY..FJZ"


config['tbeg'] = UTCDateTime("2023-04-07 00:00")
config['tend'] = UTCDateTime("2023-04-10 00:00")

config['datapath'] = "/home/andbro/kilauea-data/sagnac_frequency/Easter/"

config['repository'] = "george"

# %% [markdown]
# ## Load Data

# %%
def __load_data(config):
    
    net, sta, loc, cha = config['seed'].split(".")
    
    t1 = date.fromisoformat(str(config['tbeg'].date))
    t2 = date.fromisoformat(str(config['tend'].date))

    df = DataFrame()
    for dat in date_range(t1,t2):
        file = cha+"_"+str(dat)[:10].replace("-","")+".pkl"

        try:
            df0 = read_pickle(config['datapath']+file)
            df = concat([df, df0])
        except:
            print(f"error for {config['datapath']}{file}")
            
    return df

# %%
config['seed'] = "BW.DROMY..FJZ"
fjz = __load_data(config)

config['seed'] = "BW.DROMY..F1V"
f1z = __load_data(config)

config['seed'] = "BW.DROMY..F4V"
f2z = __load_data(config)
# Out:
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F1V_20230407.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F1V_20230408.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F1V_20230409.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F1V_20230410.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F4V_20230407.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F4V_20230408.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F4V_20230409.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/Easter/F4V_20230410.pkl

# %% [markdown]
# ## Plot Frequency

# %%
def __makeplot(df1, df2, df3):
    
    def __smooth(y, box_pts):
        from numpy import ones, convolve, hanning

#         win = ones(box_pts)/box_pts
        win = hanning(box_pts)
        y_smooth = convolve(y, win/sum(win), mode='same')

        return y_smooth
    
    time_scaling, time_unit = 1, "MJD"
    
    ## ___________________
    ##
    
    fig, ax = plt.subplots(3,1, figsize=(15,10), sharex=True)
    
    plt.subplots_adjust(hspace=0.05)
    
    font = 14
    smooting = 10
    cut_off = int(smooting/2)
    
    ## DF1
    ax[0].scatter(df1['times_mjd']/time_scaling, df1['freqs'], c="#3776ab", s=10, alpha=0.4, zorder=2, label="FJZ")
    ax[0].plot(df1['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df1['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)
    
    
    ## DF2
    ax[1].scatter(df2['times_mjd']/time_scaling, df2['freqs'], c="#f48512", s=10, alpha=0.4, zorder=2, label="F1Z")
    ax[1].plot(df2['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df2['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)


    ## DF3
    ax[2].scatter(df2['times_mjd']/time_scaling, df3['freqs'], c="darkred", s=10, alpha=0.4, zorder=2, label="F2Z")
    ax[2].plot(df2['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df3['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)


#     ax[2].set_ylim(5e12, 2e14)
        
#     ax[0].set_ylim(min(df1['freqs'][1:10]), max(df1['freqs'][1:10]))

#     ax[0].set_ylim(553.4550, 553.4655)
    
    
    ax[0].ticklabel_format(useOffset=False, style='plain')
    ax[1].ticklabel_format(useOffset=False, style='plain')
    ax[2].ticklabel_format(useOffset=False, style='plain')
    
    ymin, ymax = ax[0].axes.get_ylim()
    ax[1].set_ylim(ymin, ymax)
    ax[2].set_ylim(ymin, ymax)
    
    
    ax[0].set_ylabel(r"Sagnac Beat (Hz)", fontsize=font)
    ax[1].set_ylabel(r"CCW (Hz)", fontsize=font)
    ax[2].set_ylabel(r"CW (Hz)", fontsize=font)

    ax[2].set_xlabel("Days (MJD)", fontsize=font)
    
#     ax[0].set_title("ROMY-U Sagnac-Frequency", fontsize=font+2, pad=10)
    ax[0].legend(loc=4)
    ax[1].legend(loc=4)
    ax[2].legend(loc=4)
    
    for i in range(3):
        ax[i].grid(zorder=0)
    
    plt.show();

# %%
__makeplot(fjz, f1z, f2z)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/obs/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/obs/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/obs/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'times_mjd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9435/1085481918.py in <module>
# ----> 1 __makeplot(fjz, f1z, f2z)
#
# /tmp/ipykernel_9435/2925915824.py in __makeplot(df1, df2, df3)
#      29
#      30     ## DF2
# ---> 31     ax[1].scatter(df2['times_mjd']/time_scaling, df2['freqs'], c="#f48512", s=10, alpha=0.4, zorder=2, label="F1Z")
#      32     ax[1].plot(df2['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df2['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)
#      33
#
# ~/anaconda3/envs/obs/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/anaconda3/envs/obs/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'times_mjd'

# %% [markdown]
# ## Plot Power

# %%
def __makeplot_power(df1, df2, df3):
    
    def __smooth(y, box_pts):
        from numpy import ones, convolve, hanning

#         win = ones(box_pts)/box_pts
        win = hanning(box_pts)
        y_smooth = convolve(y, win/sum(win), mode='same')

        return y_smooth
    
    
    ## ___________________
    ##
    
    fig, ax = plt.subplots(2,1, figsize=(15,7), sharex=True)
    
    plt.subplots_adjust(hspace=0.05)
    
    font = 14
    smooting = 10
    cut_off = int(smooting/2)
    
    ## DF1
    ax[0].scatter(df1['times_mjd'], df1['psd_max'], c="#3776ab", s=10, alpha=0.4, zorder=2, label="FJZ")
#     ax[0].plot(df1['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df1['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)
    
    
    ## DF2
    ax[1].scatter(df2['times_mjd'], df2['psd_max'], c="#f48512", s=10, alpha=0.4, zorder=2, label="F1Z*")
#     ax[1].plot(df2['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df2['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)


    ## DF3
    ax[1].scatter(df2['times_mjd'], df3['psd_max'], c="darkred", s=10, alpha=0.4, zorder=2, label="F2Z")
#     ax[1].plot(df2['times_mjd'][cut_off:-cut_off]/time_scaling, __smooth(df3['freqs'],smooting)[cut_off:-cut_off], "k", zorder=2)


#     ax[2].set_ylim(5e12, 2e14)
        
#     ax[0].set_ylim(min(df1['freqs'][1:10]), max(df1['freqs'][1:10]))

#     ax[0].set_ylim(553.4550, 553.4655)
    
    
    ax[0].ticklabel_format(useOffset=False, style='plain')
    ax[1].ticklabel_format(useOffset=False, style='plain')
       
    ax[0].set_yscale("log")
    ax[1].set_yscale("log")
    
    ax[0].set_ylabel(r"PSD$_{max}$", fontsize=font)
    ax[1].set_ylabel(r"PSD$_{max}$", fontsize=font)

    ax[1].set_xlabel("Days (MJD)", fontsize=font)
    
#     ax[0].set_title("ROMY-U Sagnac-Frequency", fontsize=font+2, pad=10)
    ax[0].legend(loc=4)
    ax[1].legend(loc=4)
    
    for i in range(2):
        ax[i].grid(zorder=0)
    
    plt.show();

# %%
__makeplot_power(fjz, f1z, f2z)

# %% [markdown]
# ## Test

# %%
# !ls /home/andbro/kilauea-data/sagnac_frequency/
# Out:
# 20230331.pkl			       RZ_20230407.pkl
# 20230401.pkl			       RZ_20230408.pkl
# 20230402.pkl			       test_hilbert_lin.pkl
# 20230407.pkl			       test_hilbert_multi.pkl
# 20230408.pkl			       test_hilbert_notaper.pkl
# 20230409.pkl			       test_hilbert.pkl
# 20230410.pkl			       test_hilbert_U.pkl
# F1V_20230407.pkl		       test_hilbert_wide.pkl
# F4V_20230407.pkl		       test_multi_100.pkl
# FJZ_20230407_demean_taper.pkl	       test_multiperio.pkl
# FJZ_20230407_hilbert_120.pkl	       test_multitaper_hilbert_n2.pkl
# FJZ_20230407_lineardetrend.pkl	       test_multitaper_hilbert_n4.pkl
# FJZ_20230407multitaper_hilbert.pkl     test_multitaper_hilbert_n6.pkl
# FJZ_20230407_multitaper.pkl	       test_multitaper_hilbert_n8.pkl
# FJZ_20230407_nopresprocessing.pkl      test_multitaper_hilbert.pkl
# FJZ_20230407_overlap60.pkl	       test_perio_1200_0.pkl
# FJZ_20230407.pkl		       test_perio_120_0.pkl
# hilbert_60			       test_perio_180_0.pkl
# hilbert_60_RU			       test_perio_20_0_chirp.pkl
# hilbert_60_RU_median		       test_perio_20_0.pkl
# hilbert_60_RU_multi		       test_perio_240_0.pkl
# hilbert_60_RZ			       test_perio_300_0.pkl
# hilbert_60_tilt			       test_perio_300_100.pkl
# mono				       test_perio_30_0.pkl
# mono_hilbert_10000.pkl		       test_perio_360_0.pkl
# mono_hilbert_10000.png		       test_perio_360_100.pkl
# mono_hilbert_multitaper_10000.pkl      test_perio_420_0.pkl
# mono_hilbert_multitaper_10000.png      test_perio_420_100.pkl
# mono_multitaper_10000.pkl	       test_perio_480_0.pkl
# mono_multitaper_10000.png	       test_perio_480_100.pkl
# mono_spectrogram_multitaper_10000.pkl  test_perio_540_0.pkl
# mono_spectrogram_multitaper_10000.png  test_perio_540_100.pkl
# multiperio_1200			       test_perio_600_0_chirp.pkl
# multiperio_180			       test_perio_600_0.pkl
# multiperio_300			       test_perio_600_100.pkl
# multiperio_60			       test_perio_60_0_chirp.pkl
# perio_100			       test_perio_60_0.pkl
# perio_1200			       test_perio.pkl
# perio_1200_tilt			       test.pkl
# perio_180			       test_welch.pkl
# perio_60			       welch_100

# %%
def __load_data2(config):
    
    net, sta, loc, cha = config['seed'].split(".")
    
    t1 = date.fromisoformat(str(config['tbeg'].date))
    t2 = date.fromisoformat(str(config['tend'].date))

    df = DataFrame()
    for dat in date_range(t1,t2):
        file = cha+"_"+str(dat)[:10].replace("-","")+"_hilbert_120.pkl"

        try:
            df0 = read_pickle(config['datapath']+file)
            df = concat([df, df0])
        except:
            print(f"error for {config['datapath']}{file}")
            
    return df

# %%
config['seed'] = "BW.DROMY..FJZ"
fjz2 = __load_data2(config)

# %%
plt.plot(fjz.times_mjd, fjz.freqs)
plt.plot(fjz2.times_mjd, fjz2.freqs, alpha=0.8)

# %%
plt.plot(fjz2.times_mjd, fjz2.freqs - fjz.freqs)

# %%
from obspy import read

stt = read(config['datapath']+"FJZ_powermeter.mseed")
stt.plot()
