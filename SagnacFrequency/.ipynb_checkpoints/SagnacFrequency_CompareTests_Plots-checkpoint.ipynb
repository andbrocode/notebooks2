# %% [markdown]
# ## Compute Sagnac Frequency - Plotting

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt

from datetime import datetime, date
from pandas import DataFrame, read_pickle, date_range, concat, read_csv
from obspy import UTCDateTime

# %% [markdown]
# ## Configurations

# %%
config = {}

config['seed'] = "BW.DROMY..FJZ"


config['tbeg'] = UTCDateTime("2023-04-07 00:00")
config['tend'] = UTCDateTime("2023-04-07 00:00")

config['datapath'] = "/home/andbro/kilauea-data/sagnac_frequency/tests/"

# %%
# !ls /home/andbro/kilauea-data/sagnac_frequency/tests
# Out:
# FJZ_20230407.pkl  OLD  RZ_20230407_test10.pkl

# %% [markdown]
# Description of Tests:
#
# - test10: no preprocessing (= no detrend, no taper, no filter)
# - test11: no taper
# - test12: no taper, no filter

# %%
config['tests'] = [
#     'demean_taper',
#     'hilbert_120',
#     'lineardetrend',
#     'multitaper_hilbert',
#     'multitaper',
#     'overlap60',
    'test10',
#     'test11',
#     'test12',
]

# %% [markdown]
# ## Load Data

# %%
def __load_data(config):
    
    net, sta, loc, cha = config['seed'].split(".")
    
    t1 = date.fromisoformat(str(config['tbeg'].date))
    t2 = date.fromisoformat(str(config['tend'].date))

    df = DataFrame()
    for dat in date_range(t1,t2):
        file = cha+"_"+str(dat)[:10].replace("-","")+".pkl"

        try:
            df0 = read_pickle(config['datapath']+file)
            df = concat([df, df0])
        except:
            print(f"error for {config['datapath']}{file}")
            
    return df

# %%
config['seed'] = "BW.DROMY..FJZ"
fjz = __load_data(config)

# %%
def __load_data_tests(config, test):
    
    net, sta, loc, cha = config['seed'].split(".")
    
    t1 = date.fromisoformat(str(config['tbeg'].date))
    t2 = date.fromisoformat(str(config['tend'].date))

    df = DataFrame()
    
    for dat in date_range(t1,t2):
        
        file = "R"+cha[-1]+"_"+str(dat)[:10].replace("-","")+"_"+f"{test}.pkl"

        try:
            df0 = read_pickle(config['datapath']+file)
            df = concat([df, df0])
        except:
            print(f"error for {config['datapath']}{file}")

    return df

# %%
tests = []

for test in config['tests']:
    tmp = __load_data_tests(config, test)
    tests.append(tmp)
# Out:
# error for /home/andbro/kilauea-data/sagnac_frequency/tests/RZ_20230407_test11.pkl
# error for /home/andbro/kilauea-data/sagnac_frequency/tests/RZ_20230407_test12.pkl

# %%
# Out:
# 0       60041.000347
# 1       60041.001042
# 2       60041.001736
# 3       60041.002431
# 4       60041.003125
#             ...
# 1435    60041.996875
# 1436    60041.997569
# 1437    60041.998264
# 1438    60041.998958
# 1439    60041.999653
# Name: times_mjd, Length: 1440, dtype: float64

# %% [markdown]
# ## Plot Frequency

# %%
fig, ax = plt.subplots(2,1,figsize =(15,8), sharex=True)

ax[0].plot(fjz.times_mjd, fjz.freqs, color="k", label="orig")

for i, test_name in enumerate(config['tests']):
    ax[0].plot(tests[i].times_mjd, tests[i].freqs, label=test_name)

ax[0].legend()
ax[0].set_ylim(553.455, 553.475)


for i, test_name in enumerate(config['tests']):
    ax[1].plot(tests[i].times_mjd, tests[i].freqs-fjz.freqs, label=test_name)
    
ax[0].ticklabel_format(useOffset=False, style='plain')
ax[1].ticklabel_format(useOffset=False, style='plain')

ax[1].set_xlabel("Time (MJD)", fontsize=14)
ax[0].set_ylabel("Beat Note (Hz)", fontsize=14)
ax[1].set_ylabel("Difference (Hz)", fontsize=14)

plt.show();
