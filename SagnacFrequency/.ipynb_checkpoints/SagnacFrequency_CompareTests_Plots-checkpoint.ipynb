# %% [markdown]
# ## Compute Sagnac Frequency - Plotting

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt

from datetime import datetime, date
from pandas import DataFrame, read_pickle, date_range, concat, read_csv
from obspy import UTCDateTime

# %% [markdown]
# ## Configurations

# %%
config = {}

config['seed'] = "BW.DROMY..FJZ"


config['tbeg'] = UTCDateTime("2023-04-07 00:00")
config['tend'] = UTCDateTime("2023-04-07 00:00")

config['datapath'] = "/home/andbro/kilauea-data/sagnac_frequency/tests/"

# %%
# !ls /home/andbro/kilauea-data/sagnac_frequency/tests
# Out:
# FJZ_20230407_demean_taper.pkl	     FJZ_20230407_multitaper.pkl
# FJZ_20230407_hilbert_120.pkl	     FJZ_20230407_nopresprocessing.pkl
# FJZ_20230407_lineardetrend.pkl	     FJZ_20230407_overlap60.pkl
# FJZ_20230407_multitaper_hilbert.pkl  FJZ_20230407.pkl

# %%
config['tests'] = [
    'demean_taper',
    'hilbert_120',
    'lineardetrend',
    'multitaper_hilbert',
    'multitaper',
    'nopresprocessing',
    'overlap60',
]

# %% [markdown]
# ## Load Data

# %%
def __load_data(config):
    
    net, sta, loc, cha = config['seed'].split(".")
    
    t1 = date.fromisoformat(str(config['tbeg'].date))
    t2 = date.fromisoformat(str(config['tend'].date))

    df = DataFrame()
    for dat in date_range(t1,t2):
        file = cha+"_"+str(dat)[:10].replace("-","")+".pkl"

        try:
            df0 = read_pickle(config['datapath']+file)
            df = concat([df, df0])
        except:
            print(f"error for {config['datapath']}{file}")
            
    return df

# %%
config['seed'] = "BW.DROMY..FJZ"
fjz = __load_data(config)

# %%
def __load_data_tests(config, test):
    
    net, sta, loc, cha = config['seed'].split(".")
    
    t1 = date.fromisoformat(str(config['tbeg'].date))
    t2 = date.fromisoformat(str(config['tend'].date))

    df = DataFrame()
    
    for dat in date_range(t1,t2):
        
        file = cha+"_"+str(dat)[:10].replace("-","")+"_"+f"{test}.pkl"

        try:
            df0 = read_pickle(config['datapath']+file)
            df = concat([df, df0])
        except:
            print(f"error for {config['datapath']}{file}")

    return df

# %%
tests = []

for test in config['tests']:
    tmp = __load_data_tests(config, test)
    tests.append(tmp)

# %% [markdown]
# ## Plot Frequency

# %%
tests
# Out:
# [         times_utc     times_mjd       freqs       hmhw        psd_max
#  0     1.680826e+09  60041.000347  553.470643  16.974225  171937.003681
#  1     1.680826e+09  60041.001042  553.470504  16.632859  171900.300479
#  2     1.680826e+09  60041.001736  553.470609  16.610594  171774.631126
#  3     1.680826e+09  60041.002431  553.470676  16.334303  171928.040914
#  4     1.680826e+09  60041.003125  553.470763  13.639193  171896.685501
#  ...            ...           ...         ...        ...            ...
#  1435  1.680912e+09  60041.996875  553.465075   8.542178  205486.256241
#  0     1.680826e+09  60041.000347  0.004768  1.626848e+14  4.766751e+16
#  1     1.680826e+09  60041.001042  0.004768  1.626752e+14  4.766447e+16
#  2     1.680826e+09  60041.001736  0.004768  1.626720e+14  4.766364e+16
#  3     1.680826e+09  60041.002431  0.004768  1.626603e+14  4.766028e+16
#  4     1.680826e+09  60041.003125  0.004768  1.626652e+14  4.766183e+16
#  ...            ...           ...       ...           ...           ...
#  1435  1.680912e+09  60041.996875  0.004768  1.577212e+14  4.620086e+16
#  1436  1.680912e+09  60041.997569  0.004768  1.577285e+14  4.620315e+16
#  1437  1.680912e+09  60041.998264  0.004768  1.577130e+14  4.619857e+16
#  1438  1.680912e+09  60041.998958  0.004768  1.577176e+14  4.619983e+16
#  1439  1.680912e+09  60041.999653  0.004768  1.577053e+14  4.619633e+16
#
#  [1440 rows x 5 columns],
#           times_utc     times_mjd       freqs       hmhw        psd_max
#  0     1.680826e+09  60041.000347  553.470643  16.974252  191058.137340
#  1     1.680826e+09  60041.001042  553.470505  16.632825  190986.219268
#  2     1.680826e+09  60041.001736  553.470610  16.610683  190887.828754
#  3     1.680826e+09  60041.002431  553.470676  16.334298  191037.181014
#  4     1.680826e+09  60041.003125  553.470763  13.639248  190984.078728
#  ...            ...           ...         ...        ...            ...
#  1435  1.680912e+09  60041.996875  553.465074   8.542124  228318.519930
#  1436  1.680912e+09  60041.997569  553.465121   8.931064  228399.279736
#  1437  1.680912e+09  60041.998264  553.465484   9.121926  228326.176384
#  1438  1.680912e+09  60041.998958  553.465262   9.834886  228319.776164
#  1439  1.680912e+09  60041.999653  553.465242  11.122499  228274.012942
#
#  [1440 rows x 5 columns],
#           times_utc     times_mjd       freqs      hmhw        psd_max
#  0     1.680826e+09  60041.000347  553.470984  0.005085  171870.311097
#  1     1.680826e+09  60041.001042  553.470781  0.005718  171778.790133
#  2     1.680826e+09  60041.001736  553.470721  0.004830  171717.850342
#  3     1.680826e+09  60041.002431  553.470719  0.004377  171846.832986
#  4     1.680826e+09  60041.003125  553.470806  0.004851  171795.664582
#  ...            ...           ...         ...       ...            ...
#  1435  1.680912e+09  60041.996875  553.465187  0.006195  205454.867362
#  1436  1.680912e+09  60041.997569  553.465098  0.006053  205519.057749
#  1437  1.680912e+09  60041.998264  553.465189  0.005849  205506.260652
#  1438  1.680912e+09  60041.998958  553.465167  0.005189  205444.691424
#  1439  1.680912e+09  60041.999653  553.465088  0.004098  205404.850319
#
#  [1440 rows x 5 columns]]

# %%
plt.figure(figsize = (15, 5))

plt.plot(fjz.times_mjd, fjz.freqs, color="k", label="orig")

for i, test_name in enumerate(config['tests']):
    plt.plot(tests[i].times_mjd, tests[i].freqs, label=test_name)

plt.legend()
plt.ylim(553.455, 553.475)
# Out:
# (553.455, 553.475)
