# %%
import obspy

from andbro__querrySeismoData import __querrySeismoData

# %%
tbeg = obspy.UTCDateTime("2021-08-03 12:00")
tend = obspy.UTCDateTime("2021-08-03 14:00")

## Paramter Settings
user_params={
             'seed_id': ["BW.ROMY..BJU", "BW.ROMY..BJw"],
             'repos': 'george',
             'datapath': None,
             'tbeg': tbeg,
             'tend': tend,
             'set_filter': 'n'
            }

# %%
path = '/import/freenas-ffb-01-data/romy_archive/2021/BW/ROMY/'

# st1 = obspy.read(path+"BJU.D/BW.ROMY..BJU.D.2021.197")
# st1 += obspy.read("/import/freenas-ffb-01-data/romy_archive/2021/BW/TROMY/MAE.D/BW.TROMY..MAE.D.2021.197")


u, inv0 = __querrySeismoData(    
                            seed_id=user_params.get("seed_id")[0],
                            starttime=user_params.get("tbeg"),
                            endtime=user_params.get("tend"),
                            repository=user_params.get("repos"),
                            path=user_params.get("datapath"),
                            restitute=True,
                            detail=None,
                            )

w, inv0 = __querrySeismoData(    
                            seed_id=user_params.get("seed_id")[1],
                            starttime=user_params.get("tbeg"),
                            endtime=user_params.get("tend"),
                            repository=user_params.get("repos"),
                            path=user_params.get("datapath"),
                            restitute=True,
                            detail=None,
                            )
# Out:
# Coordinates could not be attached to Inventory!

# %%
u.plot();
w.plot();

# %%
from andbro__makeplot_trace_spectrum import __makeplot_trace_and_spectrum

# %%
__makeplot_trace_and_spectrum(u[0], fmax=0.01);
__makeplot_trace_and_spectrum(w[0], fmax=0.01);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7277be95dadc> in <module>
# ----> 1 __makeplot_trace_and_spectrum(u[0], fmax=0.01);
#       2 __makeplot_trace_and_spectrum(w[0], fmax=0.01);
#
# ~/anaconda3/lib/python3.7/site-packages/andbro__makeplot_trace_spectrum.py in __makeplot_trace_and_spectrum(trace_in, timeaxis, fmax, grid, axis_scale, smoothing, fulloutput)
#     110
#     111     ## calculate smoothed spectrum
# --> 112     if smoothing%2 == 0:
#     113         smoothing -= 1
#     114     asd_med = signal.medfilt(asd, kernel_size=smoothing)
#
# TypeError: unsupported operand type(s) for %: 'NoneType' and 'int'

# %%
from andbro__makeplot_traces_spectrogram import __makeplot_traces_spectrogram

# %%
__makeplot_traces_spectrogram(u, u, 5.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-5af3cfb0c4d8> in <module>
# ----> 1 __makeplot_traces_spectrogram(u, u, 5.0)
#
# ~/anaconda3/lib/python3.7/site-packages/andbro__makeplot_traces_spectrogram.py in __makeplot_traces_spectrogram(st1, st2, f_upper, spec_param, ylabel)
#     116     ax[0].legend(loc="upper right")
#     117
# --> 118     im1 = ax[1].imshow(Sxx1[:][:idx1], aspect='auto', cmap='viridis', origin='lower', extent=[min(times1),max(times1),min(freqs1), freqs1[idx1]])
#     119
#     120     cbaxes1 = fig.add_axes([0.92, 0.52, 0.01, 0.16])
#
# IndexError: index 257 is out of bounds for axis 0 with size 257
