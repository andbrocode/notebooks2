# %%
from obspy import UTCDateTime
from andbro__querrySeismoData import __querrySeismoData

seed_id = input("Enter station code (e.g. BW.ROMY.10.BJZ):  ")
repos   = input("Enter station code ('local', 'george', 'archive', 'online'):  ")
tbeg    = input("Enter starttime (e.g. 2021-03-04 18:35):  ")
tend    = input("Enter endtime (e.g. 2021-03-04 19:35):  ")

# tbeg = UTCDateTime("2021-03-04 18:35")
# tend = UTCDateTime("2021-03-04 19:35")
# Out:
# Enter station code (e.g. BW.ROMY.10.BJZ):  BW.ROMY.10.BJZ
# Enter station code ('local', 'george', 'archive', 'online'):  george
# Enter starttime (e.g. 2021-03-04 18:35):  2021-02-22
# Enter endtime (e.g. 2021-03-04 19:35):  2021-02-23

# %%
st, inv = __querrySeismoData(    
                            seed_id=seed_id,
                            starttime=tbeg,
                            endtime=tend,
                            where=repos,
                            path=None,
                            restitute=True,
                            detail=None,
                             )

st.plot();

# %%
# f_upper = 0.1

# st.filter('lowpass', freq=f_upper, corners=8, zerophase=True)

# st.plot();
