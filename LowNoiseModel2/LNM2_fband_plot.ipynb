# %% [markdown]
# # Hourly PSDS - IROMY | WROMY | ROMY

# %% [markdown]
# ## Load Libraries

# %%
from obspy import UTCDateTime
from scipy.signal import welch
from numpy import log10, zeros, pi, append, linspace, mean, median, array, where, transpose, shape, histogram, arange, append
from numpy import logspace, linspace, log, log10, isinf, ones, nan, count_nonzero, sqrt, isnan
from pandas import DataFrame, concat, Series, date_range, read_csv, read_pickle
from tqdm import tqdm
from pathlib import Path

import os, sys
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# from andbro__store_as_pickle import __store_as_pickle

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'

# %% [markdown]
# ## Configurations

# %%
## ---------------------------------------

# name1 = "ROMY_U"
# name1 = "ROMY_V"
name1 = "ROMY_Z"

name2 = "FFBI"

# t1 ,t2 = "2023-09-23", "2023-10-23"

# %%
# ## ---------------------------------------

config = {}

## specify paths
config['path_to_figs'] = data_path+f"LNM2/figures/scatter/"

config['path_to_data'] = data_path+f"LNM2/data/"

# %% [markdown]
# ## Methods

# %%
dat1 = pd.read_pickle(config['path_to_data']+name1+".pkl")
dat2 = pd.read_pickle(config['path_to_data']+name2+".pkl")

# %%
def fit_above(x, y):

    from scipy.optimize import minimize
    import numpy as np

    def error_function_2(b, x, y):
        a = np.min((y - b) / x)
        return np.sum((y - a * x - b)**2)


    idx = np.argsort(x)
    x = x[idx]
    y = y[idx]
    x0, y0 = x[0] - 1, y[0]
    x -= x0
    y -= y0

    b = minimize(error_function_2, [0], args=(x, y)).x[0]

    a = np.max((y - b) / x)

    return a, b - a * x0 + y0

# %%
"""line fitting on log-log scale"""
def powerfit(x, y, xnew):
    k, m = np.polyfit(np.log(x), np.log(y), 1)
    return np.exp(m) * xnew**(k)
# Out:
# 'line fitting on log-log scale'

# %%
N_bands = dat1.shape[1] - 1

bands = dat1.keys()[1:]

for _n, band in enumerate(bands):

    # if not _n == 11:
    #     continue

    _dat1 = dat1.loc[:, ["dates", band]]
    _dat2 = dat2.loc[:, ["dates", band]]

    _df = pd.merge(left=_dat1, right=_dat2, how="inner", on="dates")

    _df.dropna(inplace=True)

    _df = _df[_df.iloc[:, 1] < 1e-15]
    _df = _df.reset_index(drop=True)


    # xx = _df.iloc[:, 1]
    # yy = _df.iloc[:, 2]

    if not _df.empty:

        fig = plt.figure()

        # ys = powerfit(xx, yy, xx)
        # plt.plot(xx, ys, color="tab:green", ls="--")

        plt.scatter(_df[f'{band}_x'], _df[f'{band}_y'], s=15, edgecolors="black", lw=0.5, zorder=2)

        plt.xscale("log")
        plt.yscale("log")

        plt.title(f"{name1.replace('_','-')} & {name2.replace('_','-')} | fc = {_df.keys()[1][:-2]} Hz")
        plt.ylabel(r"PSD (hPa$^2$ /Hz)")
        plt.xlabel(r"PSD (rad$^2$ /s$^2$ /Hz)")
        plt.grid(zorder=0, alpha=0.5)

        plt.ylim(1e-7, 1e1)
        plt.xlim(1e-23, 1e-15)

        plt.show();

        fig.savefig(config['path_to_figs']+f"{name1}/{str(_n).rjust(3, '0')}_{name1}_{name2}_{band}Hz.png", format="png", dpi=200, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.001 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.0016 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.002 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.0025 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.00315 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.004 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.005 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.0063 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.008 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.01 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.0125 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.016 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.02 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.025 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.0315 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.04 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.05 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.063 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.08 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.1 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.125 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.16 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.2 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.25 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.315 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.4 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.5 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.63 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 0.8 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)
# Text(0.5, 1.0, 'ROMY-Z & FFBI | fc = 1.0 Hz')
# Text(0, 0.5, 'PSD (hPa$^2$ /Hz)')
# Text(0.5, 0, 'PSD (rad$^2$ /s$^2$ /Hz)')
# (1e-07, 10.0)
# (1e-23, 1e-15)

# %%
import scipy



x = np.arange(10).astype(float)
y = x * 2 + 3 + 3 * np.random.rand(len(x))

a, b = fit_above(x, y)

plt.plot(x, y, 'o')
plt.plot(x, a*x + b, '-')
plt.show()

# %%
print(xx, yy)
ys = powerfit(xx, yy, xx)

plt.scatter(xx, yy)
plt.plot(xx, ys)
plt.xscale("log")
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(xx, yy)
#       2 ys = powerfit(xx, yy, xx)
#       4 plt.scatter(xx, yy)
#
# NameError: name 'xx' is not defined
