# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import obspy
import numpy as np

from andbro__get_seconds import __get_seconds

# %%
path_to_files = "/home/brotzer/Documents/ROMY/ROMY_Control/data/"


## resample every nth row
nth_row = 1

# %%
## read data

day1 = 16
day2 = 16

for j, i in enumerate(range(day1,day2+1)):
    
    df0 = pd.read_csv(path_to_files+f"202112{str(i).rjust(2,'0')}_control.txt")

    df0 = df0.iloc[::int(nth_row)]
    
    if j == 0:
        df = df0
    else:
        df = pd.concat([df, df0], ignore_index=True)

## add time axis
df['times'] = [__get_seconds(df.datetime[j], mode="of_year") for j in range(df.datetime.size)]


df
# Out:
#                   datetime    AC    DC      F0  ACmean  DCmean       times
# 0      2021-12-16T00:00:00  1.13  0.83  447.60   1.122   0.830  30240000.0
# 1      2021-12-16T00:00:01  1.14  0.84  448.00   1.123   0.830  30240001.0
# 2      2021-12-16T00:00:02  1.13  0.84  447.60   1.123   0.831  30240002.0
# 3      2021-12-16T00:00:03  1.14  0.83  447.60   1.123   0.830  30240003.0
# 4      2021-12-16T00:00:04  1.12  0.82  447.35   1.124   0.830  30240004.0
# ...                    ...   ...   ...     ...     ...     ...         ...
# 35897  2021-12-16T09:58:17  0.07  0.00     NaN   0.070   0.000  30275897.0
# 35898  2021-12-16T09:58:18  0.06  0.00     NaN   0.070   0.000  30275898.0
# 35899  2021-12-16T09:58:19  0.07  0.00     NaN   0.070   0.000  30275899.0
# 35900  2021-12-16T09:58:20  0.07  0.00     NaN   0.069   0.000  30275900.0
# 35901  2021-12-16T09:58:21  0.06  0.00     NaN   0.069   0.000  30275901.0
#
# [35902 rows x 7 columns]

# %%
def __makeplot_parameters(df, roll_length=500):
    
    N = 3
    font = 12
    
    scale_timeaxis = 3600
    
    fig, ax = plt.subplots(N,1,figsize=(15,8), sharex=True)
    
    timeaxis = np.array((df.times-df.times[0])/scale_timeaxis)
    
    ax[0].plot(timeaxis, df.F0.rolling(roll_length).mean(), color='darkred', zorder=2)
    ax[0].scatter(timeaxis, df.F0, s=0.5, color='grey', alpha=0.5, zorder=1)
    
    ax[1].plot(timeaxis, df.AC.rolling(roll_length).mean(), color='darkgreen', zorder=2)
    ax[1].scatter(timeaxis, df.AC, s=0.5, color='grey', alpha=0.5, zorder=1)
    
    ax[2].plot(timeaxis, df.DC.rolling(roll_length).mean(), color='darkblue', zorder=2)
    ax[2].scatter(timeaxis, df.DC, s=0.5, color='grey', alpha=0.5, zorder=1)
    
    
    ax[0].set_ylabel("F0 (Hz)", fontsize=font)
    ax[1].set_ylabel("AC (V)", fontsize=font)
    ax[2].set_ylabel("DC (V)", fontsize=font)
    if scale_timeaxis == 3600:
        ax[N-1].set_xlabel(f"Time UTC (hours) from {df.datetime[0][:10]} {df.datetime[0][11:16]}", fontsize=font)
    elif scale_timeaxis == 86400:
        ax[N-1].set_xlabel(f"Time UTC (days) from {df.datetime[0][:10]}", fontsize=font)

    
    for i in range(N):
        ax[i].set_xlim(np.array(timeaxis[0]), timeaxis[-1])
    
#     ax[2].set_xlim(8,9)
    
__makeplot_parameters(df, roll_length=3)

# %% [markdown]
# ## New Approach

# %%
def __load_CROMY(start, end, ring="RV"):
    
    from obspy import UTCDateTime
    from andbro__get_seconds import __get_seconds

    tbeg = UTCDateTime(start)
    tend = UTCDateTime(end)
    
    if tbeg.date.year != tend.date.year:
        print("Error: Not same years!")
    
    
    for j, date in enumerate(np.arange(tbeg.date,(tend+86400).date)):

        filename = f"{str(date).replace('-','')}_control.txt"
        
        path_to_files = f"/import/freenas-ffb-01-data/romy_archive/{str(date)[:4]}/BW/CROMY/{ring}/"
        
        df0 = pd.read_csv(path_to_files+filename)

        df0 = df0.iloc[::int(nth_row)]

        if j == 0:
            df = df0
        else:
            df = pd.concat([df, df0], ignore_index=True)

    ## add time axis
    df['times'] = [__get_seconds(df.datetime[j], mode="of_year") for j in range(df.datetime.size)]

    return df

# %%
def __cut_dataframe(df, starttime, endtime, column_name_of_total_seconds=None):
    
    from andbro__get_seconds import __get_seconds

    if column_name_of_total_seconds is not None:
        tbeg_sec = __get_seconds(starttime, mode="of_year")
        tend_sec = __get_seconds(endtime, mode="of_year")

        df = df[(df[column_name_of_total_seconds] >= tbeg_sec) & (df[column_name_of_total_seconds] <= tend_sec)]
    else:
        print("Error")
    
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
def __makeplot_parameters2(df, roll_length=50):
    
    N = 3
    font = 12
    timeaxis = np.array((df.times-df.times[0])/3600)

    
    ## plotting 
    
    fig, ax = plt.subplots(N,1,figsize=(15,8), sharex=True)
    
    
    ax[0].plot(timeaxis, df.F0.rolling(roll_length).mean(), color='darkred', zorder=2)
    
    ax[1].plot(timeaxis, df.AC.rolling(roll_length).mean(), color='darkgreen', zorder=2)
    
    ax[2].plot(timeaxis, df.DC.rolling(roll_length).mean(), color='darkblue', zorder=2)
    
    
    ax[0].set_ylabel("F0 (Hz)", fontsize=font)
    ax[1].set_ylabel("AC (V)", fontsize=font)
    ax[2].set_ylabel("DC (V)", fontsize=font)
    ax[N-1].set_xlabel(f"Time (hours) from {df.datetime[0][:10]} {df.datetime[0][11:]} UTC", fontsize=font)
    
    for i in range(N):
        ax[i].set_xlim(np.array(timeaxis[0]), timeaxis[-1])
        ax[i].grid(alpha=0.7, zorder=0, ls=":", color="grey")

    return fig

# %%
df = __load_CROMY("2021-12-15", "2021-12-23", ring="RV")
    
df
# Out:
# 20211215_control.txt
# 20211216_control.txt
# 20211217_control.txt
# 20211218_control.txt
# 20211219_control.txt
# 20211220_control.txt
# 20211221_control.txt
# 20211222_control.txt
# 20211223_control.txt
#                    datetime    AC    DC      F0  ACmean  DCmean       times
# 0       2021-12-15T00:00:00  1.12  0.84  447.35   1.114   0.837  30153600.0
# 1       2021-12-15T00:00:01  1.11  0.84  447.35   1.113   0.838  30153601.0
# 2       2021-12-15T00:00:02  1.12  0.85  447.35   1.113   0.838  30153602.0
# 3       2021-12-15T00:00:03  1.15  0.84  447.35   1.116   0.838  30153603.0
# 4       2021-12-15T00:00:04  1.13  0.83  446.93   1.117   0.839  30153604.0
# ...                     ...   ...   ...     ...     ...     ...         ...
# 732072  2021-12-23T11:39:58  1.57  1.06  447.35   1.525   1.054  30886798.0
# 732073  2021-12-23T11:39:59  1.52  1.06  447.35   1.527   1.054  30886799.0
# 732074  2021-12-23T11:40:00  1.51  1.05  447.60   1.527   1.054  30886800.0
# 732075  2021-12-23T11:40:01  1.53  1.06  447.35   1.527   1.054  30886801.0
# 732076  2021-12-23T11:40:02  1.53  1.07  447.35   1.528   1.056  30886802.0
#
# [732077 rows x 7 columns]

# %%
df_sel = __cut_dataframe(df, "2021-12-22 00:00", "2021-12-22 15:00", column_name_of_total_seconds="times")   
df_sel

fig = __makeplot_parameters2(df, roll_length=1)
# Out:
#                   datetime    AC    DC      F0  ACmean  DCmean       times
# 0      2021-12-22T00:00:00  1.50  1.06  447.35   1.512   1.053  30758400.0
# 1      2021-12-22T00:00:01  1.51  1.05  446.93   1.511   1.054  30758401.0
# 2      2021-12-22T00:00:02  1.51  1.06  447.35   1.511   1.055  30758402.0
# 3      2021-12-22T00:00:03  1.54  1.06  447.35   1.511   1.055  30758403.0
# 4      2021-12-22T00:00:04  1.51  1.06  447.35   1.511   1.055  30758404.0
# ...                    ...   ...   ...     ...     ...     ...         ...
# 53996  2021-12-22T14:59:56  1.50  1.06  447.35   1.518   1.058  30812396.0
# 53997  2021-12-22T14:59:57  1.51  1.06  447.60   1.518   1.057  30812397.0
# 53998  2021-12-22T14:59:58  1.53  1.06  447.60   1.518   1.057  30812398.0
# 53999  2021-12-22T14:59:59  1.51  1.06  447.35   1.518   1.057  30812399.0
# 54000  2021-12-22T15:00:00  1.51  1.06  447.35   1.518   1.058  30812400.0
#
# [54001 rows x 7 columns]
