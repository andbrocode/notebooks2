# %% [markdown]
# # ROMY Barometer - Statistic Plots

# %%
import os
import obspy as obs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from obspy import read_inventory

from andbro__read_sds import __read_sds

# %%
from functions.get_mean_promy_pressure import __get_mean_promy_pressure
from functions.get_mean_rmy_pressure import __get_mean_rmy_pressure

# %%
#%matplotlib tk

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
    bay_path = '/home/andbro/ontap-ffb-bay200/'
    lamont_path = '/home/andbro/lamont/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/import/ontap-ffb-bay200/'
    lamont_path = '/lamont/'
elif os.uname().nodename in ['lin-ffb-01', 'ambrym', 'hochfelln']:
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/import/ontap-ffb-bay200/'
    lamont_path = '/lamont/'

# %% [markdown]
# ## Configurations

# %%
config = {}

# output path for figures
config['path_to_figs'] = data_path+"romy_baro/figures/"

# path to data archive
# config['path_to_data'] = data_path+"romy_baro/data/"

# config['tbeg'] = obs.UTCDateTime("2024-03-01")
# config['tend'] = obs.UTCDateTime("2024-06-30")

# data with regression alternative
config['path_to_data'] = data_path+"romy_baro/data2/"

config['tbeg'] = obs.UTCDateTime("2024-01-01")
config['tend'] = obs.UTCDateTime("2024-07-31")

# %% [markdown]
# ## Load Data

# %%
def __load_data(tbeg, tend, path_to_data):

    from obspy import UTCDateTime
    from datetime import date
    from pandas import read_pickle, concat, DataFrame, date_range, to_datetime
    from tqdm.notebook import tqdm

    t1 = date.fromisoformat(str(UTCDateTime(tbeg).date))
    t2 = date.fromisoformat(str((UTCDateTime(tend)).date))

    df = DataFrame()
    for dat in tqdm(date_range(t1, t2)):
        # print(str(dat)[:10])
        file = f"RB_statistics_{str(dat)[:10]}.pkl"
        try:
            df0 = read_pickle(path_to_data+file)
            df = concat([df, df0])
        except Exception as e:
            print(e)
            print(f"error for {file}")

    # remove NaN from time column
    # df.dropna(subset=['time'], inplace=True)

    # reset the index column
    df.reset_index(inplace=True, drop=True)

    # add column for relative time in seconds
    df['time_sec'] = [(_t2 - _t1)/2 + _t1 for _t1, _t2 in zip(df.t1, df.t2)]

    return df

# %%
df = __load_data(config['tbeg'], config['tend'], config['path_to_data'])
# Out:
#   0%|          | 0/213 [00:00<?, ?it/s]
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-20.pkl'
# error for RB_statistics_2024-01-20.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-21.pkl'
# error for RB_statistics_2024-01-21.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-22.pkl'
# error for RB_statistics_2024-01-22.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-23.pkl'
# error for RB_statistics_2024-01-23.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-24.pkl'
# error for RB_statistics_2024-01-24.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-25.pkl'
# error for RB_statistics_2024-01-25.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-26.pkl'
# error for RB_statistics_2024-01-26.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-27.pkl'
# error for RB_statistics_2024-01-27.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-28.pkl'
# error for RB_statistics_2024-01-28.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-29.pkl'
# error for RB_statistics_2024-01-29.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-30.pkl'
# error for RB_statistics_2024-01-30.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-01-31.pkl'
# error for RB_statistics_2024-01-31.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-01.pkl'
# error for RB_statistics_2024-02-01.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-02.pkl'
# error for RB_statistics_2024-02-02.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-03.pkl'
# error for RB_statistics_2024-02-03.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-04.pkl'
# error for RB_statistics_2024-02-04.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-05.pkl'
# error for RB_statistics_2024-02-05.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-06.pkl'
# error for RB_statistics_2024-02-06.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-07.pkl'
# error for RB_statistics_2024-02-07.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-08.pkl'
# error for RB_statistics_2024-02-08.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-09.pkl'
# error for RB_statistics_2024-02-09.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-10.pkl'
# error for RB_statistics_2024-02-10.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-11.pkl'
# error for RB_statistics_2024-02-11.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-12.pkl'
# error for RB_statistics_2024-02-12.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-13.pkl'
# error for RB_statistics_2024-02-13.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-14.pkl'
# error for RB_statistics_2024-02-14.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-15.pkl'
# error for RB_statistics_2024-02-15.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-16.pkl'
# error for RB_statistics_2024-02-16.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-17.pkl'
# error for RB_statistics_2024-02-17.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-18.pkl'
# error for RB_statistics_2024-02-18.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-19.pkl'
# error for RB_statistics_2024-02-19.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-20.pkl'
# error for RB_statistics_2024-02-20.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-21.pkl'
# error for RB_statistics_2024-02-21.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-22.pkl'
# error for RB_statistics_2024-02-22.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-23.pkl'
# error for RB_statistics_2024-02-23.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-24.pkl'
# error for RB_statistics_2024-02-24.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-25.pkl'
# error for RB_statistics_2024-02-25.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-26.pkl'
# error for RB_statistics_2024-02-26.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-27.pkl'
# error for RB_statistics_2024-02-27.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-28.pkl'
# error for RB_statistics_2024-02-28.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-02-29.pkl'
# error for RB_statistics_2024-02-29.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-01.pkl'
# error for RB_statistics_2024-03-01.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-02.pkl'
# error for RB_statistics_2024-03-02.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-03.pkl'
# error for RB_statistics_2024-03-03.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-04.pkl'
# error for RB_statistics_2024-03-04.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-05.pkl'
# error for RB_statistics_2024-03-05.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-06.pkl'
# error for RB_statistics_2024-03-06.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-07.pkl'
# error for RB_statistics_2024-03-07.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-08.pkl'
# error for RB_statistics_2024-03-08.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-09.pkl'
# error for RB_statistics_2024-03-09.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-10.pkl'
# error for RB_statistics_2024-03-10.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-11.pkl'
# error for RB_statistics_2024-03-11.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-12.pkl'
# error for RB_statistics_2024-03-12.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-13.pkl'
# error for RB_statistics_2024-03-13.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-14.pkl'
# error for RB_statistics_2024-03-14.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-15.pkl'
# error for RB_statistics_2024-03-15.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-16.pkl'
# error for RB_statistics_2024-03-16.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-17.pkl'
# error for RB_statistics_2024-03-17.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-18.pkl'
# error for RB_statistics_2024-03-18.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-19.pkl'
# error for RB_statistics_2024-03-19.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-20.pkl'
# error for RB_statistics_2024-03-20.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-21.pkl'
# error for RB_statistics_2024-03-21.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-22.pkl'
# error for RB_statistics_2024-03-22.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-23.pkl'
# error for RB_statistics_2024-03-23.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-24.pkl'
# error for RB_statistics_2024-03-24.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-25.pkl'
# error for RB_statistics_2024-03-25.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-26.pkl'
# error for RB_statistics_2024-03-26.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-27.pkl'
# error for RB_statistics_2024-03-27.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-28.pkl'
# error for RB_statistics_2024-03-28.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-29.pkl'
# error for RB_statistics_2024-03-29.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-30.pkl'
# error for RB_statistics_2024-03-30.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-03-31.pkl'
# error for RB_statistics_2024-03-31.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-01.pkl'
# error for RB_statistics_2024-04-01.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-02.pkl'
# error for RB_statistics_2024-04-02.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-03.pkl'
# error for RB_statistics_2024-04-03.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-04.pkl'
# error for RB_statistics_2024-04-04.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-05.pkl'
# error for RB_statistics_2024-04-05.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-06.pkl'
# error for RB_statistics_2024-04-06.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-07.pkl'
# error for RB_statistics_2024-04-07.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-08.pkl'
# error for RB_statistics_2024-04-08.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-09.pkl'
# error for RB_statistics_2024-04-09.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-10.pkl'
# error for RB_statistics_2024-04-10.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-11.pkl'
# error for RB_statistics_2024-04-11.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-12.pkl'
# error for RB_statistics_2024-04-12.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-13.pkl'
# error for RB_statistics_2024-04-13.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-14.pkl'
# error for RB_statistics_2024-04-14.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-15.pkl'
# error for RB_statistics_2024-04-15.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-16.pkl'
# error for RB_statistics_2024-04-16.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-17.pkl'
# error for RB_statistics_2024-04-17.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-18.pkl'
# error for RB_statistics_2024-04-18.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-19.pkl'
# error for RB_statistics_2024-04-19.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-20.pkl'
# error for RB_statistics_2024-04-20.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-21.pkl'
# error for RB_statistics_2024-04-21.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-22.pkl'
# error for RB_statistics_2024-04-22.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-23.pkl'
# error for RB_statistics_2024-04-23.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-24.pkl'
# error for RB_statistics_2024-04-24.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-25.pkl'
# error for RB_statistics_2024-04-25.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-26.pkl'
# error for RB_statistics_2024-04-26.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-27.pkl'
# error for RB_statistics_2024-04-27.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-28.pkl'
# error for RB_statistics_2024-04-28.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-29.pkl'
# error for RB_statistics_2024-04-29.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-04-30.pkl'
# error for RB_statistics_2024-04-30.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-01.pkl'
# error for RB_statistics_2024-05-01.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-02.pkl'
# error for RB_statistics_2024-05-02.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-03.pkl'
# error for RB_statistics_2024-05-03.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-04.pkl'
# error for RB_statistics_2024-05-04.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-05.pkl'
# error for RB_statistics_2024-05-05.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-06.pkl'
# error for RB_statistics_2024-05-06.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-07.pkl'
# error for RB_statistics_2024-05-07.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-08.pkl'
# error for RB_statistics_2024-05-08.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-09.pkl'
# error for RB_statistics_2024-05-09.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-10.pkl'
# error for RB_statistics_2024-05-10.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-11.pkl'
# error for RB_statistics_2024-05-11.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-12.pkl'
# error for RB_statistics_2024-05-12.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-13.pkl'
# error for RB_statistics_2024-05-13.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-14.pkl'
# error for RB_statistics_2024-05-14.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-15.pkl'
# error for RB_statistics_2024-05-15.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-16.pkl'
# error for RB_statistics_2024-05-16.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-17.pkl'
# error for RB_statistics_2024-05-17.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-18.pkl'
# error for RB_statistics_2024-05-18.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-19.pkl'
# error for RB_statistics_2024-05-19.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-20.pkl'
# error for RB_statistics_2024-05-20.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-21.pkl'
# error for RB_statistics_2024-05-21.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-22.pkl'
# error for RB_statistics_2024-05-22.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-23.pkl'
# error for RB_statistics_2024-05-23.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-24.pkl'
# error for RB_statistics_2024-05-24.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-25.pkl'
# error for RB_statistics_2024-05-25.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-26.pkl'
# error for RB_statistics_2024-05-26.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-27.pkl'
# error for RB_statistics_2024-05-27.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-28.pkl'
# error for RB_statistics_2024-05-28.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-29.pkl'
# error for RB_statistics_2024-05-29.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-30.pkl'
# error for RB_statistics_2024-05-30.pkl
# [Errno 2] No such file or directory: '/home/andbro/kilauea-data/romy_baro/data2/RB_statistics_2024-05-31.pkl'
# error for RB_statistics_2024-05-31.pkl

# %%
df = df[df.status == False]

# %%
df.keys()
# Out:
# Index(['t1', 't2', 'status', 'shift_PP_N', 'shift_PP_E', 'shift_PP_Z',
#        'shift_HP_N', 'shift_HP_E', 'shift_HP_Z', 'cmax_PP_N', 'cmax_PP_E',
#        'cmax_PP_Z', 'cmax_HP_N', 'cmax_HP_E', 'cmax_HP_Z', 'r_z', 'r_n', 'r_e',
#        'a_z', 'a_n', 'a_e', 'b_z', 'b_n', 'b_e', 'reg_r_z', 'reg_r_n',
#        'reg_r_e', 'reg_a_z', 'reg_a_n', 'reg_a_e', 'reg_b_z', 'reg_b_n',
#        'reg_b_e', 'wvel', 'wdir', 'time_sec'],
#       dtype='object')

# %%
for k in ["shift_PP_N", "shift_PP_E", "shift_HP_N", "shift_HP_E"]:
    df[k] = df[k]/20 # 20 Hz sampling rate

# %%
df
# Out:
#                 t1            t2  status  shift_PP_N  shift_PP_E  shift_PP_Z  \
# 7     1.704105e+09  1.704112e+09   False        0.00        0.00         0.0
# 11    1.704127e+09  1.704134e+09   False        0.00        0.00         0.0
# 12    1.704132e+09  1.704139e+09   False        0.00        0.00         0.0
# 42    1.704305e+09  1.704312e+09   False       14.10      127.05       144.0
# 288   1.717216e+09  1.717223e+09   False      -10.00      -10.10      -203.0
# ...            ...           ...     ...         ...         ...         ...
# 903   1.720759e+09  1.720766e+09   False      -27.35      -27.40       527.0
# 1052  1.721617e+09  1.721624e+09   False        0.00        0.00         0.0
# 1080  1.721779e+09  1.721786e+09   False        0.00        0.00         0.0
# 1098  1.721882e+09  1.721889e+09   False        0.00        0.00         0.0
# 1167  1.722276e+09  1.722283e+09   False     -101.55     -101.50      1869.0
#
#       shift_HP_N  shift_HP_E  shift_HP_Z  cmax_PP_N  ...  reg_r_e  \
# 7           0.00        0.00         0.0   0.000000  ...     0.00
# 11          0.00        0.00         0.0   0.000000  ...     0.00
# 12          0.00        0.00         0.0   0.000000  ...     0.00
# 42          0.70      141.30       -38.0  -0.652810  ...   -29.98
# 288       -30.15      -30.25      -605.0   0.568384  ...     1.68
# ...          ...         ...         ...        ...  ...      ...
# 903       -44.45      -44.10       202.0   0.586096  ...     5.53
# 1052        0.00        0.00         0.0   0.000000  ...     0.00
# 1080        0.00        0.00         0.0   0.000000  ...     0.00
# 1098        0.00        0.00         0.0   0.000000  ...     0.00
# 1167     -110.60      237.90      1669.0   0.244111  ...    -1.58
#
#            reg_a_z       reg_a_n       reg_a_e       reg_b_z       reg_b_n  \
# 7     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 11    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 12    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 42    6.426213e-09 -3.467283e-08  2.031201e-04 -1.333345e-08  1.913943e-07
# 288   5.438377e-05  2.166065e-05 -3.440544e-05 -2.464492e-05 -1.071896e-05
# ...            ...           ...           ...           ...           ...
# 903  -1.091965e-07  3.870039e-08  5.872205e-08 -1.038186e-07 -1.442339e-07
# 1052  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1080  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1098  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1167  5.793858e-09  1.155432e-07 -8.390852e-08  2.832836e-09 -5.336432e-08
#
#            reg_b_e  wvel   wdir      time_sec
# 7     0.000000e+00   2.5  255.0  1.704109e+09
# 11    0.000000e+00   2.5  255.0  1.704130e+09
# 12    0.000000e+00   2.5  255.0  1.704136e+09
# 42   -2.850502e-05   4.5  255.0  1.704308e+09
# 288   1.683738e-05   3.5  265.0  1.717220e+09
# ...            ...   ...    ...           ...
# 903   7.856993e-09   0.5  255.0  1.720762e+09
# 1052  0.000000e+00   1.5  275.0  1.721621e+09
# 1080  0.000000e+00   1.5  275.0  1.721783e+09
# 1098  0.000000e+00   0.5   85.0  1.721885e+09
# 1167  5.622060e-08   0.5   75.0  1.722280e+09
#
# [69 rows x 36 columns]

# %%
# select only those with CC > 0.7
cc_threshold = 0.7
dfN = df[(df.cmax_PP_N.abs() > cc_threshold) | (df.cmax_HP_N.abs() > cc_threshold)]
dfE = df[(df.cmax_PP_E.abs() > cc_threshold) | (df.cmax_HP_E.abs() > cc_threshold)]
dfZ = df[(df.cmax_PP_Z.abs() > cc_threshold) | (df.cmax_HP_Z.abs() > cc_threshold)]

cc_shift_threshold = 120
dfN = dfN[(dfN.shift_PP_N.abs() < cc_shift_threshold) | (dfN.shift_HP_N.abs() < cc_shift_threshold)]
dfE = dfE[(dfE.shift_PP_E.abs() < cc_shift_threshold) | (dfE.shift_HP_E.abs() < cc_shift_threshold)]
dfZ = dfZ[(dfZ.shift_PP_Z.abs() < cc_shift_threshold) | (dfZ.shift_HP_Z.abs() < cc_shift_threshold)]

# print(dfN.shape, dfE.shape, dfN.shape)

# select only those with VR > 50 %
# vr_threshold = 40
# dfN = df[(df.r_n > vr_threshold)]
# dfE = df[(df.r_e > vr_threshold)]
# dfZ = df[(df.r_z > vr_threshold)]

# %%
dfZ, dfN, dfE
# Out:
# (              t1            t2  status  shift_PP_N  shift_PP_E  shift_PP_Z  \
#  42  1.704305e+09  1.704312e+09   False        14.1      127.05       144.0
#
#      shift_HP_N  shift_HP_E  shift_HP_Z  cmax_PP_N  ...  reg_r_e       reg_a_z  \
#  42         0.7       141.3       -38.0   -0.65281  ...   -29.98  6.426213e-09
#
#           reg_a_n   reg_a_e       reg_b_z       reg_b_n   reg_b_e  wvel   wdir  \
#  42 -3.467283e-08  0.000203 -1.333345e-08  1.913943e-07 -0.000029   4.5  255.0
#
#          time_sec
#  42  1.704308e+09
#
#  [1 rows x 36 columns],
#                t1            t2  status  shift_PP_N  shift_PP_E  shift_PP_Z  \
#  42  1.704305e+09  1.704312e+09   False        14.1      127.05       144.0
#
#      shift_HP_N  shift_HP_E  shift_HP_Z  cmax_PP_N  ...  reg_r_e       reg_a_z  \
#  42         0.7       141.3       -38.0   -0.65281  ...   -29.98  6.426213e-09
#
#           reg_a_n   reg_a_e       reg_b_z       reg_b_n   reg_b_e  wvel   wdir  \
#  42 -3.467283e-08  0.000203 -1.333345e-08  1.913943e-07 -0.000029   4.5  255.0
#
#          time_sec
#  42  1.704308e+09
#
#  [1 rows x 36 columns],
#  Empty DataFrame
#  Columns: [t1, t2, status, shift_PP_N, shift_PP_E, shift_PP_Z, shift_HP_N, shift_HP_E, shift_HP_Z, cmax_PP_N, cmax_PP_E, cmax_PP_Z, cmax_HP_N, cmax_HP_E, cmax_HP_Z, r_z, r_n, r_e, a_z, a_n, a_e, b_z, b_n, b_e, reg_r_z, reg_r_n, reg_r_e, reg_a_z, reg_a_n, reg_a_e, reg_b_z, reg_b_n, reg_b_e, wvel, wdir, time_sec]
#  Index: []
#
#  [0 rows x 36 columns])

# %%
def __makeplot():

    import matplotlib.pyplot as plt
    from matplotlib.gridspec import GridSpec

    def get_box_plot_data(labels, bp):
        rows_list = []

        for i in range(len(labels)):
            dict1 = {}
            dict1['label'] = labels[i]
            dict1['lower_whisker'] = bp['whiskers'][i*2].get_ydata()[1]
            dict1['lower_quartile'] = bp['boxes'][i].get_ydata()[1]
            dict1['median'] = bp['medians'][i].get_ydata()[1]
            dict1['upper_quartile'] = bp['boxes'][i].get_ydata()[2]
            dict1['upper_whisker'] = bp['whiskers'][(i*2)+1].get_ydata()[1]
            rows_list.append(dict1)

        return pd.DataFrame(rows_list)

    def __get_medians(_dict, _lbls):
        medians = {}
        for _i, _l in enumerate(_lbls):
            medians[str(_l)] = _dict['medians'][_i].get_ydata()[1]
        return medians

    colors = {"Z":"tab:green", "N":"tab:red", "E":"tab:blue"}

    Nrow, Ncol = 3, 2

    font = 12

    ms1, ms2 = 10, 20

    scale, unit = 1e9, "nrad/hPa"

    hil = r"H[P]"

    fig = plt.figure(figsize=(15, 10))

    gs = GridSpec(Nrow, Ncol, figure=fig, hspace=0.25)

    ax0 = fig.add_subplot(gs[0, 0])
    ax1 = fig.add_subplot(gs[0, 1])
    ax2 = fig.add_subplot(gs[1, 0])
    ax3 = fig.add_subplot(gs[1, 1])
    ax4 = fig.add_subplot(gs[2, 0])
    ax5 = fig.add_subplot(gs[2, 1])

    # ___________________________________________________
    ax0.scatter(df.reg_r_z, df.reg_a_z*scale, s=ms1, color=colors["Z"], label=r"a$_Z$", zorder=2)
    ax0.scatter(df.reg_r_n, df.reg_a_n*scale, s=ms1, color=colors["N"], label=r"a$_N$", zorder=2)
    ax0.scatter(df.reg_r_e, df.reg_a_e*scale, s=ms1, color=colors["E"], label=r"a$_E$", zorder=2)
    ax0.scatter(dfZ.reg_r_z, dfZ.reg_a_z*scale, s=ms2, color=colors["Z"], zorder=2, edgecolor="k")
    ax0.scatter(dfN.reg_r_n, dfN.reg_a_n*scale, s=ms2, color=colors["N"], zorder=2, edgecolor="k")
    ax0.scatter(dfE.reg_r_e, dfE.reg_a_e*scale, s=ms2, color=colors["E"], zorder=2, edgecolor="k")
    ax0.legend(fontsize=font-2)
    ax0.set_yscale("log")
    ax0.set_xlim(0, 100)
    ax0.set_xlabel(f"variance reduction (%)", fontsize=font)
    ax0.set_ylabel(f"coefficient P ({unit})", fontsize=font)

    # ___________________________________________________
    Nmax = df.shape[0]
    weights=[np.ones(Nmax)/Nmax*100, np.ones(Nmax)/Nmax*100, np.ones(Nmax)/Nmax*100]
    ax1.hist([df.reg_r_n, df.reg_r_e, df.reg_r_z], bins=10, range=[0, 100], alpha=0.8,
             density=False, weights=weights,
             rwidth=0.8, align="mid", zorder=2, edgecolor="k",
             color=[colors["N"], colors["E"], colors["Z"]], label=["N", "E", "Z"],
            )
    ax1.grid(alpha=0.2, ls="--", zorder=0)
    ax1.set_xlim(0, 100)
    ax1.legend(fontsize=font-2)
    ax1.set_xlabel(f"variance reduction (%)", fontsize=font)
    # ax1.set_ylabel(f"count of {Nmax}", fontsize=font)
    ax1.set_ylabel(f"Percentage", fontsize=font)

    # ___________________________________________________
    ax2.scatter(df.reg_r_z, (df.reg_a_z*scale)/(df.reg_b_z*scale), s=ms1, color=colors["Z"], label=r"a$_Z$/b$_Z$", zorder=2)
    ax2.scatter(df.reg_r_n, (df.reg_a_n*scale)/(df.reg_b_n*scale), s=ms1, color=colors["N"], label=r"a$_N$/b$_N$", zorder=2)
    ax2.scatter(df.reg_r_e, (df.reg_a_e*scale)/(df.reg_b_e*scale), s=ms1, color=colors["E"], label=r"a$_E$/b$_E$", zorder=2)
    ax2.scatter(dfZ.reg_r_z, (dfZ.reg_a_z*scale)/(dfZ.reg_b_z*scale), s=ms2, color=colors["Z"], zorder=2, edgecolor="k")
    ax2.scatter(dfN.reg_r_n, (dfN.reg_a_n*scale)/(dfN.reg_b_n*scale), s=ms2, color=colors["N"], zorder=2, edgecolor="k")
    ax2.scatter(dfE.reg_r_e, (dfE.reg_a_e*scale)/(dfE.reg_b_e*scale), s=ms2, color=colors["E"], zorder=2, edgecolor="k")
    ax2.axhline(1, 0, 100, color="grey", alpha=0.8, zorder=0, ls="--")
    ax2.legend(fontsize=font-2)
    # ax2.set_ylim(-2, 2)
    ax2.set_xlim(0, 100)
    ax2.set_yscale("log")
    ax2.set_xlabel(f"variance reduction (%)", fontsize=font)
    ax2.set_ylabel(f"ratio P / {hil}", fontsize=font)

    # ___________________________________________________
    # ax3.boxplot([abs(df.reg_a_z*scale), abs(df.reg_a_n*scale), abs(df.reg_a_e*scale), abs(df.reg_b_z*scale), abs(df.reg_b_n*scale), abs(df.reg_b_e*scale)],)
    a_z, a_n, a_e = abs(dfZ.reg_a_z*scale), abs(dfN.reg_a_n*scale), abs(dfE.reg_a_e*scale)
    b_z, b_n, b_e = abs(dfZ.reg_b_z*scale), abs(dfN.reg_b_n*scale), abs(dfE.reg_b_e*scale)
    arr = [a_z, a_n, a_e, b_z, b_n, b_e]
    bp = ax3.boxplot(arr, showmeans=False)
    ax3.set_yscale("log")
    # meds = __get_medians(bp, ['a_z', 'a_n', 'a_e', 'b_z', 'b_n', 'b_e'])
    # lbls = [f"a$_Z$ \n (={int(meds['a_z'])})", f"a$_N$ \n (={int(meds['a_n'])})", f"a$_E$ \n (={int(meds['a_e'])})",
    #         f"b$_Z$ \n (={int(meds['b_z'])})", f"b$_N$ \n (={int(meds['b_n'])})", f"b$_E$ \n (={int(meds['b_e'])})"]
    # ax3.set_xticklabels(lbls, fontsize=font)
    ax3.set_ylabel(f"coefficient ({unit})", fontsize=font)

    # ___________________________________________________
    ax4.scatter(df.reg_r_z, df.reg_b_z*scale, s=ms1, color=colors["Z"], label=r"b$_Z$", zorder=2)
    ax4.scatter(df.reg_r_n, df.reg_b_n*scale, s=ms1, color=colors["N"], label=r"b$_N$", zorder=2)
    ax4.scatter(df.reg_r_e, df.reg_b_e*scale, s=ms1, color=colors["E"], label=r"b$_E$", zorder=2)
    ax4.scatter(dfZ.reg_r_z, dfZ.reg_b_z*scale, s=ms2, color=colors["Z"], zorder=2, edgecolor="k")
    ax4.scatter(dfN.reg_r_n, dfN.reg_b_n*scale, s=ms2, color=colors["N"], zorder=2, edgecolor="k")
    ax4.scatter(dfE.reg_r_e, dfE.reg_b_e*scale, s=ms2, color=colors["E"], zorder=2, edgecolor="k")
    ax4.legend(fontsize=font-2)
    ax4.set_yscale("log")
    ax4.set_xlim(0, 100)
    ax4.set_xlabel(f"variance reduction (%)", fontsize=font)
    ax4.set_ylabel(f"coefficient {hil} ({unit})", fontsize=font)

    # ___________________________________________________
    tscale = 1/60

    # ax5.scatter(df.shift_PP_N*tscale, df.shift_HP_N, s=ms1,
    #             color=colors["N"], label=r"N", zorder=2)
    # ax5.scatter(df.shift_PP_E*tscale, df.shift_HP_E, s=ms1,
    #             color=colors["E"], label=r"E", zorder=2)
    # ax5.scatter(df.shift_PP_Z*tscale, df.shift_HP_Z, s=ms1,
    #             color=colors["Z"], label=r"Z", zorder=2)
    # ax5.scatter(dfN.shift_PP_N*tscale, dfN.shift_HP_N, s=ms2,
    #             color=colors["N"], label=f"N (CC>{cc_threshold})", zorder=2, edgecolor="k")
    # ax5.scatter(dfE.shift_PP_E*tscale, dfE.shift_HP_E, s=ms2,
    #             color=colors["E"], label=f"E (CC>{cc_threshold})", zorder=2, edgecolor="k")
    # ax5.scatter(dfZ.shift_PP_Z*tscale, dfZ.shift_HP_Z, s=ms2,
    #             color=colors["Z"], label=f"Z (CC>{cc_threshold})", zorder=2, edgecolor="k")
    # ax5.set_xlabel(f"time lag P (min)", fontsize=font)
    # ax5.set_ylabel(f"time lag {hil} (s)", fontsize=font)

    ax5.scatter(df.shift_PP_Z*tscale, df.cmax_PP_Z, s=ms1,
                color=colors["Z"], label=r"Z", zorder=2, alpha=0.7)
    ax5.scatter(df.shift_PP_N*tscale, df.cmax_PP_N, s=ms1,
                color=colors["N"], label=r"N", zorder=2, alpha=0.7)
    ax5.scatter(df.shift_PP_E*tscale, df.cmax_PP_E, s=ms1,
                color=colors["E"], label=r"E", zorder=2, alpha=0.7)
    ax5.scatter(dfZ.shift_HP_Z*tscale, dfZ.cmax_HP_Z, s=ms2,
                color=colors["Z"], zorder=2, edgecolor="k")
    ax5.scatter(dfN.shift_HP_N*tscale, dfN.cmax_HP_N, s=ms2,
                color=colors["N"], zorder=2, edgecolor="k")
    ax5.scatter(dfE.shift_HP_E*tscale, dfE.cmax_HP_E, s=ms2,
                color=colors["E"], zorder=2, edgecolor="k")

    ax5.set_xlabel(f"time lag P (min)", fontsize=font)
    ax5.set_ylabel(f"CC Coefficient", fontsize=font)

    # rmin, rmax = -30, 30
    # nbins = 100
    # ax5.hist(df.shift_PP_N*tscale, bins=nbins, range=[rmin, rmax],
    #          color=colors["N"], label=r"N", zorder=2, log=True)
    # ax5.hist(df.shift_PP_E*tscale, bins=nbins, range=[rmin, rmax],
    #          color=colors["E"], label=r"E", zorder=2, log=True)
    # ax5.hist(df.shift_PP_Z*tscale, bins=nbins, range=[rmin, rmax],
    #          color=colors["Z"], label=r"Z", zorder=2, log=True)
    # ax5.hist(dfN.shift_HP_N, bins=nbins, range=[rmin, rmax],
    # color=colors["N"], label=f"N (CC>{cc_threshold})", zorder=2)
    # ax5.hist(dfE.shift_HP_E, bins=nbins, range=[rmin, rmax],
    # color=colors["E"], label=f"E (CC>{cc_threshold})", zorder=2)
    # ax5.hist(dfZ.shift_HP_Z, bins=nbins, range=[rmin, rmax],
    # color=colors["Z"], label=f"Z (CC>{cc_threshold})", zorder=2)

    ax5.legend(fontsize=font-2, loc=4)
    # ax5.set_ylim(-2, 2)
    ax5.set_xlim(-60, 60)
    # ax5.set_xlabel(f"time lag P (min)", fontsize=font)
    # ax5.set_ylabel(f"time lag {hil} (s)", fontsize=font)

    ax0.text(.005, .97,"(a)", ha='left', va='top', transform=ax0.transAxes, fontsize=font+2)
    ax1.text(.005, .97,"(b)", ha='left', va='top', transform=ax1.transAxes, fontsize=font+2)
    ax2.text(.005, .97,"(c)", ha='left', va='top', transform=ax2.transAxes, fontsize=font+2)
    ax3.text(.005, .97,"(d)", ha='left', va='top', transform=ax3.transAxes, fontsize=font+2)
    ax4.text(.005, .97,"(e)", ha='left', va='top', transform=ax4.transAxes, fontsize=font+2)
    ax5.text(.005, .97,"(f)", ha='left', va='top', transform=ax5.transAxes, fontsize=font+2)


    axes = [ax0, ax1, ax2, ax3, ax4, ax5]
    for ax in axes:
        ax.grid(ls="--", alpha=0.4, zorder=0)

    print(bp.keys())
    print(get_box_plot_data(["a_z", "a_n", "a_e", "b_z", "b_n", "b_e"], bp))

    plt.show();
    return fig

fig = __makeplot();

# fig.savefig(config['path_to_figs']+f"RB_statistic_{config['tbeg'].date}_{config['tend'].date}.png", format="png", dpi=150, bbox_inches='tight')
# Out:
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])
#   label  lower_whisker  lower_quartile      median  upper_quartile  \
# 0   a_z       6.426213        6.426213    6.426213        6.426213
# 1   a_n      34.672832       34.672832   34.672832       34.672832
# 2   a_e            NaN             NaN         NaN             NaN
# 3   b_z      13.333448       13.333448   13.333448       13.333448
# 4   b_n     191.394273      191.394273  191.394273      191.394273
# 5   b_e            NaN             NaN         NaN             NaN
#
#    upper_whisker
# 0       6.426213
# 1      34.672832
# 2            NaN
# 3      13.333448
# 4     191.394273
# 5            NaN

# %%
dfZ, dfE, dfN
# Out:
# (              t1            t2  status  shift_PP_N  shift_PP_E  shift_PP_Z  \
#  42  1.704305e+09  1.704312e+09   False        14.1      127.05       144.0
#
#      shift_HP_N  shift_HP_E  shift_HP_Z  cmax_PP_N  ...  reg_r_e       reg_a_z  \
#  42         0.7       141.3       -38.0   -0.65281  ...   -29.98  6.426213e-09
#
#           reg_a_n   reg_a_e       reg_b_z       reg_b_n   reg_b_e  wvel   wdir  \
#  42 -3.467283e-08  0.000203 -1.333345e-08  1.913943e-07 -0.000029   4.5  255.0
#
#          time_sec
#  42  1.704308e+09
#
#  [1 rows x 36 columns],
#  Empty DataFrame
#  Columns: [t1, t2, status, shift_PP_N, shift_PP_E, shift_PP_Z, shift_HP_N, shift_HP_E, shift_HP_Z, cmax_PP_N, cmax_PP_E, cmax_PP_Z, cmax_HP_N, cmax_HP_E, cmax_HP_Z, r_z, r_n, r_e, a_z, a_n, a_e, b_z, b_n, b_e, reg_r_z, reg_r_n, reg_r_e, reg_a_z, reg_a_n, reg_a_e, reg_b_z, reg_b_n, reg_b_e, wvel, wdir, time_sec]
#  Index: []
#
#  [0 rows x 36 columns],
#                t1            t2  status  shift_PP_N  shift_PP_E  shift_PP_Z  \
#  42  1.704305e+09  1.704312e+09   False        14.1      127.05       144.0
#
#      shift_HP_N  shift_HP_E  shift_HP_Z  cmax_PP_N  ...  reg_r_e       reg_a_z  \
#  42         0.7       141.3       -38.0   -0.65281  ...   -29.98  6.426213e-09
#
#           reg_a_n   reg_a_e       reg_b_z       reg_b_n   reg_b_e  wvel   wdir  \
#  42 -3.467283e-08  0.000203 -1.333345e-08  1.913943e-07 -0.000029   4.5  255.0
#
#          time_sec
#  42  1.704308e+09
#
#  [1 rows x 36 columns])

# %%
dw = 2.5

# plt.scatter(df.wdir-dw, df.r_z, s=10)
# plt.scatter(df.wdir, df.r_n, s=10)
# plt.scatter(df.wdir+dw, df.r_e, s=10)

plt.scatter(dfZ.wdir-dw, dfZ.r_z, s=10)
plt.scatter(dfN.wdir, dfN.r_n, s=10)
plt.scatter(dfE.wdir+dw, dfE.r_e, s=10)

# %%
dv = 0.05
plt.scatter(dfZ.wvel-dv, dfZ.r_z, s=10)
plt.scatter(dfN.wvel, dfN.r_n, s=10)
plt.scatter(dfE.wvel+dv, dfE.r_e, s=10)

# %%
# plt.scatter(dfZ.wvel, dfZ.wdir, s=dfZ.r_z.iloc[:])
# plt.scatter(dfN.wvel, dfN.wdir, s=dfN.r_n.iloc[:])
# plt.scatter(dfE.wvel, dfE.wdir, s=dfE.r_e.iloc[:])

plt.scatter(df.wvel, df.wdir, s=df.r_z.iloc[:]/10)
# plt.scatter(df.wvel, df.wdir, s=df.r_n.iloc[:])
# plt.scatter(df.wvel, df.wdir, s=df.r_e.iloc[:])

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import multivariate_normal
import matplotlib.colors as colors
import matplotlib.colors as mcolors


fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, (_df, c) in enumerate(zip([dfZ, dfN, dfE], ["r_z", "r_n", "r_e"])):
    wvel = _df.wvel
    wdir = _df.wdir
    vr = _df[c]

    # axs[i].set_title('Linear normalization')
    axs[i].hist2d(wdir, wvel, bins=(36, 10), range=[(0, 360), (0, 5)],
                  weights=vr/100, density=True)

fig.tight_layout()

plt.show();
# Out:
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/numpy/lib/histograms.py:1067: RuntimeWarning: invalid value encountered in divide
#   hist /= s
