# %%
import numpy as np

from PyEMD import EMD
from PyEMD import EEMD
from PyEMD import Visualisation
import numpy as np
import pylab as plt

# %%
delta = 0.1
T = 100
f = .01

t = np.arange(0, T, delta)

S = np.sin(2*np.pi*(f+np.random.rand(len(t))*0.1)*t)

plt.plot(t,S)

# %%
# Assign EEMD to `eemd` variable
eemd = EEMD()

# Say we want detect extrema using parabolic method
emd = eemd.EMD
emd.extrema_detection="parabol"

# Execute EEMD on S
eIMFs = eemd.eemd(S, t)
nIMFs = eIMFs.shape[0]

# Plot results
plt.figure(figsize=(12,9))
plt.subplot(nIMFs+1, 1, 1)
plt.plot(t, S, 'r')

for n in range(nIMFs):
    plt.subplot(nIMFs+1, 1, n+2)
    plt.plot(t, eIMFs[n], 'g')
    plt.ylabel("eIMF %i" %(n+1))
    plt.locator_params(axis='y', nbins=5)

plt.xlabel("Time [s]")
plt.tight_layout()
plt.savefig('eemd_example', dpi=120)
plt.show()

# %%
# Initiate visualisation with emd instance
vis = Visualisation(emd)


imfs, res = emd.get_imfs_and_residue()

# Create a plot with all IMFs and residue
# vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)

# Create a plot with instantaneous frequency of all IMFs
vis.plot_instant_freq(t, imfs=imfs)

# Show both plots
vis.show()

# %%
from tftb.processing import WignerVilleDistribution
wvd = WignerVilleDistribution()
wvd.run()
wvd.plot(kind='contour', extent=[0, n_points, fmin, fmax])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-0dd00d45eed4> in <module>
#       1 from tftb.processing import WignerVilleDistribution
# ----> 2 wvd = WignerVilleDistribution(z)
#       3 wvd.run()
#       4 wvd.plot(kind='contour', extent=[0, n_points, fmin, fmax])
#
# NameError: name 'z' is not defined
