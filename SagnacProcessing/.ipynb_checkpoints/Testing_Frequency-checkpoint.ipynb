# %% [markdown]
# <div style='background-image: url("https://www.geophysik.uni-muenchen.de/ROMY/theme/images/ringlaser_wideformat.jpg") ; padding: 0px ; background-size: cover ; border-radius: 15px ; height: 250px; background-position: 0% 80%'>
#     <div style="float: left ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.9) ; width: 39% ; height: 150px">
#         <div style="position: relative ; top: 50%;  transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.9) ; line-height: 100%"> <br>ROMY - <br><br> Systematic Analysis </div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.7)"></div>
#         </div>
#     </div>

# %% [markdown]
# ## Importing

# %% [markdown]
# ### Official Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import time 
import obspy

from scipy.signal import resample, hilbert, correlate
from tqdm import tqdm

# %% [markdown]
# ### Own Processing Methods

# %%
from EchoPerformance import __echo_performance
from CreateSyntheticEventV2 import __create_synthetic_event_v2
from MinimizeResidual import __minimize_residual
from CreateLinearChirp import __create_linear_chirp
from Tapering import __tapering
from InstaFreqHilbert import __insta_freq_hilbert
from LoadMseed import __load_mseed
from Modulation import __modulation

# %%
# def __modulation(time_modeltrace, modeltrace, T, sps, mod_index):

#     timeline = time_modeltrace

#     Npts = int(T*sps)

#     # tt = np.arange(0, T, 1/sps/fraction)
#     tt = time_modeltrace

# #     modulation_index = abs(f_upper-sgnc)/f_upper
# #     print(modulation_index)
    
#     fm = sgnc + mod_index * modeltrace




#     print(' Integrating ... ')
#     t1 = time.time()

#     ifm = np.zeros(Npts+1)
#     summe = 0

#     for i in range(0, Npts+1):
#         summe += fm[i]
#         ifm[i] = 2*np.pi*summe

#     ifm = ifm / sps # to finish integral

#     t2 = time.time()

#     __echo_performance(t1, t2)



#     synthetic_signal = np.sin( 2 * np.pi * ifm )
#     # synthetic_signal = np.cos( 2 * np.pi * ifm )

#     # synthetic_signal = np.cos(2*np.pi * (sgnc + 0.01 * ifm ))

#     # synthetic_signal = 1.0 * np.sin(2*np.pi*sgnc * timeline - 0.001 * np.cos(modeltrace*timeline))

#     return timeline, synthetic_signal

# %% [markdown]
# ### Own Plotting Methods

# %%
from MakeplotTraceAndSpectrum import __makeplot_trace_and_spectrum
from MakeplotTraceAndPSD import __makeplot_trace_and_psd
from MakeplotModulatedSignal import __makeplot_modulated_signal
from MakeplotDemodulationQuality import __makeplot_demodulation_quality
from Normalize import __normalize

# %% [markdown]
# ## Configuration

# %%
div = 10
oversampling = 10

T = 1600.0/div
sps = 5000.0

sgnc = 300

f_lower, f_upper = 0.01, 30.

taper_type="window"

modulation_index = 0.1
 
syn_signal = 'trace'  ## chirp or trace

# %%
def __run(sgnc, T, sps, oversampling, mod_index, f_lower, f_upper, syn_signal, taper_type, taper_percent=0.2):
    
    sps *= oversampling
    
    ## ___________________________________________________
    ## Synthetic Signal
    
    modeltrace, time_modeltrace = __create_linear_chirp(T, sps, f_lower, f_upper)

    
    ## __________________________________
    if syn_signal == 'trace':
        
        ## load trace or create and write one if not yet existing
        
        iname=f"data/SYN_T{int(T)}_fs{int(sps)}_f{f_lower}-{f_upper}.mseed"
        
        modeltrace, time_modeltrace = __load_mseed(iname, T, sps, f_lower, f_upper)

        modeltrace = __tapering(modeltrace, taper_type, taper_percent)

         ## normalize trace to avoid issues with demodulation
        modeltrace = __normalize(modeltrace)

    ## __________________________________
    elif syn_signal == 'chirp':
        
        ## generate normalized chrip signal 
        modeltrace, time_modeltrace = __create_linear_chirp(T, sps, f_lower, f_upper)

    ## __________________________________    
    elif syn_signal == 'real_trace':

        ## set starttime and endtime
        tbeg = obspy.UTCDateTime(2020, 10, 30, 12, 5)
        tend = tbeg + T


        RLAS, RLAS_inv = __querry_seismo_data("BW.RLAS..BJZ", 
                                              tbeg, 
                                              tend, 
                                              restitute=True,
                                              )

        RLAS[0].resample(sampling_rate=sps)

        RLAS[0].filter('bandpass', freqmin=f_lower, freqmax=f_upper, corners=4, zerophase=True)

        time_modeltrace = np.arange(0, T+1/sps, 1/sps)
        modeltrace = RLAS[0].data[0:time_modeltrace.size]

        modeltrace = __normalize(modeltrace)

    ## __________________________________
    else:
        print("Wrong choise!")

    __tapering(modeltrace, taper_type, taper_percent)

    ## ___________________________________________________
    ## Modulation
    
#     timeline, synthetic_signal = __modulation(time_modeltrace, modeltrace, T, sps, mod_index)
    synthetic_signal, timeline = __modulation(modeltrace,
                                              time_modeltrace, 
                                              sgnc, 
                                              T, 
                                              sps, 
                                              mod_index, 
                                              case = 3,
                                             )    
#     synthetic_signal = __tapering(synthetic_signal, taper_type, taper_percent)

#     __makeplot_trace_and_psd(synthetic_signal, timeline, fmax=0.5*sps, t1=0, t2=2);


    ## ___________________________________________________
    ## Downsample
    
    modeltrace = modeltrace[::oversampling]
    time_modeltrace = time_modeltrace[::oversampling]

    synthetic_signal = synthetic_signal[::oversampling]
    timeline = timeline[::oversampling]

    sps = 1/(timeline[1]-timeline[0])    
    
#     __makeplot_trace_and_psd(synthetic_signal, timeline, fmax=0.5*sps);

#     __makeplot_modulated_signal(synthetic_signal,timeline);

    ## ___________________________________________________
    ## Demodulation
    
    time_demod_signal, demod_signal = __insta_freq_hilbert(synthetic_signal, timeline, sps, sgnc)
    
    
#     demod_signal = demod_signal - sgnc
    demod_signal = demod_signal - np.median(demod_signal)

    
    
    cutoff = int(0.01*demod_signal.size)
    
    ## store cutoffs for displaying
    cut1 = np.array([i for i in demod_signal[:cutoff]])
    cut2 = np.array([i for i in demod_signal[-cutoff:]])
    
    ## zero out 1% at both ends
    demod_signal[:cutoff] = 0.0
    demod_signal[-cutoff:] = 0.0

    
    ## normalize original and demodulated signal
    demod_signal_norm = __normalize(demod_signal)
    modeltrace_norm = __normalize(modeltrace)

    
    ## ___________________________________________________
    ## CrossCorrelation  

    cross_corr = correlate(demod_signal, modeltrace, mode='same')
    cross_corr_lags = np.arange(-cross_corr.size//2+1,cross_corr.size//2+1,1)
    
    
    idx = abs(cross_corr).argmax()
    
    cc = cross_corr[idx]
    cclag = cross_corr_lags[idx]
    
    print(f"\n max lag CC: {cross_corr_lags.max()} \n min lag CC: {cross_corr_lags.min()}")

    print(f"\n maximal CC: {round(cross_corr[idx],3)} at lag: {cross_corr_lags[idx]}")
    
    ## ___________________________________________________
    ## Residuals 
    
    residual  = modeltrace - demod_signal
    
    residual_pre_opt  = modeltrace_norm - demod_signal_norm

    residual_post_opt, demod_signal_opt  = __minimize_residual(demod_signal_norm, modeltrace_norm)
    
    
    rms_pre  = np.sqrt(np.mean(residual_pre_opt**2))
    rms_post = np.sqrt(np.mean(residual_post_opt**2))
    rms      = np.sqrt(np.mean(residual**2))
    
    print(f'cutoff: {cutoff} --> residual median: {np.median(residual_post_opt)}')

    
    ## ___________________________________________________
    ## Plot
    
#     __makeplot_demodulation_quality(timeline, 
#                                     modeltrace_norm, 
#                                     demod_signal_norm,
#                                     cross_corr,
#                                     cross_corr_lags,
#                                     cut1,
#                                     cut2,
#                                     );
    
    return cc, cclag, rms_pre, rms_post, rms

# %%
cc, cclag, rms_pre, rms_post, rms = __run( sgnc, 
                                           T, 
                                           sps, 
                                           oversampling,
                                           modulation_index,
                                           f_lower, 
                                           f_upper, 
                                           syn_signal,
                                           taper_type, 
                                           taper_percent=0.2,
                                          )
# Out:
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 71904.061 at lag: 0
#
# optimized: original -  0.997 * model + -0.0
#
# cutoff: 8000 --> residual median: 6.881482976583975e-05
#
# optimized: original -  0.997 * model + -0.0

# %% [markdown]
# ## Test Carrier Frequency

# %%
def __makeplot_quality_quantity_freq(xaxis, ccs, cclags, rms_pres, rms_posts, rmss):

    fig, ax = plt.subplots(2,2, figsize=(15,8))


    ## ________________________________________

    ax[0,0].plot(xaxis, ccs, color='k', ls='-', label='max. CC', zorder=1)
    ax[0,0].scatter(xaxis, ccs, color='k', s=10, zorder=2.5)

    ax[0,0].grid(alpha=0.5, ls='--')

    ax[0,0].legend(loc="upper right")
    ax[0,0].set_xlabel("carrier frequency (Hz)")

    ## ________________________________________

    ax[0,1].plot(xaxis, cclags, color='k', ls='-', label='lag of max. CC', zorder=1)
    ax[0,1].scatter(xaxis, cclags, color='k', s=10, zorder=2.5)

    ax[0,1].grid(alpha=0.5, ls='--')

    ax[0,1].legend()
    ax[0,1].set_xlabel("carrier frequency (Hz)")

    ## ________________________________________

    ax[1,0].plot(xaxis, rms_pres, color='darkblue', ls='-', label='rmse norm.', zorder=1)
    ax[1,0].scatter(xaxis, rms_pres, color='blue', s=10, zorder=2.5)

    ax[1,0].plot(xaxis, rms_posts, color='darkred', ls='-', label='rmse norm. opt.', zorder=1)
    ax[1,0].scatter(xaxis, rms_posts, color='red', s=10, zorder=2.5)

    ax[1,0].grid(alpha=0.5, ls='--')

    ax[1,0].legend(loc="upper left")
    ax[1,0].set_xlabel("carrier frequency (Hz)")

    ## ________________________________________

    ax[1,1].plot(xaxis, rmss, color='darkgreen', ls='-', label='rmse total', zorder=1)
    ax[1,1].scatter(xaxis, rmss, color='green', s=10, zorder=2.5)

    ax[1,1].grid(alpha=0.5, ls='--')

    ax[1,1].legend()
    ax[1,1].set_xlabel("carrier frequency (Hz)")
    
    plt.show();
    
    return fig

# %%
class configuration():
    
    def __init():
        
        self.T
        self.sps
        self.f_lower
        self.f_upper
        self.taper_type
        self.modulation_index
        
        
f_test = configuration()

# %%
div = 10
oversampling = 10

T = 1600/div
sps = 5000

f_lower, f_upper = 0.01, 30.0

taper_type="window"

syn_signal = "trace"

freqs = np.arange(100, 600, 10)

modulation_index = 0.1

# %%
ccs, cclags, rms_pres, rms_posts, rmss = [], [], [], [], []


for ff in freqs: 
    sgnc = ff
    cc, cclag, rms_pre, rms_post, rms = __run( sgnc, 
                                               T, 
                                               sps, 
                                               oversampling,
                                               modulation_index,
                                               f_lower, 
                                               f_upper, 
                                               syn_signal,
                                               taper_type, 
                                               taper_percent=0.2,
                                              )
    
    ccs.append(cc)
    cclags.append(cclag)
    rms_pres.append(rms_pre)
    rms_posts.append(rms_post)
    rmss.append(rms)
# Out:
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.071 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.594251756185265e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.054 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -5.170670653527852e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.59 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.053 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -5.127471893096036e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.054 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -5.539438973862186e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.055 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -5.976470141688672e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.065 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.531684337596211e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.051 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.584819665245156e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.06 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.970232676317689e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.4 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.058 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.298963830754124e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.069 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.846915161262679e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.57 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.051 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -4.1973538619899387e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.52 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.065 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.917218212778743e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.068 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.591566077469469e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.062 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.461645177020415e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.58 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.058 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.232620311563217e-05
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.38 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.064 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010179657042777568
#
# optimized: original -  1.002 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.063 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.211100398665018e-05
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.32 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.077 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -8.375455287235045e-05
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.062 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.16364542324355e-05
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.059 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.838380228827104e-05
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.51 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471855.983 at lag: 0
#
# optimized: original -  1.003 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.718764027588195e-05
#
# optimized: original -  1.003 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.066 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.184626851189287e-05
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.6 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.07 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001068841577483437
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.07 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010521530554796765
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.44 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.068 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010819945039131085
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.079 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00011506861980054623
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.29 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.071 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010289387864126365
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.07 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001186113975937958
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.4 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.072 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010518492234704024
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.47 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.073 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010699160836191712
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.64 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.079 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00012685920268329376
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.069 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00011961363507477767
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.08 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00012986098357770093
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.53 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.077 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001130672689040324
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.6 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.076 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00011642445723786254
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.51 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.086 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00013144397968434252
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.069 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00011971359212348265
#
# optimized: original -  1.003 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.071 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00011513445241695397
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.078 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001367817015558992
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.089 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001343021978728598
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471857.59 at lag: 0
#
# optimized: original -  1.006 * model + -0.004
#
# cutoff: 8000 --> residual median: -0.001670100594708901
#
# optimized: original -  1.006 * model + -0.004
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.55 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.083 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00012242109180430992
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.53 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.076 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00013246451390946934
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.083 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.000145564591016778
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.077 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00013151534110778657
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.094 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.000149756688183747
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.57 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.093 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00015766425230778758
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.61 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.077 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00014598167774576202
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.52 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.091 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001557958181604424
#
# optimized: original -  1.004 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.39 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.087 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00013843242124789157
#
# optimized: original -  1.004 * model + -0.0

# %%
fig = __makeplot_quality_quantity_freq(freqs, ccs, cclags, rms_pres, rms_posts, rmss)

fig.savefig(f"plots/test_freq_{syn_signal}_{freqs[0]}-{freqs[-1]}_T{T}_fs{sps}_f{f_lower}-{f_upper}_mi{modulation_index}.pdf", dpi=300, format='pdf')

# %% [markdown]
# ## Test Modulation Index

# %%
def __makeplot_quality_quantity_mind(xaxis, ccs, cclags, rms_pres, rms_posts, rmss):

    fig, ax = plt.subplots(2,2, figsize=(15,8))


    ## ________________________________________

    ax[0,0].plot(xaxis, ccs, color='k', ls='-', label='max. CC')
    ax[0,0].scatter(xaxis, ccs, color='k', s=10)

    ax[0,0].grid(alpha=0.5, ls='--')

    ax[0,0].legend()
    ax[0,0].set_xlabel("modulation index")
    ax[0,0].set_xscale("log")
    
    ## ________________________________________

    ax[0,1].plot(xaxis, cclags, color='k', ls='-', label='lag of max. CC')
    ax[0,1].scatter(xaxis, cclags, color='k', s=10)

    ax[0,1].grid(alpha=0.5, ls='--')

    ax[0,1].legend()
    ax[0,1].set_xlabel("modulation index")
    ax[0,1].set_xscale("log")

    ## ________________________________________

    ax[1,0].plot(xaxis, rms_pres, color='darkblue', ls='-', label='rmse norm.')
    ax[1,0].scatter(xaxis, rms_pres, color='blue', s=10)

    ax[1,0].plot(xaxis, rms_posts, color='darkred', ls='-', label='rmse norm. opt.')
    ax[1,0].scatter(xaxis, rms_posts, color='red', s=10)

    ax[1,0].grid(alpha=0.5, ls='--')

    ax[1,0].legend()
    ax[1,0].set_xlabel("modulation index")
    ax[1,0].set_xscale("log")

    ## ________________________________________

    ax[1,1].plot(xaxis, rmss, color='darkgreen', ls='-', label='rmse total')
    ax[1,1].scatter(xaxis, rmss, color='green', s=10)

    ax[1,1].grid(alpha=0.5, ls='--')

    ax[1,1].legend()
    ax[1,1].set_xlabel("modulation index")
    ax[1,1].set_xscale("log")
    
    plt.show();
    
    return fig

# %%
div = 10
oversampling = 10

T = 1600/div
sps = 5000

sgnc = 300

f_lower, f_upper = 0.01, 30.0

taper_type="window"

syn_signal = "trace"

freqs = np.arange(100, 600, 10)


modulation_indicies = np.array([0.001, 0.003, 0.006, 0.01, 0.03, 0.06 ,0.1, 0.3, 0.6, 1, 2, 3, 4, 5, 10]) 
# modulation_indicies = np.logspace(-3, 1, num=11)

# %%
ccs, cclags, rms_pres, rms_posts, rmss = [], [], [], [], []


for m_ind in modulation_indicies: 
    
    modulation_index = m_ind
    
    cc, cclag, rms_pre, rms_post, rms = __run( sgnc, 
                                               T, 
                                               sps, 
                                               oversampling,
                                               modulation_index,
                                               f_lower, 
                                               f_upper, 
                                               syn_signal,
                                               taper_type, 
                                               taper_percent=0.2,
                                              )
    
    ccs.append(cc)
    cclags.append(cclag)
    rms_pres.append(rms_pre)
    rms_posts.append(rms_post)
    rmss.append(rms)
# Out:
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.514 at lag: 0
#
# optimized: original -  1.136 * model + 0.001
#
# cutoff: 8000 --> residual median: 0.0009876811075689785
#
# optimized: original -  1.136 * model + 0.001
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.59 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 14155.627 at lag: 0
#
# optimized: original -  1.929 * model + 0.002
#
# cutoff: 8000 --> residual median: 0.0018999770532998309
#
# optimized: original -  1.929 * model + 0.002
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 28311.307 at lag: 0
#
# optimized: original -  1.563 * model + 0.002
#
# cutoff: 8000 --> residual median: 0.0014386799297947787
#
# optimized: original -  1.563 * model + 0.002
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.542 at lag: 0
#
# optimized: original -  1.081 * model + 0.001
#
# cutoff: 8000 --> residual median: 0.0009672609131896048
#
# optimized: original -  1.081 * model + 0.001
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.39 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 141556.754 at lag: 0
#
# optimized: original -  1.002 * model + 0.0
#
# cutoff: 8000 --> residual median: 0.0002080098874143732
#
# optimized: original -  1.002 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 283113.565 at lag: 0
#
# optimized: original -  1.003 * model + 0.0
#
# cutoff: 8000 --> residual median: 9.002768120319748e-05
#
# optimized: original -  1.003 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.59 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471855.983 at lag: 0
#
# optimized: original -  1.003 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.718764027588195e-05
#
# optimized: original -  1.003 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 1415568.102 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.337752342822629e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2831136.214 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.6976585866190774e-05
#
# optimized: original -  1.001 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.51 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.185 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.2517520564303122e-05
#
# optimized: original -  1.0 * model + -0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 9437119.362 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: -1.460274896702518e-06
#
# optimized: original -  1.0 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 14155677.928 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.984186462427375e-06
#
# optimized: original -  1.0 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.51 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 18874238.403 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 1.1103091435843426e-06
#
# optimized: original -  1.0 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592798.473 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 1.8116838167653651e-06
#
# optimized: original -  1.0 * model + 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185600.632 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.7903651632281904e-06
#
# optimized: original -  1.0 * model + -0.0

# %%
fig = __makeplot_quality_quantity_mind(modulation_indicies, ccs, cclags, rms_pres, rms_posts, rmss)

fig.savefig(f"plots/test_mod-ind_{modulation_indicies[0]}-{modulation_indicies[-1]}_T{T}_fs{sps}_f{f_lower}-{f_upper}_S{sgnc}.pdf", dpi=300, format='pdf')
