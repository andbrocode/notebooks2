# %% [markdown]
# <div style='background-image: url("https://www.geophysik.uni-muenchen.de/ROMY/theme/images/ringlaser_wideformat.jpg") ; padding: 0px ; background-size: cover ; border-radius: 15px ; height: 250px; background-position: 0% 80%'>
#     <div style="float: left ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.9) ; width: 39% ; height: 150px">
#         <div style="position: relative ; top: 50%;  transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.9) ; line-height: 100%"> <br>ROMY - <br> Systematic Analysis <br> of Modulation Index </div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.7)"></div>
#         </div>
#     </div>

# %% [markdown]
# ## Importing

# %% [markdown]
# ### Official Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import time 
import obspy

from scipy.signal import resample, hilbert, correlate
from tqdm import tqdm
from matplotlib.patches import Polygon, Patch

# %% [markdown]
# ### Own Processing Methods

# %%
import sys
sys.path.insert(0, 'submodules')

# %%
from EchoPerformance import __echo_performance
from CreateSyntheticEventV2 import __create_synthetic_event_v2
from MinimizeResidual import __minimize_residual
from CreateLinearChirp import __create_linear_chirp
from Tapering import __tapering
from InstaFreqHilbert import __insta_freq_hilbert
from LoadMseed import __load_mseed
from Modulation import __modulation

# %%
# def __modulation(time_modeltrace, modeltrace, T, sps, mod_index):

#     timeline = time_modeltrace

#     Npts = int(T*sps)

#     # tt = np.arange(0, T, 1/sps/fraction)
#     tt = time_modeltrace

# #     modulation_index = abs(f_upper-sgnc)/f_upper
# #     print(modulation_index)
    
#     fm = sgnc + mod_index * modeltrace




#     print(' Integrating ... ')
#     t1 = time.time()

#     ifm = np.zeros(Npts+1)
#     summe = 0

#     for i in range(0, Npts+1):
#         summe += fm[i]
#         ifm[i] = 2*np.pi*summe

#     ifm = ifm / sps # to finish integral

#     t2 = time.time()

#     __echo_performance(t1, t2)



#     synthetic_signal = np.sin( 2 * np.pi * ifm )
#     # synthetic_signal = np.cos( 2 * np.pi * ifm )

#     # synthetic_signal = np.cos(2*np.pi * (sgnc + 0.01 * ifm ))

#     # synthetic_signal = 1.0 * np.sin(2*np.pi*sgnc * timeline - 0.001 * np.cos(modeltrace*timeline))

#     return timeline, synthetic_signal

# %% [markdown]
# ### Own Plotting Methods

# %%
from MakeplotTraceAndSpectrum import __makeplot_trace_and_spectrum
from MakeplotTraceAndPSD import __makeplot_trace_and_psd
from MakeplotModulatedSignal import __makeplot_modulated_signal
from MakeplotDemodulationQuality import __makeplot_demodulation_quality
from Normalize import __normalize

# %%
def __run(sgnc, T, sps, oversampling, mod_index, f_lower, f_upper, syn_signal, taper_type, taper_percent=0.2):
    
    sps *= oversampling
    
    ## ___________________________________________________
    ## Synthetic Signal
    
    modeltrace, time_modeltrace = __create_linear_chirp(T, sps, f_lower, f_upper)

    
    ## __________________________________
    if syn_signal == 'trace':
        
        ## load trace or create and write one if not yet existing
        
        iname=f"data/SYN_T{int(T)}_fs{int(sps)}_f{f_lower}-{f_upper}.mseed"
        
        modeltrace, time_modeltrace = __load_mseed(iname, T, sps, f_lower, f_upper)

        modeltrace = __tapering(modeltrace, taper_type, taper_percent)

         ## normalize trace to avoid issues with demodulation
        modeltrace = __normalize(modeltrace)

    ## __________________________________
    elif syn_signal == 'chirp':
        
        ## generate normalized chrip signal 
        modeltrace, time_modeltrace = __create_linear_chirp(T, sps, f_lower, f_upper)

    ## __________________________________    
    elif syn_signal == 'real_trace':

        ## set starttime and endtime
        tbeg = obspy.UTCDateTime(2020, 10, 30, 12, 5)
        tend = tbeg + T


        RLAS, RLAS_inv = __querry_seismo_data("BW.RLAS..BJZ", 
                                              tbeg, 
                                              tend, 
                                              restitute=True,
                                              )

        RLAS[0].resample(sampling_rate=sps)

        RLAS[0].filter('bandpass', freqmin=f_lower, freqmax=f_upper, corners=4, zerophase=True)

        time_modeltrace = np.arange(0, T+1/sps, 1/sps)
        modeltrace = RLAS[0].data[0:time_modeltrace.size]

        modeltrace = __normalize(modeltrace)

    ## __________________________________
    else:
        print("Wrong choise!")

    __tapering(modeltrace, taper_type, taper_percent)

    ## ___________________________________________________
    ## Modulation
    
#     timeline, synthetic_signal = __modulation(time_modeltrace, modeltrace, T, sps, mod_index)
    synthetic_signal, timeline = __modulation(modeltrace,
                                              time_modeltrace, 
                                              sgnc, 
                                              T, 
                                              sps, 
                                              mod_index, 
                                              case = 3,
                                             )    
#     synthetic_signal = __tapering(synthetic_signal, taper_type, taper_percent)

#     __makeplot_trace_and_psd(synthetic_signal, timeline, fmax=0.5*sps, t1=0, t2=2);


    ## ___________________________________________________
    ## Downsample
    
    modeltrace = modeltrace[::oversampling]
    time_modeltrace = time_modeltrace[::oversampling]

    synthetic_signal = synthetic_signal[::oversampling]
    timeline = timeline[::oversampling]

    sps = 1/(timeline[1]-timeline[0])    
    
#     __makeplot_trace_and_psd(synthetic_signal, timeline, fmax=0.5*sps);

#     __makeplot_modulated_signal(synthetic_signal,timeline);

    ## ___________________________________________________
    ## Demodulation
    
    time_demod_signal, demod_signal = __insta_freq_hilbert(synthetic_signal, timeline, sps, sgnc)
    
    
#     demod_signal = demod_signal - sgnc
    demod_signal = demod_signal - np.median(demod_signal)

    
    
    cutoff = int(0.01*demod_signal.size)
    
    ## store cutoffs for displaying
    cut1 = np.array([i for i in demod_signal[:cutoff]])
    cut2 = np.array([i for i in demod_signal[-cutoff:]])
    
    ## zero out 1% at both ends
    demod_signal[:cutoff] = 0.0
    demod_signal[-cutoff:] = 0.0

    
    ## normalize original and demodulated signal
    demod_signal_norm = __normalize(demod_signal)
    modeltrace_norm = __normalize(modeltrace)

    
    ## ___________________________________________________
    ## CrossCorrelation  

    cross_corr = correlate(demod_signal, modeltrace, mode='same')
    cross_corr_lags = np.arange(-cross_corr.size//2+1,cross_corr.size//2+1,1)
    
    
    idx = abs(cross_corr).argmax()
    
    cc = cross_corr[idx]
    cclag = cross_corr_lags[idx]
    
    print(f"\n max lag CC: {cross_corr_lags.max()} \n min lag CC: {cross_corr_lags.min()}")

    print(f"\n maximal CC: {round(cross_corr[idx],3)} at lag: {cross_corr_lags[idx]}")
    
    ## ___________________________________________________
    ## Residuals 
    
    residual  = modeltrace - demod_signal
    
    residual_pre_opt  = modeltrace_norm - demod_signal_norm

    residual_post_opt, demod_signal_opt  = __minimize_residual(demod_signal_norm, modeltrace_norm)
    
    N = residual.size 
    
    rms_pre  = np.sqrt(np.mean(residual_pre_opt**2))
    rms_post = np.sqrt(np.mean(residual_post_opt**2))
    rms      = np.sqrt(np.mean(residual**2))
    
    print(f'cutoff: {cutoff} --> residual median: {np.median(residual_post_opt)}')

    
    ## ___________________________________________________
    ## Plot
    
#     __makeplot_demodulation_quality(timeline, 
#                                     modeltrace_norm, 
#                                     demod_signal_norm,
#                                     cross_corr,
#                                     cross_corr_lags,
#                                     cut1,
#                                     cut2,
#                                     );
    
    return cc, cclag, rms_pre, rms_post, rms

# %% [markdown]
# ## Configuration

# %%
oversampling = 10

T = 160
sps = 5000

sgnc = 553

f_lower, f_upper = 0.01, 30.0

taper_type="window"

syn_signal = "trace"

freqs = np.arange(0, 600, 50)

# modulation_indicies = np.array([0.001, 0.003, 0.006, 0.01, 0.03, 0.06 ,0.1, 0.3, 0.6, 1, 2, 3, 4, 5, 10]) 
modulation_indicies = np.array([0.001, 0.005, 0.01, 0.05 ,0.1, 0.5, 1, 5, 10]) 

# modulation_indicies = np.logspace(-3, 1, num=11)

# %% [markdown]
# ## Test Modulation Index

# %%
ccs = np.zeros((modulation_indicies.size, freqs.size))
cclags = np.zeros((modulation_indicies.size, freqs.size))
rms_pres = np.zeros((modulation_indicies.size, freqs.size))
rms_posts = np.zeros((modulation_indicies.size, freqs.size))
rmss = np.zeros((modulation_indicies.size, freqs.size))

for i, m_ind in enumerate(modulation_indicies): 
    modulation_index = m_ind
    print(m_ind, i)
    for j, ff in enumerate(freqs):
        sgnc = ff
        
        cc, cclag, rms_pre, rms_post, rms = __run( sgnc, 
                                                   T, 
                                                   sps, 
                                                   oversampling,
                                                   modulation_index,
                                                   f_lower, 
                                                   f_upper, 
                                                   syn_signal,
                                                   taper_type, 
                                                   taper_percent=0.2,
                                                  )
    
        print(i,j, ccs[i,j])    
        ccs[i][j] = cc
        cclags[i][j] = cclag
        rms_pres[i][j] = rms_pre
        rms_posts[i][j] = rms_post
        rmss[i][j] = rms
# Out:
# 0.001 0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.31 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20847027.335 at lag: 176
#
# optimized: original -  0.711 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.000763357473828801
# 0 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.29 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.561 at lag: 0
#
# optimized: original -  1.567 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00038930990918383337
# 0 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.27 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.581 at lag: 0
#
# optimized: original -  1.927 * model + -0.002
#
# cutoff: 8000 --> residual median: -0.002686167308558426
# 0 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.44 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.561 at lag: 0
#
# optimized: original -  1.763 * model + 0.0
#
# cutoff: 8000 --> residual median: -0.00027147168837760797
# 0 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.53 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.563 at lag: 0
#
# optimized: original -  1.518 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00030647195199204477
# 0 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.32 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.561 at lag: 0
#
# optimized: original -  1.293 * model + 0.0
#
# cutoff: 8000 --> residual median: -0.00021956453628003484
# 0 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.38 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.514 at lag: 0
#
# optimized: original -  1.136 * model + 0.001
#
# cutoff: 8000 --> residual median: 0.0009876811075689785
# 0 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.559 at lag: 0
#
# optimized: original -  1.003 * model + 0.0
#
# cutoff: 8000 --> residual median: -0.00013107198631798211
# 0 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.556 at lag: 0
#
# optimized: original -  0.893 * model + 0.0
#
# cutoff: 8000 --> residual median: -9.859341416784914e-05
# 0 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.559 at lag: 0
#
# optimized: original -  0.805 * model + 0.0
#
# cutoff: 8000 --> residual median: -0.00014114420813577712
# 0 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4719.156 at lag: 0
#
# optimized: original -  0.729 * model + -0.005
#
# cutoff: 8000 --> residual median: -0.006380379274856475
# 0 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.47 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718.557 at lag: 0
#
# optimized: original -  0.673 * model + 0.0
#
# cutoff: 8000 --> residual median: -0.00012316224324074375
# 0 11 0.0
# 0.005 1
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.39 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20847024.83 at lag: 176
#
# optimized: original -  0.711 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.0007633547509418958
# 1 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.804 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001834685569466199
# 1 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.831 at lag: 0
#
# optimized: original -  0.985 * model + -0.001
#
# cutoff: 8000 --> residual median: -0.0012873882738878774
# 1 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.806 at lag: 0
#
# optimized: original -  1.083 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0003917538563461076
# 1 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.808 at lag: 0
#
# optimized: original -  1.353 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0004414275732167205
# 1 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.44 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.804 at lag: 0
#
# optimized: original -  1.549 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0003953818680083043
# 1 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.47 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.744 at lag: 0
#
# optimized: original -  1.719 * model + 0.002
#
# cutoff: 8000 --> residual median: 0.0016919776987368246
# 1 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.803 at lag: 0
#
# optimized: original -  1.828 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0003147083607559359
# 1 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.37 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.796 at lag: 0
#
# optimized: original -  1.887 * model + 0.0
#
# cutoff: 8000 --> residual median: -0.00013838292484374642
# 1 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.807 at lag: 0
#
# optimized: original -  1.92 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00042371917030905774
# 1 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.39 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23593.634 at lag: 0
#
# optimized: original -  1.911 * model + -0.02
#
# cutoff: 8000 --> residual median: -0.020528208819360266
# 1 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592.807 at lag: 0
#
# optimized: original -  1.917 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.000379053941760812
# 1 11 0.0
# 0.01 2
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20847017.002 at lag: 176
#
# optimized: original -  0.711 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.0007633574695554298
# 2 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.608 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00014173405633284013
# 2 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.49 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.637 at lag: 0
#
# optimized: original -  1.003 * model + -0.001
#
# cutoff: 8000 --> residual median: -0.0005943787813744716
# 2 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.609 at lag: 0
#
# optimized: original -  0.995 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0002678179496863157
# 2 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.39 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.613 at lag: 0
#
# optimized: original -  0.984 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00031527523969813857
# 2 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.615 at lag: 0
#
# optimized: original -  0.968 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00043818940973716636
# 2 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.542 at lag: 0
#
# optimized: original -  1.081 * model + 0.001
#
# cutoff: 8000 --> residual median: 0.0009672609131896048
# 2 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.52 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.615 at lag: 0
#
# optimized: original -  1.224 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00045604236495890753
# 2 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.602 at lag: 0
#
# optimized: original -  1.345 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00023893058041180026
# 2 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.612 at lag: 0
#
# optimized: original -  1.455 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0004266536635236048
# 2 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47186.575 at lag: 0
#
# optimized: original -  1.536 * model + -0.019
#
# cutoff: 8000 --> residual median: -0.017115478794318587
# 2 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.44 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185.611 at lag: 0
#
# optimized: original -  1.634 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00043061891118820195
# 2 11 0.0
# 0.05 3
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20846766.507 at lag: 176
#
# optimized: original -  0.711 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.0007632884575690347
# 3 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.022 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -4.8390085809937866e-05
# 3 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.063 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00016728315769892754
# 3 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.035 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.000104162113179318
# 3 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.47 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.043 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.151732665286459e-05
# 3 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.049 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001551772811195784
# 3 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.53 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235927.953 at lag: 0
#
# optimized: original -  1.003 * model + 0.0
#
# cutoff: 8000 --> residual median: 0.00012189275831420154
# 3 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.4 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.047 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00017974989567162356
# 3 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.4 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.036 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.0001605827499634449
# 3 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.055 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00022662045541410603
# 3 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235929.38 at lag: 0
#
# optimized: original -  1.007 * model + -0.007
#
# cutoff: 8000 --> residual median: -0.0030058630379945495
# 3 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.48 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 235928.052 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00023428666887476135
# 3 11 0.0
# 0.1 4
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.59 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20845983.685 at lag: 176
#
# optimized: original -  0.711 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.0007631238816014059
# 4 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.37 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.04 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.1229388223280585e-05
# 4 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.53 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.071 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -9.594251756185265e-05
# 4 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.065 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.531684337596211e-05
# 4 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.051 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -4.1973538619899387e-05
# 4 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.32 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.064 at lag: 0
#
# optimized: original -  1.002 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00010179657042777568
# 4 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.32 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471855.983 at lag: 0
#
# optimized: original -  1.003 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.718764027588195e-05
# 4 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.22 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.079 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00011506861980054623
# 4 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.54 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.079 at lag: 0
#
# optimized: original -  1.003 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00012685920268329376
# 4 8 0.0
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.26 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.086 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.00013144397968434252
# 4 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.23 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471857.59 at lag: 0
#
# optimized: original -  1.006 * model + -0.004
#
# cutoff: 8000 --> residual median: -0.001670100594708901
# 4 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.24 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 471856.094 at lag: 0
#
# optimized: original -  1.004 * model + -0.0
#
# cutoff: 8000 --> residual median: -0.000149756688183747
# 4 11 0.0
# 0.5 5
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.44 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20820911.057 at lag: 176
#
# optimized: original -  0.713 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.000759038005437588
# 5 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359279.65 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 4.554867576244445e-06
# 5 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.119 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.1246645926360488e-05
# 5 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.107 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.0805462701563712e-05
# 5 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.161 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.4333093541789169e-05
# 5 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.34 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.252 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.139960989517743e-05
# 5 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.208 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.8695563956672157e-05
# 5 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.24 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.208 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -2.5393748028151863e-05
# 5 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.26 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.210883685733165e-05
# 5 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.265 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -4.919467396466426e-05
# 5 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359282.065 at lag: 0
#
# optimized: original -  1.002 * model + -0.001
#
# cutoff: 8000 --> residual median: -0.0004236451042721745
# 5 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 2359280.212 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.5273655933032444e-05
# 5 11 0.0
# 1.0 6
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -20742277.734 at lag: 176
#
# optimized: original -  0.719 * model + 0.003
#
# cutoff: 8000 --> residual median: 0.0007557720562765551
# 6 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.28 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718559.838 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 1.9820185780533572e-06
# 6 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.25 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718559.32 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.90481804521739e-06
# 6 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.37 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718559.673 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 1.3267589772658628e-06
# 6 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.187 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -2.8052737572059616e-06
# 6 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.3 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.297 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.511942070301503e-05
# 6 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.185 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.2517520564303122e-05
# 6 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.227 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -1.9707880936872813e-05
# 6 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.487 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.989333253267939e-05
# 6 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.2 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.378 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -2.596321143309363e-05
# 6 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.35 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718562.29 at lag: 0
#
# optimized: original -  1.001 * model + -0.001
#
# cutoff: 8000 --> residual median: -0.00020501729372043864
# 6 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 4718560.384 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.0865140626556986e-05
# 6 11 0.0
# 5.0 7
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.32 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: -17979909.258 at lag: 177
#
# optimized: original -  0.976 * model + 0.005
#
# cutoff: 8000 --> residual median: -0.0008444453667246403
# 7 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#  elapsed time: 4.29 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592755.975 at lag: 0
#
# optimized: original -  1.001 * model + -0.0
#
# cutoff: 8000 --> residual median: 1.235798085065954e-05
# 7 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592800.963 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.50555084148407e-06
# 7 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.32 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592800.563 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -4.706185100705751e-06
# 7 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.19 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592799.962 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: -4.019751024592413e-06
# 7 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.39 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592799.258 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: -1.1774973570841119e-06
# 7 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592798.473 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 1.8116838167653651e-06
# 7 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592798.019 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 2.1440325498542356e-06
# 7 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.45 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592797.571 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.585370167022428e-06
# 7 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.21 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592797.201 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.2377610943296053e-06
# 7 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592796.824 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 3.4976825581331528e-06
# 7 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.41 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 23592796.056 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 4.644583262936042e-06
# 7 11 0.0
# 10.0 8
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 12701261.844 at lag: 694
#
# optimized: original -  0.859 * model + 0.002
#
# cutoff: 8000 --> residual median: 7.611655558646273e-05
# 8 0 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.47 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47184178.646 at lag: 0
#
# optimized: original -  1.006 * model + -0.0
#
# cutoff: 8000 --> residual median: 3.910238328158622e-05
# 8 1 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.42 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185602.157 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -5.545562431329837e-06
# 8 2 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.38 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185601.971 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -7.2357693680080715e-06
# 8 3 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.47 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185601.165 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -4.9529792221295055e-06
# 8 4 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.43 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185601.392 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -6.635373263817736e-06
# 8 5 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185600.632 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.7903651632281904e-06
# 8 6 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.33 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185600.115 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: -2.944897593420981e-06
# 8 7 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.5 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185599.834 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: -2.864476213337852e-06
# 8 8 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.46 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185599.018 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: -1.5178234730166967e-06
# 8 9 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.36 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185601.624 at lag: 0
#
# optimized: original -  1.0 * model + -0.0
#
# cutoff: 8000 --> residual median: -3.723044784179584e-05
# 8 10 0.0
#
# Modulation option 3 is executed ...
#
#  --> integrating ...
#
#  elapsed time: 4.25 sec
# 1 nan removed !
#
#  max lag CC: 400000
#  min lag CC: -400000
#
#  maximal CC: 47185597.532 at lag: 0
#
# optimized: original -  1.0 * model + 0.0
#
# cutoff: 8000 --> residual median: 5.693943781887034e-07
# 8 11 0.0

# %%
def __makeplot_quality_quantity_mind(xaxis, mind, ccs, cclags, rms_pres, rms_posts, rmss):

    fig, ax = plt.subplots(2,2, figsize=(15,8))

    font = 15
    
    colors = ['darkred', 'darkorange', 'lightgreen', 'darkgreen', 'cyan', 'darkblue', 'purple', 'pink']
    
    fig.subplots_adjust(hspace=0.3)
    
    ## ________________________________________

    for k in range(len(ccs)-1):
        ax[0,0].plot(xaxis, ccs[k][:], color=colors[k], ls='--', label='max. CC')
        ax[0,1].plot(xaxis, cclags[k][:], color=colors[k], ls='--', label='lag of max. CC')
        ax[1,0].plot(xaxis, rms_pres[k][:], color=colors[k], ls='--', label='rmse norm.')
        ax[1,1].plot(xaxis, rmss[k][:], color=colors[k], ls='--', label='rmse total')

        ax[0,0].scatter(xaxis, ccs[k][:], color=colors[k], ls='-', label='max. CC')
        ax[0,1].scatter(xaxis, cclags[k][:], color=colors[k], ls='-', label='lag of max. CC')
        ax[1,0].scatter(xaxis, rms_pres[k][:], color=colors[k], ls='-', label='rmse norm.')
        ax[1,1].scatter(xaxis, rmss[k][:], color=colors[k], ls='-', label='rmse total')

    ## ________________________________________


    ax[0,0].grid(alpha=0.5, ls='--')

    ax[0,0].set_xlabel("carrier frequency (Hz)", fontsize=font)
    ax[0,0].set_ylabel("max. cross-correlation", fontsize=font)
    ax[0,0].set_yscale("log")
    
    ## ________________________________________


    ax[0,1].grid(alpha=0.5, ls='--')

    ax[0,1].set_xlabel("carrier frequency (Hz)", fontsize=font)
    ax[0,1].set_ylabel("cross-correlation lag", fontsize=font)
    ax[0,1].set_ylim(-1,1)
    ## ________________________________________


    ax[1,0].grid(alpha=0.5, ls='--')

    ax[1,0].set_xlabel("carrier frequency (Hz)", fontsize=font)
    ax[1,0].set_ylabel("root mean square error", fontsize=font)
    ax[1,0].set_yscale("log")

    ## ________________________________________


    ax[1,1].grid(alpha=0.5, ls='--')

    ax[1,1].set_xlabel("carrier frequency (Hz)", fontsize=font)
    ax[1,1].set_ylabel("root mean square error", fontsize=font)
    
    ax[0,0].tick_params(labelsize=font-2)
    ax[1,0].tick_params(labelsize=font-2)
    ax[0,1].tick_params(labelsize=font-2)
    ax[1,1].tick_params(labelsize=font-2)
    ax[1,1].set_yscale("log")
    
    ## add legend 
#     legend_elements = [Patch(facecolor='green', edgecolor='green', label='Q0'),
#                        Patch(facecolor='yellow', edgecolor='yellow', label='Q1'),
#                        Patch(facecolor='darkorange', edgecolor='darkorange', label='Q2'),
#                        Patch(facecolor='darkred', edgecolor='darkred', label='Q3')
#                       ]

#     ax[0,0].legend(handles=legend_elements, loc='upper center', fontsize=font, ncol=9, edgecolor='black')
    ax[0,1].legend([mind[0],
                   mind[1],
                   mind[2],
                   mind[3],
                   mind[4],
                   mind[5],
                   mind[6],
                   mind[7]],
                   fontsize=font,
                   bbox_to_anchor=(1,0.3),
                   loc="upper left",
                  )
    
    plt.show();

#     ax[1,1].legend(fontsize=font-2)
    
    return fig

# %%
fig = __makeplot_quality_quantity_mind(freqs, 
                                       modulation_indicies, 
                                       ccs, 
                                       cclags, 
                                       rms_pres, 
                                       rms_posts, 
                                       rmss,
                                      )

fig.savefig(f"plots/test_mod-ind_{syn_signal}_{modulation_indicies[0]}-{modulation_indicies[-1]}_T{T}_fs{sps}_f{f_lower}-{f_upper}_S{sgnc}.pdf", dpi=300, format='pdf')
