# %% [markdown]
# # ROMY Status File

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import obspy as obs
import matplotlib.colors

from pandas import DataFrame, merge
from andbro__save_to_pickle import __save_to_pickle

# %%
from functions.load_beat import __load_beat
from functions.load_mlti import __load_mlti
from functions.get_mlti_intervals import __get_mlti_intervals

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
    bay_path = '/home/andbro/bay200/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/bay200/'
elif os.uname().nodename == 'lin-ffb-01':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'
    bay_path = '/bay200/'

# %% [markdown]
# ## Configurations

# %%
config = {}


# config['tbeg'] = obs.UTCDateTime("2024-02-01")
# config['tend'] = obs.UTCDateTime("2024-02-29")

config['tbeg'] = obs.UTCDateTime("2022-01-01")
config['tend'] = obs.UTCDateTime("2022-12-31")

# config['ring'] = "U"

config['path_to_figures'] = data_path+f"quality_status/figures/"

config['path_to_data'] = archive_path+f"temp_archive/"

# %% [markdown]
# ### Load Status Data

# %%
from functions.load_status import __load_status

# %%
statusU = __load_status(config['tbeg'], config['tend'], "U", config['path_to_data'])
# Out:
#  -> no such file: 2022/BW/RU/RU_2022-01-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-01-31_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-02-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-03-31_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-04-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-05-31_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-06-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-07-31_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-08-31_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-09-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-10-31_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-11-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-01_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-02_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-03_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-04_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-05_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-06_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-07_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-08_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-09_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-10_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-11_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-12_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-13_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-14_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-15_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-16_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-17_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-18_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-19_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-20_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-21_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-22_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-23_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-24_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-25_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-26_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-27_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-28_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-29_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-30_status.pkl
#  -> no such file: 2022/BW/RU/RU_2022-12-31_status.pkl

# %%
statusV = __load_status(config['tbeg'], config['tend'], "V", config['path_to_data'])
# Out:
#  -> no such file: 2022/BW/RV/RV_2022-01-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-01-31_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-02-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-03-31_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-04-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-05-31_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-06-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-07-31_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-08-31_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-09-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-10-31_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-11-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-01_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-02_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-03_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-04_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-05_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-06_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-07_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-08_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-09_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-10_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-11_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-12_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-13_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-14_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-15_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-16_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-17_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-18_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-19_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-20_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-21_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-22_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-23_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-24_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-25_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-26_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-27_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-28_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-29_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-30_status.pkl
#  -> no such file: 2022/BW/RV/RV_2022-12-31_status.pkl

# %%
statusZ = __load_status(config['tbeg'], config['tend'], "Z", config['path_to_data'])
# Out:
#  -> no such file: 2022/BW/RZ/RZ_2022-01-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-01-31_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-02-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-03-31_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-04-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-05-31_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-06-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-07-31_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-08-31_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-09-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-10-31_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-11-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-01_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-02_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-03_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-04_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-05_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-06_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-07_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-08_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-09_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-10_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-11_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-12_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-13_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-14_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-15_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-16_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-17_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-18_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-19_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-20_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-21_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-22_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-23_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-24_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-25_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-26_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-27_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-28_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-29_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-30_status.pkl
#  -> no such file: 2022/BW/RZ/RZ_2022-12-31_status.pkl

# %% [markdown]
# ### Plotting

# %%
statusU = statusU.sort_values(by="times_utc").reset_index()
statusV = statusV.sort_values(by="times_utc").reset_index()
statusZ = statusZ.sort_values(by="times_utc").reset_index()

# %%
def __makelplot_single_status(df, ring):

    names = ["quality", "fsagnac", "mlti", "ac_threshold", "dc_threshold"]
    bars = np.ones(len(names))-0.5

    arr = np.ones((len(names), df['quality'].size))

    for _n, name in enumerate(names):
        arr[_n] *= df[name]

    time_scaling = 1

    cmap = matplotlib.colors.ListedColormap(['darkred', 'green'])
    cmap.set_bad("w")

    font = 12

    fig, ax = plt.subplots(1, 1, figsize=(15, 4))

    c = ax.pcolormesh(df.times_utc_sec*time_scaling, names, arr, cmap=cmap, rasterized=False, alpha=0.8)

    for _k, bar in enumerate(bars):
        ax.axhline(bar+_k, color="w", alpha=0.8, lw=2)

    # ax.set_xlabel("Time (days)")

    ax.set_title(f"Quality Status of R{ring}")

    ref_date = df.times_utc.iloc[0]
    tcks = ax.get_xticks()
    tcklbls = [str((obs.UTCDateTime(ref_date)+t).date) for t in tcks]
    ax.set_xticklabels(tcklbls)

    ax.tick_params(axis='y', labelsize=font)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.show();
    return fig

# %%
fig = __makelplot_single_status(statusU, "U")

fig = __makelplot_single_status(statusV, "V")

fig = __makelplot_single_status(statusZ, "Z")


# print(f" -> stored: {config['path_to_figures']}R{config['ring']}_{config['tbeg'].date}_status.png")
# fig.savefig(config['path_to_figures']+f"R{config['ring']}_{config['tbeg'].date}_status.png", format="png", dpi=100, bbox_inches='tight')

# %%
## create sub-frames
statusZ_mod = statusZ[['times_utc','quality']]
statusU_mod = statusU[['times_utc','quality']]
statusV_mod = statusV[['times_utc','quality']]

## remove NaN from times
statusZ_mod = statusZ_mod.dropna(subset="times_utc").reset_index()
statusV_mod = statusV_mod.dropna(subset="times_utc").reset_index()
statusU_mod = statusU_mod.dropna(subset="times_utc").reset_index()

# statusZ_mod.shape, statusU_mod.shape, statusV_mod.shape

## make times all to string objects
statusZ_mod['times_utc'] = statusZ_mod.times_utc.astype(str)
statusU_mod['times_utc'] = statusU_mod.times_utc.astype(str)
statusV_mod['times_utc'] = statusV_mod.times_utc.astype(str)

# %%
## create new frame with all rings and their quality
df_new = statusZ_mod.copy()

print(df_new)


df_new = df_new.merge(statusU_mod, how="outer", on=["times_utc"])

print(df_new)

df_new = df_new.merge(statusV_mod, how="outer", on=["times_utc"])

print(df_new)

## drop irrelevant columns
df_new.drop(columns=["index_x", "index_y", "index"], inplace=True)

## renaming ...
df_new.rename(columns={"quality_x":"RZ", "quality_y":"RU", "quality":"RV"}, inplace=True)

## add relative times
ref_time = df_new.times_utc.iloc[0]
df_new['times_utc_sec'] = np.array([abs(obs.UTCDateTime(ref_time) - obs.UTCDateTime(_t) +30) for _t in df_new.times_utc])

## add RW column
df_new['RW'] = np.ones(df_new.shape[0])*np.nan

## sort all by time
df_new.sort_values(by="times_utc", inplace=True)

# %%
def __makelplot_all_status(df):

    names = ["RZ", "RU", "RV", "RW"]

    ## make statistics
    df_stats = DataFrame(columns=["ring", "R_0", "R_1", "R_nan", "R_N", "R_0_p", "R_1_p", "R_nan_p"])

    R_0, R_1, R_nan = np.zeros(len(names)), np.zeros(len(names)), np.zeros(len(names))
    for _n, k in enumerate(names):

        R_0 = df_new[k][df_new[k] == 0].size
        R_1 = df_new[k][df_new[k] == 1].size
        R_nan = df_new[k][df_new[k].isnull()].size
        R_N = df_new[k].size

        R_0_p = round(R_0/R_N*100, 2)
        R_1_p = round(R_1/R_N*100, 2 )
        R_nan_p = round(R_nan/R_N*100, 2)

        df_stats.loc[len(df_stats)] = [k, R_0, R_1, R_nan, R_N, R_0_p, R_1_p, R_nan_p]


    bars = np.ones(4)-0.5

    arr = np.ones((4, df.shape[0]))

    for _n, name in enumerate(names):
        arr[_n] *= df[name]

    time_scaling = 1

    cmap = matplotlib.colors.ListedColormap(['darkred', 'green'])
    cmap.set_bad("w")

    font = 12

    fig, ax = plt.subplots(1, 1, figsize=(15, 4))

    c = ax.pcolormesh(df.times_utc_sec*time_scaling, names, arr, cmap=cmap, rasterized=True, alpha=0.8)

    for _k, bar in enumerate(bars):
        ax.axhline(bar+_k, color="w", alpha=0.8, lw=2)

    ax.set_xlim(left=0)

    ax.set_title(f"Quality Status [ {config['tbeg'].date} - {config['tend'].date} ]")

    ## add dates for x-axis
    ref_date = df.times_utc.iloc[0]
    tcks = ax.get_xticks()
    tcklbls = [str((obs.UTCDateTime(ref_date)+t).date) for t in tcks]
    ax.set_xticklabels(tcklbls)

    ax.tick_params(axis='y', labelsize=font)
    ax.tick_params(axis='x', labelsize=font-2)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.show();
    return fig

fig = __makelplot_all_status(df_new);

fig.savefig(config['path_to_figures']+f"overview_timeline_{config['tbeg'].date}_{config['tend'].date}.png", format="png", dpi=150, bbox_inches='tight')

# %%
df_stats = DataFrame(columns=["ring", "R_0", "R_1", "R_nan", "R_N", "R_0_p", "R_1_p", "R_nan_p"])

rings = ['RZ', 'RU', 'RV', 'RW']

R_0, R_1, R_nan = np.zeros(len(rings)), np.zeros(len(rings)), np.zeros(len(rings))
for _n, k in enumerate(rings):

    R_0 = df_new[k][df_new[k] == 0].size
    R_1 = df_new[k][df_new[k] == 1].size
    R_nan = df_new[k][df_new[k].isnull()].size
    R_N = df_new[k].size

    R_0_p = round(R_0/R_N*100, 2)
    R_1_p = round(R_1/R_N*100, 2)
    R_nan_p = round(R_nan/R_N*100, 2)

    df_stats.loc[len(df_stats)] = [k, R_0, R_1, R_nan, R_N, R_0_p, R_1_p, R_nan_p]

df_stats

# %%
def __makeplot_statistics():

    barWidth = 0.85
    r = range(df_stats.ring.size)

    fig, ax = plt.subplots(1, 1, figsize=(8,5))

    ax.bar(r, df_stats.R_1_p,
            color='green', edgecolor='k', width=barWidth, label="Good Quality")

    ax.bar(r, df_stats.R_0_p, bottom=df_stats.R_1_p,
            color='darkred', edgecolor='k', width=barWidth, label="Bad Quality")

    ax.bar(r, df_stats.R_nan_p, bottom=[i+j for i,j in zip(df_stats.R_0_p, df_stats.R_1_p)],
            color='white', edgecolor='k', width=barWidth, label="NaN")

    ax.set_xticks(r, df_stats.ring)

    ax.legend(loc='upper left', bbox_to_anchor=(0.15, 1.1), ncol=3)

    ax.set_title(f"Quality Statistics [ {config['tbeg'].date} - {config['tend'].date} ]", pad=35)

    vals = ax.get_yticks()
    ax.set_yticklabels([f'{int(x)}%' for x in vals])

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    for c in ax.containers:

        # Optional: if the segment is small or 0, customize the labels
        labels = [round(v.get_height(), 2) if v.get_height() > 0 else '' for v in c]

        # remove the labels parameter if it's not needed for customized labels
        plt.bar_label(c, labels=labels, label_type='center', padding=0)

    plt.show();
    return fig

fig = __makeplot_statistics()

fig.savefig(config['path_to_figures']+f"overview_percent_{config['tbeg'].date}_{config['tend'].date}.png", format="png", dpi=150, bbox_inches='tight')
