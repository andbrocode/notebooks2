# %% [markdown]
# # ROMY Event Catalog

# %%
import os
import obspy as obs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# from andbro__savefig import __savefig
from obspy.clients.fdsn import Client

# %% [markdown]
# ## Configurations

# %%
if os.uname().nodename == 'lighthouse':
    root_path = '/home/andbro/'
    data_path = '/home/andbro/kilauea-data/'
    archive_path = '/home/andbro/freenas/'
elif os.uname().nodename == 'kilauea':
    root_path = '/home/brotzer/'
    data_path = '/import/kilauea-data/'
    archive_path = '/import/freenas-ffb-01-data/'

# %%
config = {}

## ROMY coordinates
config['ROMY_lon'] = 11.275501
config['ROMY_lat'] = 48.162941

## minimal magnitude
config['minmagnitude'] = 6.0

## first region specified
config['minlatitude'] = -90
config['maxlatitude'] = 90
config['minlongitude'] = -180
config['maxlongitude'] = 180

config['eventfile'] = "ROMY_global_catalog"


config['tbeg'] = obs.UTCDateTime("2019-01-01")
config['tend'] = obs.UTCDateTime("2024-04-30")


config['outpath'] = data_path+"romy_events/data/catalogs/"
# config['outpath'] = "./data/"

config['outpath_figs'] = data_path+"romy_events/figures/"

## adjust eventfile name
config['eventfile'] += f"_{str(config['tbeg'].date).replace('-','')}"
config['eventfile'] += f"_{str(config['tend'].date).replace('-','')}"

config['str_dates'] = f"{str(config['tbeg'].date).replace('-','')}_{str(config['tend'].date).replace('-','')}"

# %%
from functions.catalog_to_dataframe import __catalog_to_dataframe
from functions.add_distances_and_backazimuth import __add_distances_and_backazimuth

# %%
def __export_new_events(config, events_old, events):

    ## combine new and old catalog
    tmp = pd.concat([__cat_to_df(events_old), __cat_to_df(events)]).reset_index(drop=False)
    ## remove duplicates
    df = tmp.drop_duplicates(subset=['index'], keep=False)
    ## sort and set index
    df = df.sort_index(ascending=False)
    df.set_index('index', inplace=True, drop=True)

    ## export new events to pickle file
    print(f" -> export new events: {config['outpath']}new_events.pkl")
    df.to_pickle(config['outpath']+"new_events.pkl")

    del tmp, df

# %% [markdown]
# ## Get Events

# %%
client = Client("ISC")

## events - all in area and time period
events = client.get_events(
                           minlatitude=config['minlatitude'], maxlatitude=config['maxlatitude'],
                           minlongitude=config['minlongitude'], maxlongitude=config['maxlongitude'],
                           minmagnitude=config['minmagnitude'],
                           starttime=config['tbeg'], endtime=config['tend'],
                           )

# %%
print(f" -> storing: {config['outpath']}{config['eventfile']}.xml")
events.write(config['outpath']+config['eventfile']+".xml", format="QUAKEML")
# Out:
#  -> storing: /home/andbro/kilauea-data/romy_events/data/catalogs/ROMY_global_catalog_20190101_20240430.xml

# %% [markdown]
# ### converting to dataframe

# %%
## convert catalog object to data frame
events_df = __catalog_to_dataframe(events)

events_df = events_df.rename_axis('timestamp').reset_index()
events_df['seconds'] = [abs((events_df.timestamp.min()-tt).total_seconds()) for tt in events_df.timestamp]
events_df
# Out:
#                    timestamp  latitude  longitude     depth  magnitude type  \
# 0    2019-01-04 06:24:16.200  -27.9600  -172.6600    5000.0       6.03   mb
# 1    2019-01-05 19:25:38.000   -8.1802   -71.6436  583477.7       6.30   mb
# 2    2019-01-06 17:27:19.630    2.3041   126.7147   48386.1       6.15   mb
# 3    2019-01-08 12:39:30.820   30.5733   131.2115   32697.4       5.81   mb
# 4    2019-01-15 18:06:36.200  -13.4074   166.8097   54284.2       5.94   mb
# ...                      ...       ...        ...       ...        ...  ...
# 1164 2024-04-23 22:42:24.370  -17.6178  -178.8382  541268.0       4.86   mb
# 1165 2024-04-24 05:27:52.020  -30.1719  -177.4805   10000.0       5.38   mb
# 1166 2024-04-27 08:35:35.900   27.8630   139.5310  518200.0       5.84    M
# 1167 2024-04-27 16:29:45.120   -7.9160   107.3200   71000.0       6.08   Mw
# 1168 2024-04-27 16:29:52.500   -7.8820   107.4120   66700.0       6.08    M
#
#            seconds
# 0     0.000000e+00
# 1     1.332818e+05
# 2     2.125834e+05
# 3     3.681146e+05
# 4     9.925400e+05
# ...            ...
# 1164  1.673291e+08
# 1165  1.673534e+08
# 1166  1.676239e+08
# 1167  1.676523e+08
# 1168  1.676523e+08
#
# [1169 rows x 7 columns]

# %% [markdown]
# ### add distances and backazimuth

# %%
## add epicentral distances
__add_distances_and_backazimuth(config, events_df)
# Out:
#                    timestamp  latitude  longitude     depth  magnitude type  \
# 0    2019-01-04 06:24:16.200  -27.9600  -172.6600    5000.0       6.03   mb
# 1    2019-01-05 19:25:38.000   -8.1802   -71.6436  583477.7       6.30   mb
# 2    2019-01-06 17:27:19.630    2.3041   126.7147   48386.1       6.15   mb
# 3    2019-01-08 12:39:30.820   30.5733   131.2115   32697.4       5.81   mb
# 4    2019-01-15 18:06:36.200  -13.4074   166.8097   54284.2       5.94   mb
# ...                      ...       ...        ...       ...        ...  ...
# 1164 2024-04-23 22:42:24.370  -17.6178  -178.8382  541268.0       4.86   mb
# 1165 2024-04-24 05:27:52.020  -30.1719  -177.4805   10000.0       5.38   mb
# 1166 2024-04-27 08:35:35.900   27.8630   139.5310  518200.0       5.84    M
# 1167 2024-04-27 16:29:45.120   -7.9160   107.3200   71000.0       6.08   Mw
# 1168 2024-04-27 16:29:52.500   -7.8820   107.4120   66700.0       6.08    M
#
#            seconds  backazimuth  distances_km
# 0     0.000000e+00     9.861260  17736.186488
# 1     1.332818e+05   259.452974  10159.784920
# 2     2.125834e+05    68.838795  11666.901912
# 3     3.681146e+05    48.473355   9438.885512
# 4     9.925400e+05    38.357811  15542.253850
# ...            ...          ...           ...
# 1164  1.673291e+08    18.444150  16494.914547
# 1165  1.673534e+08    23.265545  17873.821025
# 1166  1.676239e+08    43.909283  10136.052851
# 1167  1.676523e+08    90.655824  11108.644001
# 1168  1.676523e+08    90.564217  11112.711675
#
# [1169 rows x 9 columns]

# %%
events_df = events_df[events_df.magnitude > config['minmagnitude']]

events_df.reset_index(drop=True, inplace=True)

# %%
events_df[events_df.magnitude > 9]
# Out:
#                   timestamp  latitude  longitude   depth  magnitude type  \
# 218 2022-05-31 06:04:25.530   17.9827   -67.0538  9240.0       9.15    M
# 230 2022-07-21 09:21:49.350   17.9707   -66.9613  9760.0       9.67    M
# 262 2022-09-19 04:58:32.320   17.9292   -66.8133  9710.0       9.63    M
#
__request_CMT_events(starttime=config['tbeg'], endtime=config['tend'], outtype="QUAKEML", outfile=config['outpath']+f"gcmt_solutions_{config['str_dates']}.xml")

cgmt = obs.read_events(config['outpath']+f"gcmt_solutions_{config['str_dates']}.xml")
# Out:
#  -> file: /home/andbro/kilauea-data/romy_events/data/catalogs/gcmt_solutions_20190101_20240430.xml already exists!

# %% [markdown]
# ## Plot Event Timeline

# %%
def __plot_timeline(catalog_all_df):

    fig, ax = plt.subplots(1, 1, figsize=(15, 5))

    cmap = plt.get_cmap('viridis', 7)

    cax = ax.scatter(catalog_all_df.timestamp, catalog_all_df.distances_km, s=2**catalog_all_df.magnitude,
                     c=catalog_all_df.magnitude, alpha=0.6, cmap=cmap, zorder=2)


    cbar = plt.colorbar(cax, ax=ax, pad=0.01)
    cbar.set_label("Magnitude", fontsize=14)
    cax.set_clim(6, 9.5)

    ax.set_ylim(bottom=0)
    ax.set_ylabel("Distance (km)", fontsize=14)

    ax.grid(ls=":", zorder=-1)

    ax.set_xlim(config['tbeg']-15*86400, config['tend']+15*86400)

    ax.text(config['tend']-10*86400, catalog_all_df.distances_km.max(), f"Events={len(catalog_all_df)}", ha="right")

    plt.show();
    return fig

# %%
fig = __plot_timeline(events_df)

fig.savefig(config['outpath_figs']+f"Plot_timeline_{config['eventfile']}_{config['str_dates']}.png", dpi=150, bbox_inches="tight", pad_inches=0.05)

# %%
events.plot();

# %%
cgmt[1374]
# Out:
# Event:	2023-09-08T22:11:06.900000Z | +30.990,   -8.300 | 6.9  Mwc
#
# 	                  resource_id: ResourceIdentifier(id="smi:local/ndk/C202309082211A/event")
# 	                   event_type: 'earthquake'
# 	         event_type_certainty: 'known'
# 	          preferred_origin_id: ResourceIdentifier(id="smi:local/ndk/C202309082211A/origin#cmtorigin")
# 	       preferred_magnitude_id: ResourceIdentifier(id="smi:local/ndk/C202309082211A/magnitude#moment_mag")
# 	 preferred_focal_mechanism_id: ResourceIdentifier(id="smi:local/ndk/C202309082211A/focal_mechanism")
# 	                         ---------
# 	           event_descriptions: 2 Elements
# 	             focal_mechanisms: 1 Elements
# 	                      origins: 2 Elements
# 	                   magnitudes: 3 Elements

# %%
cgmt[1374].focal_mechanisms[0].moment_tensor
# Out:
# MomentTensor
# 	          resource_id: ResourceIdentifier(id="smi:local/ndk/C202309082211A/momenttensor")
# 	    derived_origin_id: ResourceIdentifier(id="smi:local/ndk/C202309082211A/origin#cmtorigin")
# 	        scalar_moment: 2.79e+19
# 	               tensor: Tensor(m_rr=1.49e+19 [uncertainty=6e+16], m_tt=-1.79e+19 [uncertainty=5e+16], m_pp=3.09e+18 [uncertainty=4e+16], m_rt=-2.09e+19 [uncertainty=1.9e+17], m_rp=-7.72e+18 [uncertainty=1.4e+17], m_tp=2.47e+18 [uncertainty=4e+16])
# 	 source_time_function: SourceTimeFunction(type='triangle', duration=13.8)
# 	       inversion_type: 'zero trace'
# 	        creation_info: CreationInfo(agency_id='GCMT', version='V10')
# 	                 ---------
# 	            data_used: 3 Elements
