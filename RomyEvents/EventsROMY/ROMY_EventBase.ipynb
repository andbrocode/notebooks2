# %%
import obspy as obs
import pandas as pd

from andbro__querryEventFromCatalog import __querry_event_from_catalog
from andbro__writeCatalogToExcel import __write_events_to_excel

# %%
config = {}

config['tbeg'] = "2021-10-30"
config['tend'] = "2021-11-02"

config['min_magnitude'] = 6.0 

config['file'] = "/home/brotzer/Documents/ROMY/ROMY_EventBase.xls"

# %%
cat = __querry_event_from_catalog(config)
cat
# Out:
#  -->  Using IRIS as source !!

# %%
user_params = {}

user_params['ROMY_Z'] = input("On ROMY Z (TRUE | FALSE)?: ") or False
user_params['ROMY_U'] = input("On ROMY U (TRUE | FALSE)?: ") or False
user_params['ROMY_V'] = input("On ROMY V (TRUE | FALSE)?: ") or False
user_params['ROMY_W'] = input("On ROMY W (TRUE | FALSE)?: ") or False
# Out:
# On ROMY Z (TRUE | FALSE)?:
# On ROMY U (TRUE | FALSE)?:
# On ROMY V (TRUE | FALSE)?:
# On ROMY W (TRUE | FALSE)?:

# %%
# df = __write_events_to_excel(cat, config.get('file'), user_params)
# df
# Out:
#  --> Added event 11493266 to /home/brotzer/Documents/ROMY/ROMY_EventBase.xls!
#
#  --> Added event 11492939 to /home/brotzer/Documents/ROMY/ROMY_EventBase.xls!
#
#
#  --> Dublicates found:
# 2     1.14933e+07
# 3     1.14929e+07
# 4     1.14933e+07
# 5     1.14929e+07
# 6     1.14933e+07
# 7     1.14929e+07
# 8     1.14933e+07
# 9     1.14929e+07
# 10    1.14933e+07
# 11    1.14929e+07
# 12    1.14933e+07
# 13    1.14929e+07
# 14    1.14933e+07
# 15    1.14929e+07
# 16    1.14933e+07
# 17    1.14929e+07
# Name: EVENT ID, dtype: object
#        EVENT ID                     DATETIME  MAGNITUDE MAGNITUDE TYPE  \
# 0   1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 1   1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 2   1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 3   1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 4   1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 5   1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 6   1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 7   1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 8   1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 9   1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 10  1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 11  1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 12  1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 13  1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 14  1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 15  1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 16  1.14933e+07  2021-11-01T17:04:17.559000Z        6.0            mww
# 17  1.14929e+07  2021-11-01T00:02:49.075000Z        6.0            Mww
# 18     11493266  2021-11-01T17:04:17.559000Z        6.0            mww
# 19     11492939  2021-11-01T00:02:49.075000Z        6.0            Mww
#
#     LONGITUDE  LATITUDE    DEPTH ROMY Z ROMY U ROMY V ROMY W  CATALOG  \
# 0     96.7204    0.1985  15330.0    NaN    NaN    NaN    NaN      NaN
# 1    -25.2265  -58.0245  22000.0    NaN    NaN    NaN    NaN      NaN
# 2     96.7204    0.1985  15330.0    NaN    NaN    NaN    NaN      NaN
# 3    -25.2265  -58.0245  22000.0    NaN    NaN    NaN    NaN      NaN
# 4     96.7204    0.1985  15330.0    NaN    NaN    NaN    NaN      NaN
# 5    -25.2265  -58.0245  22000.0    NaN    NaN    NaN    NaN      NaN
# 6     96.7204    0.1985  15330.0      1      0      0      0      NaN
# 7    -25.2265  -58.0245  22000.0      1      0      0      0      NaN
# 8     96.7204    0.1985  15330.0      0      0      0      0      NaN
# 9    -25.2265  -58.0245  22000.0      0      0      0      0      NaN
# 10    96.7204    0.1985  15330.0      0      0      0      0      NaN
# 11   -25.2265  -58.0245  22000.0      0      0      0      0      NaN
# 12    96.7204    0.1985  15330.0      0      0      0      0      NaN
# 13   -25.2265  -58.0245  22000.0      0      0      0      0      NaN
# 14    96.7204    0.1985  15330.0      0      0      0      0      NaN
# 15   -25.2265  -58.0245  22000.0      0      0      0      0      NaN
# 16    96.7204    0.1985  15330.0      0      0      0      0      NaN
# 17   -25.2265  -58.0245  22000.0      0      0      0      0      NaN
# 18    96.7204    0.1985  15330.0  False  False  False  False      NaN
# 19   -25.2265  -58.0245  22000.0  False  False  False  False      NaN
#
#                       FLINN_ENGDAHL  RLAS
# 0                               NaN   NaN
# 1                               NaN   NaN
# 2   OFF W COAST OF NORTHERN SUMATRA   NaN
# 3     SOUTH SANDWICH ISLANDS REGION   NaN
# 4   OFF W COAST OF NORTHERN SUMATRA   NaN
# 5     SOUTH SANDWICH ISLANDS REGION   NaN
# 6   OFF W COAST OF NORTHERN SUMATRA   NaN
# 7     SOUTH SANDWICH ISLANDS REGION   NaN
# 8   OFF W COAST OF NORTHERN SUMATRA   NaN
# 9     SOUTH SANDWICH ISLANDS REGION   NaN
# 10  OFF W COAST OF NORTHERN SUMATRA   NaN
# 11    SOUTH SANDWICH ISLANDS REGION   NaN
# 12  OFF W COAST OF NORTHERN SUMATRA   NaN
# 13    SOUTH SANDWICH ISLANDS REGION   NaN
# 14  OFF W COAST OF NORTHERN SUMATRA   NaN
# 15    SOUTH SANDWICH ISLANDS REGION   NaN
# 16  OFF W COAST OF NORTHERN SUMATRA   NaN
# 17    SOUTH SANDWICH ISLANDS REGION   NaN
# 18  OFF W COAST OF NORTHERN SUMATRA   NaN
# 19    SOUTH SANDWICH ISLANDS REGION   NaN
